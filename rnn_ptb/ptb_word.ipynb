# %%
# %pylab
# %matplotlib inline
# %load_ext watermark
# %watermark -v -m -p numpy,tensorflow
# Out:
# Using matplotlib backend: Qt5Agg
# Populating the interactive namespace from numpy and matplotlib
# CPython 3.5.6
# IPython 6.5.0
#
# numpy 1.15.2
# tensorflow 1.11.0
#
# compiler   : GCC 7.3.0
# system     : Linux
# release    : 4.15.0-34-generic
# machine    : x86_64
# processor  : x86_64
# CPU cores  : 4
# interpreter: 64bit

# %% [markdown]
# 텐서플로 1.7.0 버전에서부터는 샘플 데이터를 다운로드하는 기능이 제외될 예정이라는 경고가 발생합니다. 경고를 무시하기 위해 로깅 설정을 변경합니다.

# %%
import tensorflow as tf
tf.logging.set_verbosity(tf.logging.ERROR)

# %%
import time
import tensorflow as tf
from tensorflow.contrib.rnn import BasicLSTMCell, MultiRNNCell, DropoutWrapper

import reader

# %% [markdown]
# Small Config 정보를 사용합니다.

# %%
class SmallConfig(object):
    """Small config."""
    init_scale = 0.1
    learning_rate = 1.0
    max_grad_norm = 5
    num_layers = 2
    num_steps = 20
    hidden_size = 200
    max_epoch = 4
    max_max_epoch = 13
    keep_prob = 1.0
    lr_decay = 0.5
    batch_size = 20
    vocab_size = 10000

# %% [markdown]
# 트레이닝과 테스트에 사용할 두개의 config 오브젝트를 만듭니다.

# %%
config = SmallConfig()
eval_config = SmallConfig()
eval_config.batch_size = 1
eval_config.num_steps = 1

# %% [markdown]
# PTB 모델을 만들어 주는 클래스를 작성합니다.

# %%
class PTBModel(object):
    """The PTB model."""

    def __init__(self, config, is_training=False):
        self.batch_size = config.batch_size
        self.num_steps = config.num_steps
        input_size = [config.batch_size, config.num_steps]
        self.input_data = tf.placeholder(tf.int32, input_size)
        self.targets = tf.placeholder(tf.int32, input_size)

        lstm_fn = lambda: BasicLSTMCell(config.hidden_size, forget_bias=0.0, state_is_tuple=True, 
                                        reuse=tf.get_variable_scope().reuse)
        # SmallConfig에서는 드롭아웃이 적용되지 않습니다.
        if is_training and config.keep_prob < 1:
            lstm_fn = lambda: DropoutWrapper(lstm_fn(), config.keep_prob)
        # 두개의 계층을 가진 신경망 구조를 만듭니다.
        cell = MultiRNNCell([lstm_fn() for _ in range(config.num_layers)], state_is_tuple=True)

        self.initial_state = cell.zero_state(config.batch_size, tf.float32)

        with tf.device("/cpu:0"):
            embedding_size = [config.vocab_size, config.hidden_size]
            embedding = tf.get_variable("embedding", embedding_size)
            inputs = tf.nn.embedding_lookup(embedding, self.input_data)

        # SmallConfig에서는 드롭아웃이 적용되지 않습니다.
        if is_training and config.keep_prob < 1:
            inputs = tf.nn.dropout(inputs, config.keep_prob)

        # 각 배치마다 순서대로 데이터를 뽑아 셀에 입력합니다. 
        outputs = []
        state = self.initial_state
        with tf.variable_scope("RNN"):
            for time_step in range(config.num_steps):
                if time_step > 0: tf.get_variable_scope().reuse_variables()
                (cell_output, state) = cell(inputs[:, time_step, :], state)
                outputs.append(cell_output)

        # output의 크기를 20x20x200에서 400x200으로 변경합니다.
        output = tf.reshape(tf.concat(outputs, 1), [-1, config.hidden_size])
        softmax_w_size = [config.hidden_size, config.vocab_size]
        softmax_w = tf.get_variable("softmax_w", softmax_w_size)
        softmax_b = tf.get_variable("softmax_b", [config.vocab_size])
        # logits의 크기는 400x10000이 됩니다.
        logits = tf.matmul(output, softmax_w) + softmax_b
    
        loss = tf.contrib.legacy_seq2seq.sequence_loss_by_example(
            [logits],
            [tf.reshape(self.targets, [-1])],
            [tf.ones([config.batch_size * config.num_steps])])
        self.cost = tf.reduce_sum(loss) / config.batch_size
        self.final_state = state

        if not is_training:
            return

        self.lr = tf.Variable(0.0, trainable=False)
        tvars = tf.trainable_variables()
        # 기울기 클리핑을 수행합니다.
        grads, _ = tf.clip_by_global_norm(tf.gradients(self.cost, tvars),
                                          config.max_grad_norm)
        optimizer = tf.train.GradientDescentOptimizer(self.lr)
        self.train_op = optimizer.apply_gradients(zip(grads, tvars))

    def assign_lr(self, session, lr_value):
        session.run(tf.assign(self.lr, lr_value))

# %% [markdown]
# 에포크를 처리할 함수를 만듭니다.

# %%
def run_epoch(session, m, data, is_training=False):
    """Runs the model on the given data."""
    epoch_size = ((len(data) // m.batch_size) - 1) // m.num_steps
    start_time = time.time()
    costs = 0.0
    iters = 0
    
    eval_op = m.train_op if is_training else tf.no_op()
    
    # initial_state는 2x20x200 크기의 튜플입니다.
    state_list = []
    for c, h in m.initial_state:
        state_list.extend([c.eval(), h.eval()])
    
    ptb_iter = reader.ptb_iterator(data, m.batch_size, m.num_steps)
    for step, (x, y) in enumerate(ptb_iter):
        fetch_list = [m.cost]
        # final_state 튜플에 담겨있는 상태를 꺼내어 fetch_list에 담습니다. 
        for c, h in m.final_state:
            fetch_list.extend([c, h])
        fetch_list.append(eval_op)
        
        # 이전 스텝에서 구해진 state_list가 feed_dict로 주입됩니다.
        feed_dict = {m.input_data: x, m.targets: y}
        for i in range(len(m.initial_state)):
            c, h = m.initial_state[i]
            feed_dict[c], feed_dict[h] = state_list[i*2:(i+1)*2]
        
        # fetch_list에 담긴 final_state의 결과를 state_list로 전달 받습니다.
        cost, *state_list, _ = session.run(fetch_list, feed_dict)

        costs += cost
        iters += m.num_steps

        if is_training and step % (epoch_size // 10) == 10:
            print("%.3f perplexity: %.3f speed: %.0f wps" %
                    (step * 1.0 / epoch_size, np.exp(costs / iters),
                     iters * m.batch_size / (time.time() - start_time)))

    return np.exp(costs / iters)

# %%
raw_data = reader.ptb_raw_data('simple-examples/data')
train_data, valid_data, test_data, _ = raw_data

# %% [markdown]
# train_data, valid_data, test_data 는 단어를 숫자로 바꾼 리스트입니다.
# 가장 많이 나온 단어 순으로 0번 부터 시작하여 10000번 까지의 번호를 가지고 있습니다.

# %%
with tf.Graph().as_default(), tf.Session() as session:
    initializer = tf.random_uniform_initializer(-config.init_scale, config.init_scale)

    # 학습과 검증, 테스트를 위한 모델을 만듭니다.
    with tf.variable_scope("model", reuse=None, initializer=initializer):
        m = PTBModel(config, is_training=True)
    with tf.variable_scope("model", reuse=True, initializer=initializer):
        mvalid = PTBModel(config)
        mtest = PTBModel(eval_config)
        
    tf.global_variables_initializer().run()
    
    for i in range(config.max_max_epoch):
        # lr_decay는 반복속도를 조절해 주는 역할을 합니다.
        lr_decay = config.lr_decay ** max(i - config.max_epoch, 0.0)
        m.assign_lr(session, config.learning_rate * lr_decay)
        print("Epoch: %d Learning rate: %.3f" % (i + 1, session.run(m.lr)))
        
        perplexity = run_epoch(session, m, train_data, is_training=True)
        print("Epoch: %d Train Perplexity: %.3f" % (i + 1, perplexity))

        perplexity = run_epoch(session, mvalid, valid_data)
        print("Epoch: %d Valid Perplexity: %.3f" % (i + 1, perplexity))

    perplexity = run_epoch(session, mtest, test_data)
    print("Test Perplexity: %.3f" % perplexity)
# Out:
# Epoch: 1 Learning rate: 1.000
# 0.004 perplexity: 5031.668 speed: 10529 wps
# 0.104 perplexity: 832.873 speed: 31272 wps
# 0.204 perplexity: 617.159 speed: 32771 wps
# 0.304 perplexity: 498.391 speed: 33415 wps
# 0.404 perplexity: 430.419 speed: 33594 wps
# 0.504 perplexity: 386.209 speed: 33575 wps
# 0.604 perplexity: 347.987 speed: 33671 wps
# 0.703 perplexity: 321.971 speed: 33664 wps
# 0.803 perplexity: 301.308 speed: 33779 wps
# 0.903 perplexity: 282.299 speed: 33901 wps
# Epoch: 1 Train Perplexity: 268.141
# Epoch: 1 Valid Perplexity: 178.698
# Epoch: 2 Learning rate: 1.000
# 0.004 perplexity: 210.388 speed: 26919 wps
# 0.104 perplexity: 151.180 speed: 34528 wps
# 0.204 perplexity: 158.486 speed: 34726 wps
# 0.304 perplexity: 153.300 speed: 34597 wps
# 0.404 perplexity: 150.206 speed: 34492 wps
# 0.504 perplexity: 147.746 speed: 34299 wps
# 0.604 perplexity: 143.027 speed: 34272 wps
# 0.703 perplexity: 140.945 speed: 34233 wps
# 0.803 perplexity: 138.980 speed: 34257 wps
# 0.903 perplexity: 135.458 speed: 34257 wps
# Epoch: 2 Train Perplexity: 133.433
# Epoch: 2 Valid Perplexity: 144.995
# Epoch: 3 Learning rate: 1.000
# 0.004 perplexity: 145.222 speed: 27034 wps
# 0.104 perplexity: 105.143 speed: 34255 wps
# 0.204 perplexity: 114.228 speed: 34318 wps
# 0.304 perplexity: 111.334 speed: 34436 wps
# 0.404 perplexity: 110.313 speed: 34358 wps
# 0.504 perplexity: 109.541 speed: 34235 wps
# 0.604 perplexity: 106.779 speed: 34227 wps
# 0.703 perplexity: 106.184 speed: 34232 wps
# 0.803 perplexity: 105.528 speed: 34198 wps
# 0.903 perplexity: 103.393 speed: 34231 wps
# Epoch: 3 Train Perplexity: 102.427
# Epoch: 3 Valid Perplexity: 132.684
# Epoch: 4 Learning rate: 1.000
# 0.004 perplexity: 117.225 speed: 26713 wps
# 0.104 perplexity: 85.288 speed: 33890 wps
# 0.204 perplexity: 93.882 speed: 34172 wps
# 0.304 perplexity: 91.552 speed: 33998 wps
# 0.404 perplexity: 91.027 speed: 34135 wps
# 0.504 perplexity: 90.667 speed: 34218 wps
# 0.604 perplexity: 88.643 speed: 34131 wps
# 0.703 perplexity: 88.424 speed: 34220 wps
# 0.803 perplexity: 88.189 speed: 34228 wps
# 0.903 perplexity: 86.616 speed: 34219 wps
# Epoch: 4 Train Perplexity: 86.064
# Epoch: 4 Valid Perplexity: 127.439
# Epoch: 5 Learning rate: 1.000
# 0.004 perplexity: 99.665 speed: 26395 wps
# 0.104 perplexity: 74.134 speed: 33515 wps
# 0.204 perplexity: 81.731 speed: 33775 wps
# 0.304 perplexity: 79.847 speed: 33840 wps
# 0.404 perplexity: 79.482 speed: 33999 wps
# 0.504 perplexity: 79.290 speed: 34074 wps
# 0.604 perplexity: 77.753 speed: 34121 wps
# 0.703 perplexity: 77.732 speed: 34202 wps
# 0.803 perplexity: 77.659 speed: 34159 wps
# 0.903 perplexity: 76.417 speed: 34136 wps
# Epoch: 5 Train Perplexity: 76.031
# Epoch: 5 Valid Perplexity: 127.758
# Epoch: 6 Learning rate: 0.500
# 0.004 perplexity: 89.428 speed: 26631 wps
# 0.104 perplexity: 64.691 speed: 33875 wps
# 0.204 perplexity: 69.993 speed: 33951 wps
# 0.304 perplexity: 67.313 speed: 34143 wps
# 0.404 perplexity: 66.250 speed: 34055 wps
# 0.504 perplexity: 65.364 speed: 34164 wps
# 0.604 perplexity: 63.333 speed: 34237 wps
# 0.703 perplexity: 62.637 speed: 34216 wps
# 0.803 perplexity: 61.954 speed: 34194 wps
# 0.903 perplexity: 60.307 speed: 34167 wps
# Epoch: 6 Train Perplexity: 59.398
# Epoch: 6 Valid Perplexity: 120.684
# Epoch: 7 Learning rate: 0.250
# 0.004 perplexity: 72.709 speed: 26898 wps
# 0.104 perplexity: 53.501 speed: 33948 wps
# 0.204 perplexity: 58.141 speed: 34162 wps
# 0.304 perplexity: 55.903 speed: 34130 wps
# 0.404 perplexity: 54.921 speed: 34181 wps
# 0.504 perplexity: 54.085 speed: 34136 wps
# 0.604 perplexity: 52.295 speed: 34164 wps
# 0.703 perplexity: 51.595 speed: 34168 wps
# 0.803 perplexity: 50.890 speed: 34166 wps
# 0.903 perplexity: 49.368 speed: 34195 wps
# Epoch: 7 Train Perplexity: 48.460
# Epoch: 7 Valid Perplexity: 121.728
# Epoch: 8 Learning rate: 0.125
# 0.004 perplexity: 64.692 speed: 26709 wps
# 0.104 perplexity: 47.527 speed: 33582 wps
# 0.204 perplexity: 51.775 speed: 34014 wps
# 0.304 perplexity: 49.777 speed: 34082 wps
# 0.404 perplexity: 48.850 speed: 34148 wps
# 0.504 perplexity: 48.046 speed: 34156 wps
# 0.604 perplexity: 46.428 speed: 34225 wps
# 0.703 perplexity: 45.753 speed: 34253 wps
# 0.803 perplexity: 45.069 speed: 34261 wps
# 0.903 perplexity: 43.649 speed: 34294 wps
# Epoch: 8 Train Perplexity: 42.780
# Epoch: 8 Valid Perplexity: 123.303
# Epoch: 9 Learning rate: 0.062
# 0.004 perplexity: 61.085 speed: 26576 wps
# 0.104 perplexity: 44.458 speed: 33754 wps
# 0.204 perplexity: 48.531 speed: 34038 wps
# 0.304 perplexity: 46.646 speed: 34124 wps
# 0.404 perplexity: 45.769 speed: 34126 wps
# 0.504 perplexity: 44.991 speed: 34090 wps
# 0.604 perplexity: 43.467 speed: 34139 wps
# 0.703 perplexity: 42.811 speed: 34106 wps
# 0.803 perplexity: 42.137 speed: 34116 wps
# 0.903 perplexity: 40.771 speed: 34114 wps
# Epoch: 9 Train Perplexity: 39.932
# Epoch: 9 Valid Perplexity: 124.294
# Epoch: 10 Learning rate: 0.031
# 0.004 perplexity: 59.159 speed: 26635 wps
# 0.104 perplexity: 42.907 speed: 33613 wps
# 0.204 perplexity: 46.853 speed: 33969 wps
# 0.304 perplexity: 45.003 speed: 34054 wps
# 0.404 perplexity: 44.154 speed: 34114 wps
# 0.504 perplexity: 43.403 speed: 34115 wps
# 0.604 perplexity: 41.923 speed: 34095 wps
# 0.703 perplexity: 41.285 speed: 34045 wps
# 0.803 perplexity: 40.610 speed: 34070 wps
# 0.903 perplexity: 39.275 speed: 34060 wps
# Epoch: 10 Train Perplexity: 38.448
# Epoch: 10 Valid Perplexity: 124.367
# Epoch: 11 Learning rate: 0.016
# 0.004 perplexity: 57.809 speed: 26435 wps
# 0.104 perplexity: 42.036 speed: 33504 wps
# 0.204 perplexity: 45.930 speed: 33802 wps
# 0.304 perplexity: 44.101 speed: 33927 wps
# 0.404 perplexity: 43.266 speed: 34048 wps
# 0.504 perplexity: 42.528 speed: 34042 wps
# 0.604 perplexity: 41.069 speed: 34137 wps
# 0.703 perplexity: 40.442 speed: 34115 wps
# 0.803 perplexity: 39.768 speed: 34102 wps
# 0.903 perplexity: 38.451 speed: 34174 wps
# Epoch: 11 Train Perplexity: 37.631
# Epoch: 11 Valid Perplexity: 124.000
# Epoch: 12 Learning rate: 0.008
# 0.004 perplexity: 56.914 speed: 27036 wps
# 0.104 perplexity: 41.490 speed: 34243 wps
# 0.204 perplexity: 45.369 speed: 34272 wps
# 0.304 perplexity: 43.570 speed: 34313 wps
# 0.404 perplexity: 42.753 speed: 34183 wps
# 0.504 perplexity: 42.023 speed: 34286 wps
# 0.604 perplexity: 40.579 speed: 34295 wps
# 0.703 perplexity: 39.958 speed: 34279 wps
# 0.803 perplexity: 39.290 speed: 34231 wps
# 0.903 perplexity: 37.982 speed: 34226 wps
# Epoch: 12 Train Perplexity: 37.169
# Epoch: 12 Valid Perplexity: 123.597
# Epoch: 13 Learning rate: 0.004
# 0.004 perplexity: 56.428 speed: 26646 wps
# 0.104 perplexity: 41.165 speed: 33452 wps
# 0.204 perplexity: 45.029 speed: 33664 wps
# 0.304 perplexity: 43.254 speed: 33835 wps
# 0.404 perplexity: 42.452 speed: 34000 wps
# 0.504 perplexity: 41.730 speed: 34021 wps
# 0.604 perplexity: 40.298 speed: 33997 wps
# 0.703 perplexity: 39.681 speed: 34053 wps
# 0.803 perplexity: 39.020 speed: 34103 wps
# 0.903 perplexity: 37.719 speed: 34156 wps
# Epoch: 13 Train Perplexity: 36.911
# Epoch: 13 Valid Perplexity: 123.328
# Test Perplexity: 116.045
