# %%
# %pylab
# %matplotlib inline
# %load_ext watermark
# %watermark -v -m -p numpy,tensorflow
# Out:
# Using matplotlib backend: Qt5Agg
# Populating the interactive namespace from numpy and matplotlib
# CPython 3.5.6
# IPython 6.5.0
#
# numpy 1.15.2
# tensorflow 1.13.1
#
# compiler   : GCC 7.3.0
# system     : Linux
# release    : 4.15.0-45-generic
# machine    : x86_64
# processor  : x86_64
# CPU cores  : 4
# interpreter: 64bit

# %% [markdown]
# 텐서플로 1.7.0 버전에서부터는 샘플 데이터를 다운로드하는 기능이 제외될 예정이라는 경고가 발생합니다. 경고를 무시하기 위해 로깅 설정을 변경합니다.

# %%
import tensorflow as tf
tf.logging.set_verbosity(tf.logging.ERROR)

# %%
import time
import tensorflow as tf
from tensorflow.contrib.rnn import BasicLSTMCell, MultiRNNCell, DropoutWrapper

import reader

# %% [markdown]
# Small Config 정보를 사용합니다.

# %%
class SmallConfig(object):
    """Small config."""
    init_scale = 0.1
    learning_rate = 1.0
    max_grad_norm = 5
    num_layers = 2
    num_steps = 20
    hidden_size = 200
    max_epoch = 4
    max_max_epoch = 13
    keep_prob = 1.0
    lr_decay = 0.5
    batch_size = 20
    vocab_size = 10000

# %% [markdown]
# 트레이닝과 테스트에 사용할 두개의 config 오브젝트를 만듭니다.

# %%
config = SmallConfig()
eval_config = SmallConfig()
eval_config.batch_size = 1
eval_config.num_steps = 1

# %% [markdown]
# PTB 모델을 만들어 주는 클래스를 작성합니다.

# %%
class PTBModel(object):
    """The PTB model."""

    def __init__(self, config, is_training=False):
        self.batch_size = config.batch_size
        self.num_steps = config.num_steps
        input_size = [config.batch_size, config.num_steps]
        self.input_data = tf.placeholder(tf.int32, input_size)
        self.targets = tf.placeholder(tf.int32, input_size)

        lstm_fn = lambda: BasicLSTMCell(config.hidden_size, forget_bias=0.0, state_is_tuple=True, 
                                        reuse=tf.get_variable_scope().reuse)
        # SmallConfig에서는 드롭아웃이 적용되지 않습니다.
        if is_training and config.keep_prob < 1:
            lstm_fn = lambda: DropoutWrapper(lstm_fn(), config.keep_prob)
        # 두개의 계층을 가진 신경망 구조를 만듭니다.
        cell = MultiRNNCell([lstm_fn() for _ in range(config.num_layers)], state_is_tuple=True)

        self.initial_state = cell.zero_state(config.batch_size, tf.float32)

        with tf.device("/cpu:0"):
            embedding_size = [config.vocab_size, config.hidden_size]
            embedding = tf.get_variable("embedding", embedding_size)
            inputs = tf.nn.embedding_lookup(embedding, self.input_data)

        # SmallConfig에서는 드롭아웃이 적용되지 않습니다.
        if is_training and config.keep_prob < 1:
            inputs = tf.nn.dropout(inputs, config.keep_prob)

        # 각 배치마다 순서대로 데이터를 뽑아 셀에 입력합니다. 
        outputs = []
        state = self.initial_state
        with tf.variable_scope("RNN"):
            for time_step in range(config.num_steps):
                if time_step > 0: tf.get_variable_scope().reuse_variables()
                (cell_output, state) = cell(inputs[:, time_step, :], state)
                outputs.append(cell_output)

        # output의 크기를 20x20x200에서 400x200으로 변경합니다.
        output = tf.reshape(tf.concat(outputs, 1), [-1, config.hidden_size])
        softmax_w_size = [config.hidden_size, config.vocab_size]
        softmax_w = tf.get_variable("softmax_w", softmax_w_size)
        softmax_b = tf.get_variable("softmax_b", [config.vocab_size])
        # logits의 크기는 400x10000이 됩니다.
        logits = tf.matmul(output, softmax_w) + softmax_b
    
        loss = tf.contrib.legacy_seq2seq.sequence_loss_by_example(
            [logits],
            [tf.reshape(self.targets, [-1])],
            [tf.ones([config.batch_size * config.num_steps])])
        self.cost = tf.reduce_sum(loss) / config.batch_size
        self.final_state = state

        if not is_training:
            return

        self.lr = tf.Variable(0.0, trainable=False)
        tvars = tf.trainable_variables()
        # 기울기 클리핑을 수행합니다.
        grads, _ = tf.clip_by_global_norm(tf.gradients(self.cost, tvars),
                                          config.max_grad_norm)
        optimizer = tf.train.GradientDescentOptimizer(self.lr)
        self.train_op = optimizer.apply_gradients(zip(grads, tvars))

    def assign_lr(self, session, lr_value):
        session.run(tf.assign(self.lr, lr_value))

# %% [markdown]
# 에포크를 처리할 함수를 만듭니다.

# %%
def run_epoch(session, m, data, is_training=False):
    """Runs the model on the given data."""
    epoch_size = ((len(data) // m.batch_size) - 1) // m.num_steps
    start_time = time.time()
    costs = 0.0
    iters = 0
    
    eval_op = m.train_op if is_training else tf.no_op()
    
    # initial_state는 2x20x200 크기의 튜플입니다.
    state_list = []
    for c, h in m.initial_state:
        state_list.extend([c.eval(), h.eval()])
    
    ptb_iter = reader.ptb_iterator(data, m.batch_size, m.num_steps)
    for step, (x, y) in enumerate(ptb_iter):
        fetch_list = [m.cost]
        # final_state 튜플에 담겨있는 상태를 꺼내어 fetch_list에 담습니다. 
        for c, h in m.final_state:
            fetch_list.extend([c, h])
        fetch_list.append(eval_op)
        
        # 이전 스텝에서 구해진 state_list가 feed_dict로 주입됩니다.
        feed_dict = {m.input_data: x, m.targets: y}
        for i in range(len(m.initial_state)):
            c, h = m.initial_state[i]
            feed_dict[c], feed_dict[h] = state_list[i*2:(i+1)*2]
        
        # fetch_list에 담긴 final_state의 결과를 state_list로 전달 받습니다.
        cost, *state_list, _ = session.run(fetch_list, feed_dict)

        costs += cost
        iters += m.num_steps

        if is_training and step % (epoch_size // 10) == 10:
            print("%.3f perplexity: %.3f speed: %.0f wps" %
                    (step * 1.0 / epoch_size, np.exp(costs / iters),
                     iters * m.batch_size / (time.time() - start_time)))

    return np.exp(costs / iters)

# %%
raw_data = reader.ptb_raw_data('simple-examples/data')
train_data, valid_data, test_data, _ = raw_data

# %% [markdown]
# train_data, valid_data, test_data 는 단어를 숫자로 바꾼 리스트입니다.
# 가장 많이 나온 단어 순으로 0번 부터 시작하여 10000번 까지의 번호를 가지고 있습니다.

# %%
with tf.Graph().as_default(), tf.Session() as session:
    initializer = tf.random_uniform_initializer(-config.init_scale, config.init_scale)

    # 학습과 검증, 테스트를 위한 모델을 만듭니다.
    with tf.variable_scope("model", reuse=None, initializer=initializer):
        m = PTBModel(config, is_training=True)
    with tf.variable_scope("model", reuse=True, initializer=initializer):
        mvalid = PTBModel(config)
        mtest = PTBModel(eval_config)
        
    tf.global_variables_initializer().run()
    
    for i in range(config.max_max_epoch):
        # lr_decay는 반복속도를 조절해 주는 역할을 합니다.
        lr_decay = config.lr_decay ** max(i - config.max_epoch, 0.0)
        m.assign_lr(session, config.learning_rate * lr_decay)
        print("Epoch: %d Learning rate: %.3f" % (i + 1, session.run(m.lr)))
        
        perplexity = run_epoch(session, m, train_data, is_training=True)
        print("Epoch: %d Train Perplexity: %.3f" % (i + 1, perplexity))

        perplexity = run_epoch(session, mvalid, valid_data)
        print("Epoch: %d Valid Perplexity: %.3f" % (i + 1, perplexity))

    perplexity = run_epoch(session, mtest, test_data)
    print("Test Perplexity: %.3f" % perplexity)
# Out:
# Epoch: 1 Learning rate: 1.000
# 0.004 perplexity: 5577.968 speed: 4188 wps
# 0.104 perplexity: 849.255 speed: 5395 wps
# 0.204 perplexity: 629.489 speed: 5429 wps
# 0.304 perplexity: 506.071 speed: 5448 wps
# 0.404 perplexity: 435.397 speed: 5458 wps
# 0.504 perplexity: 389.620 speed: 5467 wps
# 0.604 perplexity: 350.841 speed: 5469 wps
# 0.703 perplexity: 324.115 speed: 5462 wps
# 0.803 perplexity: 303.062 speed: 5463 wps
# 0.903 perplexity: 283.718 speed: 5468 wps
# Epoch: 1 Train Perplexity: 269.315
# Epoch: 1 Valid Perplexity: 179.192
# Epoch: 2 Learning rate: 1.000
# 0.004 perplexity: 212.316 speed: 5214 wps
# 0.104 perplexity: 152.633 speed: 5467 wps
# 0.204 perplexity: 159.769 speed: 5480 wps
# 0.304 perplexity: 154.691 speed: 5471 wps
# 0.404 perplexity: 151.657 speed: 5469 wps
# 0.504 perplexity: 149.161 speed: 5471 wps
# 0.604 perplexity: 144.546 speed: 5475 wps
# 0.703 perplexity: 142.398 speed: 5476 wps
# 0.803 perplexity: 140.333 speed: 5480 wps
# 0.903 perplexity: 136.658 speed: 5481 wps
# Epoch: 2 Train Perplexity: 134.618
# Epoch: 2 Valid Perplexity: 143.331
# Epoch: 3 Learning rate: 1.000
# 0.004 perplexity: 148.121 speed: 5283 wps
# 0.104 perplexity: 106.703 speed: 5455 wps
# 0.204 perplexity: 115.807 speed: 5473 wps
# 0.304 perplexity: 112.891 speed: 5476 wps
# 0.404 perplexity: 111.718 speed: 5478 wps
# 0.504 perplexity: 110.849 speed: 5478 wps
# 0.604 perplexity: 108.211 speed: 5479 wps
# 0.703 perplexity: 107.526 speed: 5470 wps
# 0.803 perplexity: 106.846 speed: 5472 wps
# 0.903 perplexity: 104.569 speed: 5471 wps
# Epoch: 3 Train Perplexity: 103.598
# Epoch: 3 Valid Perplexity: 133.814
# Epoch: 4 Learning rate: 1.000
# 0.004 perplexity: 117.418 speed: 5225 wps
# 0.104 perplexity: 86.490 speed: 5477 wps
# 0.204 perplexity: 94.773 speed: 5484 wps
# 0.304 perplexity: 92.611 speed: 5487 wps
# 0.404 perplexity: 92.038 speed: 5478 wps
# 0.504 perplexity: 91.572 speed: 5481 wps
# 0.604 perplexity: 89.665 speed: 5480 wps
# 0.703 perplexity: 89.421 speed: 5485 wps
# 0.803 perplexity: 89.181 speed: 5487 wps
# 0.903 perplexity: 87.500 speed: 5488 wps
# Epoch: 4 Train Perplexity: 86.949
# Epoch: 4 Valid Perplexity: 127.721
# Epoch: 5 Learning rate: 1.000
# 0.004 perplexity: 98.373 speed: 5147 wps
# 0.104 perplexity: 74.484 speed: 5432 wps
# 0.204 perplexity: 82.173 speed: 5472 wps
# 0.304 perplexity: 80.403 speed: 5471 wps
# 0.404 perplexity: 80.052 speed: 5474 wps
# 0.504 perplexity: 79.863 speed: 5479 wps
# 0.604 perplexity: 78.398 speed: 5478 wps
# 0.703 perplexity: 78.335 speed: 5482 wps
# 0.803 perplexity: 78.259 speed: 5481 wps
# 0.903 perplexity: 76.955 speed: 5481 wps
# Epoch: 5 Train Perplexity: 76.648
# Epoch: 5 Valid Perplexity: 128.232
# Epoch: 6 Learning rate: 0.500
# 0.004 perplexity: 88.571 speed: 5213 wps
# 0.104 perplexity: 65.135 speed: 5453 wps
# 0.204 perplexity: 70.353 speed: 5467 wps
# 0.304 perplexity: 67.758 speed: 5472 wps
# 0.404 perplexity: 66.678 speed: 5467 wps
# 0.504 perplexity: 65.765 speed: 5469 wps
# 0.604 perplexity: 63.845 speed: 5470 wps
# 0.703 perplexity: 63.098 speed: 5473 wps
# 0.803 perplexity: 62.340 speed: 5475 wps
# 0.903 perplexity: 60.624 speed: 5477 wps
# Epoch: 6 Train Perplexity: 59.766
# Epoch: 6 Valid Perplexity: 121.034
# Epoch: 7 Learning rate: 0.250
# 0.004 perplexity: 73.110 speed: 5317 wps
# 0.104 perplexity: 53.749 speed: 5429 wps
# 0.204 perplexity: 58.375 speed: 5454 wps
# 0.304 perplexity: 56.063 speed: 5467 wps
# 0.404 perplexity: 55.092 speed: 5469 wps
# 0.504 perplexity: 54.286 speed: 5473 wps
# 0.604 perplexity: 52.613 speed: 5476 wps
# 0.703 perplexity: 51.892 speed: 5475 wps
# 0.803 perplexity: 51.100 speed: 5465 wps
# 0.903 perplexity: 49.533 speed: 5466 wps
# Epoch: 7 Train Perplexity: 48.664
# Epoch: 7 Valid Perplexity: 120.857
# Epoch: 8 Learning rate: 0.125
# 0.004 perplexity: 65.242 speed: 5250 wps
# 0.104 perplexity: 47.659 speed: 5499 wps
# 0.204 perplexity: 51.878 speed: 5495 wps
# 0.304 perplexity: 49.756 speed: 5491 wps
# 0.404 perplexity: 48.881 speed: 5491 wps
# 0.504 perplexity: 48.127 speed: 5476 wps
# 0.604 perplexity: 46.603 speed: 5480 wps
# 0.703 perplexity: 45.920 speed: 5478 wps
# 0.803 perplexity: 45.153 speed: 5480 wps
# 0.903 perplexity: 43.698 speed: 5482 wps
# Epoch: 8 Train Perplexity: 42.879
# Epoch: 8 Valid Perplexity: 122.045
# Epoch: 9 Learning rate: 0.062
# 0.004 perplexity: 61.017 speed: 5193 wps
# 0.104 perplexity: 44.504 speed: 5470 wps
# 0.204 perplexity: 48.557 speed: 5474 wps
# 0.304 perplexity: 46.541 speed: 5485 wps
# 0.404 perplexity: 45.732 speed: 5481 wps
# 0.504 perplexity: 45.015 speed: 5483 wps
# 0.604 perplexity: 43.568 speed: 5486 wps
# 0.703 perplexity: 42.911 speed: 5484 wps
# 0.803 perplexity: 42.160 speed: 5485 wps
# 0.903 perplexity: 40.762 speed: 5483 wps
# Epoch: 9 Train Perplexity: 39.972
# Epoch: 9 Valid Perplexity: 122.962
# Epoch: 10 Learning rate: 0.031
# 0.004 perplexity: 59.156 speed: 5173 wps
# 0.104 perplexity: 42.913 speed: 5470 wps
# 0.204 perplexity: 46.857 speed: 5463 wps
# 0.304 perplexity: 44.897 speed: 5463 wps
# 0.404 perplexity: 44.133 speed: 5469 wps
# 0.504 perplexity: 43.427 speed: 5424 wps
# 0.604 perplexity: 42.018 speed: 5388 wps
# 0.703 perplexity: 41.374 speed: 5118 wps
# 0.803 perplexity: 40.627 speed: 4900 wps
# 0.903 perplexity: 39.256 speed: 4867 wps
# Epoch: 10 Train Perplexity: 38.475
# Epoch: 10 Valid Perplexity: 123.339
# Epoch: 11 Learning rate: 0.016
# 0.004 perplexity: 58.050 speed: 5238 wps
# 0.104 perplexity: 42.057 speed: 5451 wps
# 0.204 perplexity: 45.927 speed: 5474 wps
# 0.304 perplexity: 44.006 speed: 5479 wps
# 0.404 perplexity: 43.264 speed: 5475 wps
# 0.504 perplexity: 42.570 speed: 5478 wps
# 0.604 perplexity: 41.176 speed: 5393 wps
# 0.703 perplexity: 40.538 speed: 5376 wps
# 0.803 perplexity: 39.796 speed: 5359 wps
# 0.903 perplexity: 38.440 speed: 5345 wps
# Epoch: 11 Train Perplexity: 37.660
# Epoch: 11 Valid Perplexity: 123.317
# Epoch: 12 Learning rate: 0.008
# 0.004 perplexity: 57.320 speed: 4845 wps
# 0.104 perplexity: 41.555 speed: 5207 wps
# 0.204 perplexity: 45.403 speed: 4727 wps
# 0.304 perplexity: 43.509 speed: 4779 wps
# 0.404 perplexity: 42.771 speed: 4857 wps
# 0.504 perplexity: 42.082 speed: 4912 wps
# 0.604 perplexity: 40.698 speed: 4962 wps
# 0.703 perplexity: 40.063 speed: 4886 wps
# 0.803 perplexity: 39.328 speed: 4754 wps
# 0.903 perplexity: 37.982 speed: 4711 wps
# Epoch: 12 Train Perplexity: 37.204
# Epoch: 12 Valid Perplexity: 123.014
# Epoch: 13 Learning rate: 0.004
# 0.004 perplexity: 56.821 speed: 4742 wps
# 0.104 perplexity: 41.247 speed: 5157 wps
# 0.204 perplexity: 45.098 speed: 5265 wps
# 0.304 perplexity: 43.225 speed: 5318 wps
# 0.404 perplexity: 42.491 speed: 5357 wps
# 0.504 perplexity: 41.804 speed: 5383 wps
# 0.604 perplexity: 40.429 speed: 5400 wps
# 0.703 perplexity: 39.797 speed: 5415 wps
# 0.803 perplexity: 39.067 speed: 5425 wps
# 0.903 perplexity: 37.729 speed: 5432 wps
# Epoch: 13 Train Perplexity: 36.953
# Epoch: 13 Valid Perplexity: 122.715
# Test Perplexity: 118.137
