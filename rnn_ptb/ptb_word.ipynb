# %%
# %pylab
# %matplotlib inline
# %load_ext watermark
# %watermark -v -m -p numpy,tensorflow
# Out:
# Using matplotlib backend: MacOSX
# Populating the interactive namespace from numpy and matplotlib
# CPython 3.5.2
# IPython 5.1.0
#
# numpy 1.13.1
# tensorflow 1.3.0
#
# compiler   : GCC 4.2.1 Compatible Apple LLVM 4.2 (clang-425.0.28)
# system     : Darwin
# release    : 16.7.0
# machine    : x86_64
# processor  : i386
# CPU cores  : 8
# interpreter: 64bit

# %%
import time
import tensorflow as tf
from tensorflow.contrib.rnn import BasicLSTMCell, MultiRNNCell, DropoutWrapper

import reader

# %% [markdown]
# Small Config 정보를 사용합니다.

# %%
class SmallConfig(object):
    """Small config."""
    init_scale = 0.1
    learning_rate = 1.0
    max_grad_norm = 5
    num_layers = 2
    num_steps = 20
    hidden_size = 200
    max_epoch = 4
    max_max_epoch = 13
    keep_prob = 1.0
    lr_decay = 0.5
    batch_size = 20
    vocab_size = 10000

# %% [markdown]
# 트레이닝과 테스트에 사용할 두개의 config 오브젝트를 만듭니다.

# %%
config = SmallConfig()
eval_config = SmallConfig()
eval_config.batch_size = 1
eval_config.num_steps = 1

# %% [markdown]
# PTB 모델을 만들어 주는 클래스를 작성합니다.

# %%
class PTBModel(object):
    """The PTB model."""

    def __init__(self, config, is_training=False):
        self.batch_size = config.batch_size
        self.num_steps = config.num_steps
        input_size = [config.batch_size, config.num_steps]
        self.input_data = tf.placeholder(tf.int32, input_size)
        self.targets = tf.placeholder(tf.int32, input_size)

        lstm_fn = lambda: BasicLSTMCell(config.hidden_size, forget_bias=0.0, state_is_tuple=True, 
                                        reuse=tf.get_variable_scope().reuse)
        # SmallConfig에서는 드롭아웃이 적용되지 않습니다.
        if is_training and config.keep_prob < 1:
            lstm_fn = lambda: DropoutWrapper(lstm_fn(), config.keep_prob)
        # 두개의 계층을 가진 신경망 구조를 만듭니다.
        cell = MultiRNNCell([lstm_fn() for _ in range(config.num_layers)], state_is_tuple=True)

        self.initial_state = cell.zero_state(config.batch_size, tf.float32)

        with tf.device("/cpu:0"):
            embedding_size = [config.vocab_size, config.hidden_size]
            embedding = tf.get_variable("embedding", embedding_size)
            inputs = tf.nn.embedding_lookup(embedding, self.input_data)

        # SmallConfig에서는 드롭아웃이 적용되지 않습니다.
        if is_training and config.keep_prob < 1:
            inputs = tf.nn.dropout(inputs, config.keep_prob)

        # 각 배치마다 순서대로 데이터를 뽑아 셀에 입력합니다. 
        outputs = []
        state = self.initial_state
        with tf.variable_scope("RNN"):
            for time_step in range(config.num_steps):
                if time_step > 0: tf.get_variable_scope().reuse_variables()
                (cell_output, state) = cell(inputs[:, time_step, :], state)
                outputs.append(cell_output)

        # output의 크기를 20x20x200에서 400x200으로 변경합니다.
        output = tf.reshape(tf.concat(outputs, 1), [-1, config.hidden_size])
        softmax_w_size = [config.hidden_size, config.vocab_size]
        softmax_w = tf.get_variable("softmax_w", softmax_w_size)
        softmax_b = tf.get_variable("softmax_b", [config.vocab_size])
        # logits의 크기는 400x10000이 됩니다.
        logits = tf.matmul(output, softmax_w) + softmax_b
    
        loss = tf.contrib.legacy_seq2seq.sequence_loss_by_example(
            [logits],
            [tf.reshape(self.targets, [-1])],
            [tf.ones([config.batch_size * config.num_steps])])
        self.cost = tf.reduce_sum(loss) / config.batch_size
        self.final_state = state

        if not is_training:
            return

        self.lr = tf.Variable(0.0, trainable=False)
        tvars = tf.trainable_variables()
        # 기울기 클리핑을 수행합니다.
        grads, _ = tf.clip_by_global_norm(tf.gradients(self.cost, tvars),
                                          config.max_grad_norm)
        optimizer = tf.train.GradientDescentOptimizer(self.lr)
        self.train_op = optimizer.apply_gradients(zip(grads, tvars))

    def assign_lr(self, session, lr_value):
        session.run(tf.assign(self.lr, lr_value))

# %% [markdown]
# 에포크를 처리할 함수를 만듭니다.

# %%
def run_epoch(session, m, data, is_training=False):
    """Runs the model on the given data."""
    epoch_size = ((len(data) // m.batch_size) - 1) // m.num_steps
    start_time = time.time()
    costs = 0.0
    iters = 0
    
    eval_op = m.train_op if is_training else tf.no_op()
    
    # initial_state는 2x20x200 크기의 튜플입니다.
    state_list = []
    for c, h in m.initial_state:
        state_list.extend([c.eval(), h.eval()])
    
    ptb_iter = reader.ptb_iterator(data, m.batch_size, m.num_steps)
    for step, (x, y) in enumerate(ptb_iter):
        fetch_list = [m.cost]
        # final_state 튜플에 담겨있는 상태를 꺼내어 fetch_list에 담습니다. 
        for c, h in m.final_state:
            fetch_list.extend([c, h])
        fetch_list.append(eval_op)
        
        # 이전 스텝에서 구해진 state_list가 feed_dict로 주입됩니다.
        feed_dict = {m.input_data: x, m.targets: y}
        for i in range(len(m.initial_state)):
            c, h = m.initial_state[i]
            feed_dict[c], feed_dict[h] = state_list[i*2:(i+1)*2]
        
        # fetch_list에 담긴 final_state의 결과를 state_list로 전달 받습니다.
        cost, *state_list, _ = session.run(fetch_list, feed_dict)

        costs += cost
        iters += m.num_steps

        if is_training and step % (epoch_size // 10) == 10:
            print("%.3f perplexity: %.3f speed: %.0f wps" %
                    (step * 1.0 / epoch_size, np.exp(costs / iters),
                     iters * m.batch_size / (time.time() - start_time)))

    return np.exp(costs / iters)

# %%
raw_data = reader.ptb_raw_data('simple-examples/data')
train_data, valid_data, test_data, _ = raw_data

# %% [markdown]
# train_data, valid_data, test_data 는 단어를 숫자로 바꾼 리스트입니다.
# 가장 많이 나온 단어 순으로 0번 부터 시작하여 10000번 까지의 번호를 가지고 있습니다.

# %%
with tf.Graph().as_default(), tf.Session() as session:
    initializer = tf.random_uniform_initializer(-config.init_scale, config.init_scale)

    # 학습과 검증, 테스트를 위한 모델을 만듭니다.
    with tf.variable_scope("model", reuse=None, initializer=initializer):
        m = PTBModel(config, is_training=True)
    with tf.variable_scope("model", reuse=True, initializer=initializer):
        mvalid = PTBModel(config)
        mtest = PTBModel(eval_config)
        
    tf.global_variables_initializer().run()
    
    for i in range(config.max_max_epoch):
        # lr_decay는 반복속도를 조절해 주는 역할을 합니다.
        lr_decay = config.lr_decay ** max(i - config.max_epoch, 0.0)
        m.assign_lr(session, config.learning_rate * lr_decay)
        print("Epoch: %d Learning rate: %.3f" % (i + 1, session.run(m.lr)))
        
        perplexity = run_epoch(session, m, train_data, is_training=True)
        print("Epoch: %d Train Perplexity: %.3f" % (i + 1, perplexity))

        perplexity = run_epoch(session, mvalid, valid_data)
        print("Epoch: %d Valid Perplexity: %.3f" % (i + 1, perplexity))

    perplexity = run_epoch(session, mtest, test_data)
    print("Test Perplexity: %.3f" % perplexity)
# Out:
# Epoch: 1 Learning rate: 1.000
# 0.004 perplexity: 5136.346 speed: 2337 wps
# 0.104 perplexity: 834.726 speed: 2441 wps
# 0.204 perplexity: 620.344 speed: 2350 wps
# 0.304 perplexity: 501.597 speed: 2308 wps
# 0.404 perplexity: 432.540 speed: 2258 wps
# 0.504 perplexity: 387.669 speed: 2210 wps
# 0.604 perplexity: 349.204 speed: 2186 wps
# 0.703 perplexity: 322.797 speed: 2174 wps
# 0.803 perplexity: 301.890 speed: 2165 wps
# 0.903 perplexity: 282.561 speed: 2154 wps
# Epoch: 1 Train Perplexity: 268.177
# Epoch: 1 Valid Perplexity: 178.404
# Epoch: 2 Learning rate: 1.000
# 0.004 perplexity: 212.744 speed: 1974 wps
# 0.104 perplexity: 151.204 speed: 2046 wps
# 0.204 perplexity: 158.224 speed: 2044 wps
# 0.304 perplexity: 152.809 speed: 2047 wps
# 0.404 perplexity: 149.911 speed: 2045 wps
# 0.504 perplexity: 147.554 speed: 2043 wps
# 0.604 perplexity: 142.967 speed: 2040 wps
# 0.703 perplexity: 140.832 speed: 2039 wps
# 0.803 perplexity: 138.831 speed: 2038 wps
# 0.903 perplexity: 135.148 speed: 2037 wps
# Epoch: 2 Train Perplexity: 133.044
# Epoch: 2 Valid Perplexity: 141.441
# Epoch: 3 Learning rate: 1.000
# 0.004 perplexity: 141.702 speed: 1907 wps
# 0.104 perplexity: 104.695 speed: 2021 wps
# 0.204 perplexity: 113.808 speed: 1998 wps
# 0.304 perplexity: 110.767 speed: 2000 wps
# 0.404 perplexity: 109.823 speed: 2006 wps
# 0.504 perplexity: 109.058 speed: 2008 wps
# 0.604 perplexity: 106.410 speed: 2010 wps
# 0.703 perplexity: 105.796 speed: 2010 wps
# 0.803 perplexity: 105.178 speed: 2010 wps
# 0.903 perplexity: 102.923 speed: 2011 wps
# Epoch: 3 Train Perplexity: 101.917
# Epoch: 3 Valid Perplexity: 130.571
# Epoch: 4 Learning rate: 1.000
# 0.004 perplexity: 112.647 speed: 1921 wps
# 0.104 perplexity: 84.686 speed: 2004 wps
# 0.204 perplexity: 93.119 speed: 2012 wps
# 0.304 perplexity: 90.814 speed: 1980 wps
# 0.404 perplexity: 90.365 speed: 1961 wps
# 0.504 perplexity: 90.056 speed: 1953 wps
# 0.604 perplexity: 88.302 speed: 1947 wps
# 0.703 perplexity: 88.152 speed: 1958 wps
# 0.803 perplexity: 87.910 speed: 1963 wps
# 0.903 perplexity: 86.280 speed: 1967 wps
# Epoch: 4 Train Perplexity: 85.689
# Epoch: 4 Valid Perplexity: 127.406
# Epoch: 5 Learning rate: 1.000
# 0.004 perplexity: 97.472 speed: 1970 wps
# 0.104 perplexity: 73.286 speed: 1978 wps
# 0.204 perplexity: 81.005 speed: 1914 wps
# 0.304 perplexity: 79.209 speed: 1921 wps
# 0.404 perplexity: 78.986 speed: 1926 wps
# 0.504 perplexity: 78.846 speed: 1921 wps
# 0.604 perplexity: 77.478 speed: 1919 wps
# 0.703 perplexity: 77.543 speed: 1914 wps
# 0.803 perplexity: 77.463 speed: 1916 wps
# 0.903 perplexity: 76.150 speed: 1916 wps
# Epoch: 5 Train Perplexity: 75.748
# Epoch: 5 Valid Perplexity: 126.791
# Epoch: 6 Learning rate: 0.500
# 0.004 perplexity: 85.902 speed: 1840 wps
# 0.104 perplexity: 63.924 speed: 1852 wps
# 0.204 perplexity: 69.332 speed: 1848 wps
# 0.304 perplexity: 66.720 speed: 1863 wps
# 0.404 perplexity: 65.786 speed: 1869 wps
# 0.504 perplexity: 64.989 speed: 1873 wps
# 0.604 perplexity: 63.162 speed: 1876 wps
# 0.703 perplexity: 62.519 speed: 1877 wps
# 0.803 perplexity: 61.800 speed: 1877 wps
# 0.903 perplexity: 60.075 speed: 1880 wps
# Epoch: 6 Train Perplexity: 59.141
# Epoch: 6 Valid Perplexity: 120.530
# Epoch: 7 Learning rate: 0.250
# 0.004 perplexity: 71.923 speed: 1643 wps
# 0.104 perplexity: 52.763 speed: 1661 wps
# 0.204 perplexity: 57.521 speed: 1712 wps
# 0.304 perplexity: 55.281 speed: 1758 wps
# 0.404 perplexity: 54.455 speed: 1783 wps
# 0.504 perplexity: 53.688 speed: 1797 wps
# 0.604 perplexity: 52.058 speed: 1802 wps
# 0.703 perplexity: 51.409 speed: 1805 wps
# 0.803 perplexity: 50.674 speed: 1810 wps
# 0.903 perplexity: 49.108 speed: 1813 wps
# Epoch: 7 Train Perplexity: 48.172
# Epoch: 7 Valid Perplexity: 120.604
# Epoch: 8 Learning rate: 0.125
# 0.004 perplexity: 64.107 speed: 1887 wps
# 0.104 perplexity: 46.789 speed: 1852 wps
# 0.204 perplexity: 51.100 speed: 1851 wps
# 0.304 perplexity: 49.100 speed: 1846 wps
# 0.404 perplexity: 48.348 speed: 1848 wps
# 0.504 perplexity: 47.639 speed: 1847 wps
# 0.604 perplexity: 46.150 speed: 1856 wps
# 0.703 perplexity: 45.520 speed: 1864 wps
# 0.803 perplexity: 44.804 speed: 1869 wps
# 0.903 perplexity: 43.350 speed: 1875 wps
# Epoch: 8 Train Perplexity: 42.459
# Epoch: 8 Valid Perplexity: 121.982
# Epoch: 9 Learning rate: 0.062
# 0.004 perplexity: 60.079 speed: 1834 wps
# 0.104 perplexity: 43.810 speed: 1916 wps
# 0.204 perplexity: 47.916 speed: 1920 wps
# 0.304 perplexity: 46.009 speed: 1923 wps
# 0.404 perplexity: 45.288 speed: 1924 wps
# 0.504 perplexity: 44.601 speed: 1926 wps
# 0.604 perplexity: 43.182 speed: 1924 wps
# 0.703 perplexity: 42.555 speed: 1925 wps
# 0.803 perplexity: 41.850 speed: 1927 wps
# 0.903 perplexity: 40.452 speed: 1928 wps
# Epoch: 9 Train Perplexity: 39.588
# Epoch: 9 Valid Perplexity: 123.159
# Epoch: 10 Learning rate: 0.031
# 0.004 perplexity: 57.799 speed: 1849 wps
# 0.104 perplexity: 42.306 speed: 1926 wps
# 0.204 perplexity: 46.296 speed: 1931 wps
# 0.304 perplexity: 44.435 speed: 1933 wps
# 0.404 perplexity: 43.716 speed: 1933 wps
# 0.504 perplexity: 43.039 speed: 1931 wps
# 0.604 perplexity: 41.661 speed: 1932 wps
# 0.703 perplexity: 41.030 speed: 1933 wps
# 0.803 perplexity: 40.328 speed: 1934 wps
# 0.903 perplexity: 38.956 speed: 1936 wps
# Epoch: 10 Train Perplexity: 38.105
# Epoch: 10 Valid Perplexity: 123.606
# Epoch: 11 Learning rate: 0.016
# 0.004 perplexity: 56.450 speed: 1899 wps
# 0.104 perplexity: 41.469 speed: 1914 wps
# 0.204 perplexity: 45.390 speed: 1920 wps
# 0.304 perplexity: 43.547 speed: 1927 wps
# 0.404 perplexity: 42.834 speed: 1930 wps
# 0.504 perplexity: 42.168 speed: 1930 wps
# 0.604 perplexity: 40.819 speed: 1931 wps
# 0.703 perplexity: 40.190 speed: 1931 wps
# 0.803 perplexity: 39.490 speed: 1931 wps
# 0.903 perplexity: 38.136 speed: 1929 wps
# Epoch: 11 Train Perplexity: 37.294
# Epoch: 11 Valid Perplexity: 123.459
# Epoch: 12 Learning rate: 0.008
# 0.004 perplexity: 55.659 speed: 1928 wps
# 0.104 perplexity: 40.974 speed: 1938 wps
# 0.204 perplexity: 44.850 speed: 1934 wps
# 0.304 perplexity: 43.025 speed: 1930 wps
# 0.404 perplexity: 42.323 speed: 1927 wps
# 0.504 perplexity: 41.667 speed: 1925 wps
# 0.604 perplexity: 40.338 speed: 1929 wps
# 0.703 perplexity: 39.716 speed: 1925 wps
# 0.803 perplexity: 39.019 speed: 1919 wps
# 0.903 perplexity: 37.677 speed: 1919 wps
# Epoch: 12 Train Perplexity: 36.842
# Epoch: 12 Valid Perplexity: 123.121
# Epoch: 13 Learning rate: 0.004
# 0.004 perplexity: 55.200 speed: 1844 wps
# 0.104 perplexity: 40.671 speed: 1938 wps
# 0.204 perplexity: 44.526 speed: 1939 wps
# 0.304 perplexity: 42.722 speed: 1937 wps
# 0.404 perplexity: 42.031 speed: 1937 wps
# 0.504 perplexity: 41.384 speed: 1936 wps
# 0.604 perplexity: 40.066 speed: 1936 wps
# 0.703 perplexity: 39.449 speed: 1936 wps
# 0.803 perplexity: 38.756 speed: 1936 wps
# 0.903 perplexity: 37.422 speed: 1937 wps
# Epoch: 13 Train Perplexity: 36.592
# Epoch: 13 Valid Perplexity: 122.825
# Test Perplexity: 116.858
