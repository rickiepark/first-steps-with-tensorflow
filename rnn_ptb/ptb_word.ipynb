# %%
# %pylab
# %matplotlib inline
# %load_ext watermark
# %watermark -v -m -p numpy,tensorflow
# Out:
# Using matplotlib backend: MacOSX
# Populating the interactive namespace from numpy and matplotlib
# CPython 3.5.2
# IPython 5.1.0
#
# numpy 1.11.2
# tensorflow 0.11.0
#
# compiler   : GCC 4.2.1 Compatible Apple LLVM 4.2 (clang-425.0.28)
# system     : Darwin
# release    : 16.1.0
# machine    : x86_64
# processor  : i386
# CPU cores  : 8
# interpreter: 64bit

# %%
import time
import tensorflow as tf
from tensorflow.python.ops.rnn_cell import BasicLSTMCell, MultiRNNCell, DropoutWrapper

from tensorflow.models.rnn.ptb import reader

# %% [markdown]
# Small Config 정보를 사용합니다.

# %%
class SmallConfig(object):
    """Small config."""
    init_scale = 0.1
    learning_rate = 1.0
    max_grad_norm = 5
    num_layers = 2
    num_steps = 20
    hidden_size = 200
    max_epoch = 4
    max_max_epoch = 13
    keep_prob = 1.0
    lr_decay = 0.5
    batch_size = 20
    vocab_size = 10000

# %% [markdown]
# 트레이닝과 테스트에 사용할 두개의 config 오브젝트를 만듭니다.

# %%
config = SmallConfig()
eval_config = SmallConfig()
eval_config.batch_size = 1
eval_config.num_steps = 1

# %% [markdown]
# PTB 모델을 만들어 주는 클래스를 작성합니다.

# %%
class PTBModel(object):
    """The PTB model."""

    def __init__(self, config, is_training=False):
        self.batch_size = config.batch_size
        self.num_steps = config.num_steps
        input_size = [config.batch_size, config.num_steps]
        self.input_data = tf.placeholder(tf.int32, input_size)
        self.targets = tf.placeholder(tf.int32, input_size)

        lstm_cell = BasicLSTMCell(config.hidden_size, forget_bias=0.0, state_is_tuple=True)
        # SmallConfig에서는 드롭아웃이 적용되지 않습니다.
        if is_training and config.keep_prob < 1:
            lstm_cell = DropoutWrapper(lstm_cell, config.keep_prob)
        # 두개의 계층을 가진 신경망 구조를 만듭니다.
        cell = MultiRNNCell([lstm_cell] * config.num_layers, state_is_tuple=True)

        self.initial_state = cell.zero_state(config.batch_size, tf.float32)

        with tf.device("/cpu:0"):
            embedding_size = [config.vocab_size, config.hidden_size]
            embedding = tf.get_variable("embedding", embedding_size)
            inputs = tf.nn.embedding_lookup(embedding, self.input_data)

        # SmallConfig에서는 드롭아웃이 적용되지 않습니다.
        if is_training and config.keep_prob < 1:
            inputs = tf.nn.dropout(inputs, config.keep_prob)

        # 각 배치마다 순서대로 데이터를 뽑아 셀에 입력합니다. 
        outputs = []
        state = self.initial_state
        with tf.variable_scope("RNN"):
            for time_step in range(config.num_steps):
                if time_step > 0: tf.get_variable_scope().reuse_variables()
                (cell_output, state) = cell(inputs[:, time_step, :], state)
                outputs.append(cell_output)

        # output의 크기를 20x20x200에서 400x200으로 변경합니다.
        output = tf.reshape(tf.concat(1, outputs), [-1, config.hidden_size])
        softmax_w_size = [config.hidden_size, config.vocab_size]
        softmax_w = tf.get_variable("softmax_w", softmax_w_size)
        softmax_b = tf.get_variable("softmax_b", [config.vocab_size])
        # logits의 크기는 400x10000이 됩니다.
        logits = tf.matmul(output, softmax_w) + softmax_b
    
        loss = tf.nn.seq2seq.sequence_loss_by_example(
            [logits],
            [tf.reshape(self.targets, [-1])],
            [tf.ones([config.batch_size * config.num_steps])])
        self.cost = tf.reduce_sum(loss) / config.batch_size
        self.final_state = state

        if not is_training:
            return

        self.lr = tf.Variable(0.0, trainable=False)
        tvars = tf.trainable_variables()
        # 기울기 클리핑을 수행합니다.
        grads, _ = tf.clip_by_global_norm(tf.gradients(self.cost, tvars),
                                          config.max_grad_norm)
        optimizer = tf.train.GradientDescentOptimizer(self.lr)
        self.train_op = optimizer.apply_gradients(zip(grads, tvars))

    def assign_lr(self, session, lr_value):
        session.run(tf.assign(self.lr, lr_value))

# %% [markdown]
# 에포크를 처리할 함수를 만듭니다.

# %%
def run_epoch(session, m, data, is_training=False):
    """Runs the model on the given data."""
    epoch_size = ((len(data) // m.batch_size) - 1) // m.num_steps
    start_time = time.time()
    costs = 0.0
    iters = 0
    
    eval_op = m.train_op if is_training else tf.no_op()
    
    # initial_state는 2x20x200 크기의 튜플입니다.
    state_list = []
    for c, h in m.initial_state:
        state_list.extend([c.eval(), h.eval()])
    
    ptb_iter = reader.ptb_iterator(data, m.batch_size, m.num_steps)
    for step, (x, y) in enumerate(ptb_iter):
        fetch_list = [m.cost]
        # final_state 튜플에 담겨있는 상태를 꺼내어 fetch_list에 담습니다. 
        for c, h in m.final_state:
            fetch_list.extend([c, h])
        fetch_list.append(eval_op)
        
        # 이전 스텝에서 구해진 state_list가 feed_dict로 주입됩니다.
        feed_dict = {m.input_data: x, m.targets: y}
        for i in range(len(m.initial_state)):
            c, h = m.initial_state[i]
            feed_dict[c], feed_dict[h] = state_list[i*2:(i+1)*2]
        
        # fetch_list에 담긴 final_state의 결과를 state_list로 전달 받습니다.
        cost, *state_list, _ = session.run(fetch_list, feed_dict)

        costs += cost
        iters += m.num_steps

        if is_training and step % (epoch_size // 10) == 10:
            print("%.3f perplexity: %.3f speed: %.0f wps" %
                    (step * 1.0 / epoch_size, np.exp(costs / iters),
                     iters * m.batch_size / (time.time() - start_time)))

    return np.exp(costs / iters)

# %%
raw_data = reader.ptb_raw_data('simple-examples/data')
train_data, valid_data, test_data, _ = raw_data

# %% [markdown]
# train_data, valid_data, test_data 는 단어를 숫자로 바꾼 리스트입니다.
# 가장 많이 나온 단어 순으로 0번 부터 시작하여 10000번 까지의 번호를 가지고 있습니다.

# %%
with tf.Graph().as_default(), tf.Session() as session:
    initializer = tf.random_uniform_initializer(-config.init_scale, config.init_scale)

    # 학습과 검증, 테스트를 위한 모델을 만듭니다.
    with tf.variable_scope("model", reuse=None, initializer=initializer):
        m = PTBModel(config, is_training=True)
    with tf.variable_scope("model", reuse=True, initializer=initializer):
        mvalid = PTBModel(config)
        mtest = PTBModel(eval_config)
        
    tf.initialize_all_variables().run()
    
    for i in range(config.max_max_epoch):
        # lr_decay는 반복속도를 조절해 주는 역할을 합니다.
        lr_decay = config.lr_decay ** max(i - config.max_epoch, 0.0)
        m.assign_lr(session, config.learning_rate * lr_decay)
        print("Epoch: %d Learning rate: %.3f" % (i + 1, session.run(m.lr)))
        
        perplexity = run_epoch(session, m, train_data, is_training=True)
        print("Epoch: %d Train Perplexity: %.3f" % (i + 1, perplexity))

        perplexity = run_epoch(session, mvalid, valid_data)
        print("Epoch: %d Valid Perplexity: %.3f" % (i + 1, perplexity))

    perplexity = run_epoch(session, mtest, test_data)
    print("Test Perplexity: %.3f" % perplexity)
# Out:
# Epoch: 1 Learning rate: 1.000
# 0.004 perplexity: 5498.754 speed: 1839 wps
# 0.104 perplexity: 846.351 speed: 1924 wps
# 0.204 perplexity: 626.172 speed: 1761 wps
# 0.304 perplexity: 504.910 speed: 1718 wps
# 0.404 perplexity: 434.432 speed: 1703 wps
# 0.504 perplexity: 388.965 speed: 1694 wps
# 0.604 perplexity: 349.839 speed: 1702 wps
# 0.703 perplexity: 323.081 speed: 1693 wps
# 0.803 perplexity: 301.858 speed: 1677 wps
# 0.903 perplexity: 282.476 speed: 1675 wps
# Epoch: 1 Train Perplexity: 267.951
# Epoch: 1 Valid Perplexity: 176.513
# Epoch: 2 Learning rate: 1.000
# 0.004 perplexity: 206.834 speed: 1879 wps
# 0.104 perplexity: 149.299 speed: 1829 wps
# 0.204 perplexity: 157.039 speed: 1841 wps
# 0.304 perplexity: 151.953 speed: 1796 wps
# 0.404 perplexity: 149.136 speed: 1785 wps
# 0.504 perplexity: 146.806 speed: 1775 wps
# 0.604 perplexity: 142.229 speed: 1785 wps
# 0.703 perplexity: 140.147 speed: 1788 wps
# 0.803 perplexity: 138.204 speed: 1788 wps
# 0.903 perplexity: 134.666 speed: 1790 wps
# Epoch: 2 Train Perplexity: 132.654
# Epoch: 2 Valid Perplexity: 141.675
# Epoch: 3 Learning rate: 1.000
# 0.004 perplexity: 143.142 speed: 1540 wps
# 0.104 perplexity: 104.811 speed: 1757 wps
# 0.204 perplexity: 114.063 speed: 1763 wps
# 0.304 perplexity: 111.026 speed: 1787 wps
# 0.404 perplexity: 110.029 speed: 1794 wps
# 0.504 perplexity: 109.265 speed: 1799 wps
# 0.604 perplexity: 106.750 speed: 1796 wps
# 0.703 perplexity: 106.159 speed: 1794 wps
# 0.803 perplexity: 105.559 speed: 1795 wps
# 0.903 perplexity: 103.415 speed: 1805 wps
# Epoch: 3 Train Perplexity: 102.491
# Epoch: 3 Valid Perplexity: 130.429
# Epoch: 4 Learning rate: 1.000
# 0.004 perplexity: 117.042 speed: 1899 wps
# 0.104 perplexity: 85.163 speed: 1876 wps
# 0.204 perplexity: 93.815 speed: 1874 wps
# 0.304 perplexity: 91.610 speed: 1874 wps
# 0.404 perplexity: 91.068 speed: 1873 wps
# 0.504 perplexity: 90.707 speed: 1872 wps
# 0.604 perplexity: 88.891 speed: 1870 wps
# 0.703 perplexity: 88.715 speed: 1870 wps
# 0.803 perplexity: 88.531 speed: 1869 wps
# 0.903 perplexity: 86.955 speed: 1867 wps
# Epoch: 4 Train Perplexity: 86.384
# Epoch: 4 Valid Perplexity: 127.803
# Epoch: 5 Learning rate: 1.000
# 0.004 perplexity: 100.718 speed: 1814 wps
# 0.104 perplexity: 73.960 speed: 1834 wps
# 0.204 perplexity: 81.756 speed: 1834 wps
# 0.304 perplexity: 79.880 speed: 1831 wps
# 0.404 perplexity: 79.622 speed: 1831 wps
# 0.504 perplexity: 79.462 speed: 1829 wps
# 0.604 perplexity: 78.033 speed: 1826 wps
# 0.703 perplexity: 78.034 speed: 1825 wps
# 0.803 perplexity: 78.019 speed: 1824 wps
# 0.903 perplexity: 76.732 speed: 1822 wps
# Epoch: 5 Train Perplexity: 76.385
# Epoch: 5 Valid Perplexity: 126.238
# Epoch: 6 Learning rate: 0.500
# 0.004 perplexity: 88.333 speed: 1810 wps
# 0.104 perplexity: 64.444 speed: 1807 wps
# 0.204 perplexity: 70.039 speed: 1807 wps
# 0.304 perplexity: 67.425 speed: 1806 wps
# 0.404 perplexity: 66.392 speed: 1805 wps
# 0.504 perplexity: 65.520 speed: 1805 wps
# 0.604 perplexity: 63.647 speed: 1805 wps
# 0.703 perplexity: 62.984 speed: 1804 wps
# 0.803 perplexity: 62.332 speed: 1804 wps
# 0.903 perplexity: 60.632 speed: 1804 wps
# Epoch: 6 Train Perplexity: 59.738
# Epoch: 6 Valid Perplexity: 120.027
# Epoch: 7 Learning rate: 0.250
# 0.004 perplexity: 73.110 speed: 1779 wps
# 0.104 perplexity: 53.641 speed: 1798 wps
# 0.204 perplexity: 58.465 speed: 1800 wps
# 0.304 perplexity: 56.097 speed: 1800 wps
# 0.404 perplexity: 55.142 speed: 1799 wps
# 0.504 perplexity: 54.330 speed: 1803 wps
# 0.604 perplexity: 52.653 speed: 1806 wps
# 0.703 perplexity: 51.978 speed: 1810 wps
# 0.803 perplexity: 51.266 speed: 1814 wps
# 0.903 perplexity: 49.696 speed: 1816 wps
# Epoch: 7 Train Perplexity: 48.796
# Epoch: 7 Valid Perplexity: 120.953
# Epoch: 8 Learning rate: 0.125
# 0.004 perplexity: 64.588 speed: 1829 wps
# 0.104 perplexity: 47.637 speed: 1833 wps
# 0.204 perplexity: 51.980 speed: 1833 wps
# 0.304 perplexity: 49.827 speed: 1835 wps
# 0.404 perplexity: 48.974 speed: 1836 wps
# 0.504 perplexity: 48.202 speed: 1835 wps
# 0.604 perplexity: 46.676 speed: 1836 wps
# 0.703 perplexity: 46.041 speed: 1836 wps
# 0.803 perplexity: 45.351 speed: 1835 wps
# 0.903 perplexity: 43.904 speed: 1836 wps
# Epoch: 8 Train Perplexity: 43.053
# Epoch: 8 Valid Perplexity: 122.697
# Epoch: 9 Learning rate: 0.062
# 0.004 perplexity: 60.569 speed: 1848 wps
# 0.104 perplexity: 44.602 speed: 1835 wps
# 0.204 perplexity: 48.721 speed: 1837 wps
# 0.304 perplexity: 46.685 speed: 1839 wps
# 0.404 perplexity: 45.873 speed: 1838 wps
# 0.504 perplexity: 45.136 speed: 1837 wps
# 0.604 perplexity: 43.676 speed: 1838 wps
# 0.703 perplexity: 43.057 speed: 1837 wps
# 0.803 perplexity: 42.380 speed: 1837 wps
# 0.903 perplexity: 40.993 speed: 1835 wps
# Epoch: 9 Train Perplexity: 40.170
# Epoch: 9 Valid Perplexity: 123.736
# Epoch: 10 Learning rate: 0.031
# 0.004 perplexity: 58.537 speed: 1859 wps
# 0.104 perplexity: 43.029 speed: 1840 wps
# 0.204 perplexity: 47.048 speed: 1839 wps
# 0.304 perplexity: 45.082 speed: 1840 wps
# 0.404 perplexity: 44.288 speed: 1840 wps
# 0.504 perplexity: 43.565 speed: 1839 wps
# 0.604 perplexity: 42.138 speed: 1839 wps
# 0.703 perplexity: 41.519 speed: 1840 wps
# 0.803 perplexity: 40.849 speed: 1840 wps
# 0.903 perplexity: 39.490 speed: 1841 wps
# Epoch: 10 Train Perplexity: 38.675
# Epoch: 10 Valid Perplexity: 124.115
# Epoch: 11 Learning rate: 0.016
# 0.004 perplexity: 57.334 speed: 1847 wps
# 0.104 perplexity: 42.134 speed: 1849 wps
# 0.204 perplexity: 46.114 speed: 1848 wps
# 0.304 perplexity: 44.200 speed: 1845 wps
# 0.404 perplexity: 43.435 speed: 1846 wps
# 0.504 perplexity: 42.723 speed: 1846 wps
# 0.604 perplexity: 41.315 speed: 1845 wps
# 0.703 perplexity: 40.694 speed: 1845 wps
# 0.803 perplexity: 40.021 speed: 1845 wps
# 0.903 perplexity: 38.678 speed: 1845 wps
# Epoch: 11 Train Perplexity: 37.867
# Epoch: 11 Valid Perplexity: 124.084
# Epoch: 12 Learning rate: 0.008
# 0.004 perplexity: 56.541 speed: 1844 wps
# 0.104 perplexity: 41.586 speed: 1846 wps
# 0.204 perplexity: 45.544 speed: 1844 wps
# 0.304 perplexity: 43.667 speed: 1845 wps
# 0.404 perplexity: 42.927 speed: 1845 wps
# 0.504 perplexity: 42.230 speed: 1845 wps
# 0.604 perplexity: 40.840 speed: 1845 wps
# 0.703 perplexity: 40.222 speed: 1845 wps
# 0.803 perplexity: 39.549 speed: 1845 wps
# 0.903 perplexity: 38.217 speed: 1845 wps
# Epoch: 12 Train Perplexity: 37.411
# Epoch: 12 Valid Perplexity: 123.806
# Epoch: 13 Learning rate: 0.004
# 0.004 perplexity: 56.084 speed: 1846 wps
# 0.104 perplexity: 41.269 speed: 1845 wps
# 0.204 perplexity: 45.206 speed: 1844 wps
# 0.304 perplexity: 43.354 speed: 1844 wps
# 0.404 perplexity: 42.630 speed: 1844 wps
# 0.504 perplexity: 41.943 speed: 1843 wps
# 0.604 perplexity: 40.569 speed: 1843 wps
# 0.703 perplexity: 39.954 speed: 1844 wps
# 0.803 perplexity: 39.284 speed: 1843 wps
# 0.903 perplexity: 37.960 speed: 1843 wps
# Epoch: 13 Train Perplexity: 37.158
# Epoch: 13 Valid Perplexity: 123.506
# Test Perplexity: 117.692
