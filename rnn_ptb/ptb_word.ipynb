# %%
# %pylab
# %matplotlib inline
# %load_ext watermark
# %watermark -v -m -p numpy,tensorflow
# Out:
# Using matplotlib backend: MacOSX
# Populating the interactive namespace from numpy and matplotlib
# CPython 3.5.2
# IPython 5.1.0
#
# numpy 1.12.1
# tensorflow 1.1.0
#
# compiler   : GCC 4.2.1 Compatible Apple LLVM 4.2 (clang-425.0.28)
# system     : Darwin
# release    : 16.5.0
# machine    : x86_64
# processor  : i386
# CPU cores  : 8
# interpreter: 64bit

# %%
import time
import tensorflow as tf
from tensorflow.contrib.rnn import BasicLSTMCell, MultiRNNCell, DropoutWrapper

import reader

# %% [markdown]
# Small Config 정보를 사용합니다.

# %%
class SmallConfig(object):
    """Small config."""
    init_scale = 0.1
    learning_rate = 1.0
    max_grad_norm = 5
    num_layers = 2
    num_steps = 20
    hidden_size = 200
    max_epoch = 4
    max_max_epoch = 13
    keep_prob = 1.0
    lr_decay = 0.5
    batch_size = 20
    vocab_size = 10000

# %% [markdown]
# 트레이닝과 테스트에 사용할 두개의 config 오브젝트를 만듭니다.

# %%
config = SmallConfig()
eval_config = SmallConfig()
eval_config.batch_size = 1
eval_config.num_steps = 1

# %% [markdown]
# PTB 모델을 만들어 주는 클래스를 작성합니다.

# %%
class PTBModel(object):
    """The PTB model."""

    def __init__(self, config, is_training=False):
        self.batch_size = config.batch_size
        self.num_steps = config.num_steps
        input_size = [config.batch_size, config.num_steps]
        self.input_data = tf.placeholder(tf.int32, input_size)
        self.targets = tf.placeholder(tf.int32, input_size)

        lstm_fn = lambda: BasicLSTMCell(config.hidden_size, forget_bias=0.0, state_is_tuple=True, 
                                        reuse=tf.get_variable_scope().reuse)
        # SmallConfig에서는 드롭아웃이 적용되지 않습니다.
        if is_training and config.keep_prob < 1:
            lstm_fn = lambda: DropoutWrapper(lstm_fn(), config.keep_prob)
        # 두개의 계층을 가진 신경망 구조를 만듭니다.
        cell = MultiRNNCell([lstm_fn() for _ in range(config.num_layers)], state_is_tuple=True)

        self.initial_state = cell.zero_state(config.batch_size, tf.float32)

        with tf.device("/cpu:0"):
            embedding_size = [config.vocab_size, config.hidden_size]
            embedding = tf.get_variable("embedding", embedding_size)
            inputs = tf.nn.embedding_lookup(embedding, self.input_data)

        # SmallConfig에서는 드롭아웃이 적용되지 않습니다.
        if is_training and config.keep_prob < 1:
            inputs = tf.nn.dropout(inputs, config.keep_prob)

        # 각 배치마다 순서대로 데이터를 뽑아 셀에 입력합니다. 
        outputs = []
        state = self.initial_state
        with tf.variable_scope("RNN"):
            for time_step in range(config.num_steps):
                if time_step > 0: tf.get_variable_scope().reuse_variables()
                (cell_output, state) = cell(inputs[:, time_step, :], state)
                outputs.append(cell_output)

        # output의 크기를 20x20x200에서 400x200으로 변경합니다.
        output = tf.reshape(tf.concat(outputs, 1), [-1, config.hidden_size])
        softmax_w_size = [config.hidden_size, config.vocab_size]
        softmax_w = tf.get_variable("softmax_w", softmax_w_size)
        softmax_b = tf.get_variable("softmax_b", [config.vocab_size])
        # logits의 크기는 400x10000이 됩니다.
        logits = tf.matmul(output, softmax_w) + softmax_b
    
        loss = tf.contrib.legacy_seq2seq.sequence_loss_by_example(
            [logits],
            [tf.reshape(self.targets, [-1])],
            [tf.ones([config.batch_size * config.num_steps])])
        self.cost = tf.reduce_sum(loss) / config.batch_size
        self.final_state = state

        if not is_training:
            return

        self.lr = tf.Variable(0.0, trainable=False)
        tvars = tf.trainable_variables()
        # 기울기 클리핑을 수행합니다.
        grads, _ = tf.clip_by_global_norm(tf.gradients(self.cost, tvars),
                                          config.max_grad_norm)
        optimizer = tf.train.GradientDescentOptimizer(self.lr)
        self.train_op = optimizer.apply_gradients(zip(grads, tvars))

    def assign_lr(self, session, lr_value):
        session.run(tf.assign(self.lr, lr_value))

# %% [markdown]
# 에포크를 처리할 함수를 만듭니다.

# %%
def run_epoch(session, m, data, is_training=False):
    """Runs the model on the given data."""
    epoch_size = ((len(data) // m.batch_size) - 1) // m.num_steps
    start_time = time.time()
    costs = 0.0
    iters = 0
    
    eval_op = m.train_op if is_training else tf.no_op()
    
    # initial_state는 2x20x200 크기의 튜플입니다.
    state_list = []
    for c, h in m.initial_state:
        state_list.extend([c.eval(), h.eval()])
    
    ptb_iter = reader.ptb_iterator(data, m.batch_size, m.num_steps)
    for step, (x, y) in enumerate(ptb_iter):
        fetch_list = [m.cost]
        # final_state 튜플에 담겨있는 상태를 꺼내어 fetch_list에 담습니다. 
        for c, h in m.final_state:
            fetch_list.extend([c, h])
        fetch_list.append(eval_op)
        
        # 이전 스텝에서 구해진 state_list가 feed_dict로 주입됩니다.
        feed_dict = {m.input_data: x, m.targets: y}
        for i in range(len(m.initial_state)):
            c, h = m.initial_state[i]
            feed_dict[c], feed_dict[h] = state_list[i*2:(i+1)*2]
        
        # fetch_list에 담긴 final_state의 결과를 state_list로 전달 받습니다.
        cost, *state_list, _ = session.run(fetch_list, feed_dict)

        costs += cost
        iters += m.num_steps

        if is_training and step % (epoch_size // 10) == 10:
            print("%.3f perplexity: %.3f speed: %.0f wps" %
                    (step * 1.0 / epoch_size, np.exp(costs / iters),
                     iters * m.batch_size / (time.time() - start_time)))

    return np.exp(costs / iters)

# %%
raw_data = reader.ptb_raw_data('simple-examples/data')
train_data, valid_data, test_data, _ = raw_data

# %% [markdown]
# train_data, valid_data, test_data 는 단어를 숫자로 바꾼 리스트입니다.
# 가장 많이 나온 단어 순으로 0번 부터 시작하여 10000번 까지의 번호를 가지고 있습니다.

# %%
with tf.Graph().as_default(), tf.Session() as session:
    initializer = tf.random_uniform_initializer(-config.init_scale, config.init_scale)

    # 학습과 검증, 테스트를 위한 모델을 만듭니다.
    with tf.variable_scope("model", reuse=None, initializer=initializer):
        m = PTBModel(config, is_training=True)
    with tf.variable_scope("model", reuse=True, initializer=initializer):
        mvalid = PTBModel(config)
        mtest = PTBModel(eval_config)
        
    tf.global_variables_initializer().run()
    
    for i in range(config.max_max_epoch):
        # lr_decay는 반복속도를 조절해 주는 역할을 합니다.
        lr_decay = config.lr_decay ** max(i - config.max_epoch, 0.0)
        m.assign_lr(session, config.learning_rate * lr_decay)
        print("Epoch: %d Learning rate: %.3f" % (i + 1, session.run(m.lr)))
        
        perplexity = run_epoch(session, m, train_data, is_training=True)
        print("Epoch: %d Train Perplexity: %.3f" % (i + 1, perplexity))

        perplexity = run_epoch(session, mvalid, valid_data)
        print("Epoch: %d Valid Perplexity: %.3f" % (i + 1, perplexity))

    perplexity = run_epoch(session, mtest, test_data)
    print("Test Perplexity: %.3f" % perplexity)
# Out:
# Epoch: 1 Learning rate: 1.000
# 0.004 perplexity: 5952.278 speed: 2161 wps
# 0.104 perplexity: 856.705 speed: 2193 wps
# 0.204 perplexity: 634.142 speed: 2143 wps
# 0.304 perplexity: 511.525 speed: 2096 wps
# 0.404 perplexity: 440.336 speed: 2090 wps
# 0.504 perplexity: 394.137 speed: 2105 wps
# 0.604 perplexity: 354.470 speed: 2115 wps
# 0.703 perplexity: 327.310 speed: 2123 wps
# 0.803 perplexity: 305.857 speed: 2127 wps
# 0.903 perplexity: 286.459 speed: 2130 wps
# Epoch: 1 Train Perplexity: 271.755
# Epoch: 1 Valid Perplexity: 179.848
# Epoch: 2 Learning rate: 1.000
# 0.004 perplexity: 212.886 speed: 2006 wps
# 0.104 perplexity: 152.280 speed: 2148 wps
# 0.204 perplexity: 159.714 speed: 2157 wps
# 0.304 perplexity: 154.555 speed: 2158 wps
# 0.404 perplexity: 151.511 speed: 2161 wps
# 0.504 perplexity: 148.941 speed: 2163 wps
# 0.604 perplexity: 144.259 speed: 2164 wps
# 0.703 perplexity: 142.120 speed: 2165 wps
# 0.803 perplexity: 140.048 speed: 2166 wps
# 0.903 perplexity: 136.373 speed: 2167 wps
# Epoch: 2 Train Perplexity: 134.288
# Epoch: 2 Valid Perplexity: 143.285
# Epoch: 3 Learning rate: 1.000
# 0.004 perplexity: 146.287 speed: 2106 wps
# 0.104 perplexity: 105.529 speed: 2173 wps
# 0.204 perplexity: 114.814 speed: 2167 wps
# 0.304 perplexity: 111.933 speed: 2143 wps
# 0.404 perplexity: 110.964 speed: 2137 wps
# 0.504 perplexity: 110.090 speed: 2144 wps
# 0.604 perplexity: 107.386 speed: 2148 wps
# 0.703 perplexity: 106.670 speed: 2152 wps
# 0.803 perplexity: 106.036 speed: 2155 wps
# 0.903 perplexity: 103.766 speed: 2157 wps
# Epoch: 3 Train Perplexity: 102.785
# Epoch: 3 Valid Perplexity: 130.966
# Epoch: 4 Learning rate: 1.000
# 0.004 perplexity: 115.609 speed: 2123 wps
# 0.104 perplexity: 85.167 speed: 2174 wps
# 0.204 perplexity: 93.859 speed: 2173 wps
# 0.304 perplexity: 91.723 speed: 2175 wps
# 0.404 perplexity: 91.319 speed: 2175 wps
# 0.504 perplexity: 90.945 speed: 2174 wps
# 0.604 perplexity: 89.040 speed: 2174 wps
# 0.703 perplexity: 88.809 speed: 2175 wps
# 0.803 perplexity: 88.589 speed: 2175 wps
# 0.903 perplexity: 86.908 speed: 2174 wps
# Epoch: 4 Train Perplexity: 86.328
# Epoch: 4 Valid Perplexity: 127.565
# Epoch: 5 Learning rate: 1.000
# 0.004 perplexity: 99.790 speed: 2102 wps
# 0.104 perplexity: 73.683 speed: 2169 wps
# 0.204 perplexity: 81.526 speed: 2177 wps
# 0.304 perplexity: 79.872 speed: 2171 wps
# 0.404 perplexity: 79.674 speed: 2172 wps
# 0.504 perplexity: 79.544 speed: 2173 wps
# 0.604 perplexity: 78.029 speed: 2171 wps
# 0.703 perplexity: 77.962 speed: 2171 wps
# 0.803 perplexity: 77.948 speed: 2169 wps
# 0.903 perplexity: 76.623 speed: 2157 wps
# Epoch: 5 Train Perplexity: 76.250
# Epoch: 5 Valid Perplexity: 127.961
# Epoch: 6 Learning rate: 0.500
# 0.004 perplexity: 88.747 speed: 2005 wps
# 0.104 perplexity: 64.283 speed: 2039 wps
# 0.204 perplexity: 69.874 speed: 2046 wps
# 0.304 perplexity: 67.270 speed: 2061 wps
# 0.404 perplexity: 66.350 speed: 2059 wps
# 0.504 perplexity: 65.503 speed: 2058 wps
# 0.604 perplexity: 63.606 speed: 2057 wps
# 0.703 perplexity: 62.894 speed: 2056 wps
# 0.803 perplexity: 62.205 speed: 2055 wps
# 0.903 perplexity: 60.469 speed: 2055 wps
# Epoch: 6 Train Perplexity: 59.561
# Epoch: 6 Valid Perplexity: 120.296
# Epoch: 7 Learning rate: 0.250
# 0.004 perplexity: 73.361 speed: 1994 wps
# 0.104 perplexity: 53.372 speed: 2044 wps
# 0.204 perplexity: 58.277 speed: 2045 wps
# 0.304 perplexity: 55.975 speed: 2053 wps
# 0.404 perplexity: 55.061 speed: 2056 wps
# 0.504 perplexity: 54.255 speed: 2057 wps
# 0.604 perplexity: 52.549 speed: 2059 wps
# 0.703 perplexity: 51.841 speed: 2059 wps
# 0.803 perplexity: 51.111 speed: 2060 wps
# 0.903 perplexity: 49.528 speed: 2060 wps
# Epoch: 7 Train Perplexity: 48.627
# Epoch: 7 Valid Perplexity: 120.443
# Epoch: 8 Learning rate: 0.125
# 0.004 perplexity: 64.898 speed: 2071 wps
# 0.104 perplexity: 47.324 speed: 2084 wps
# 0.204 perplexity: 51.834 speed: 2081 wps
# 0.304 perplexity: 49.791 speed: 2081 wps
# 0.404 perplexity: 48.915 speed: 2082 wps
# 0.504 perplexity: 48.177 speed: 2095 wps
# 0.604 perplexity: 46.620 speed: 2124 wps
# 0.703 perplexity: 45.949 speed: 2145 wps
# 0.803 perplexity: 45.244 speed: 2162 wps
# 0.903 perplexity: 43.770 speed: 2175 wps
# Epoch: 8 Train Perplexity: 42.909
# Epoch: 8 Valid Perplexity: 122.118
# Epoch: 9 Learning rate: 0.062
# 0.004 perplexity: 60.969 speed: 2229 wps
# 0.104 perplexity: 44.295 speed: 2273 wps
# 0.204 perplexity: 48.594 speed: 2277 wps
# 0.304 perplexity: 46.690 speed: 2278 wps
# 0.404 perplexity: 45.836 speed: 2281 wps
# 0.504 perplexity: 45.119 speed: 2284 wps
# 0.604 perplexity: 43.629 speed: 2285 wps
# 0.703 perplexity: 42.975 speed: 2279 wps
# 0.803 perplexity: 42.281 speed: 2281 wps
# 0.903 perplexity: 40.864 speed: 2282 wps
# Epoch: 9 Train Perplexity: 40.030
# Epoch: 9 Valid Perplexity: 123.083
# Epoch: 10 Learning rate: 0.031
# 0.004 perplexity: 58.880 speed: 2227 wps
# 0.104 perplexity: 42.739 speed: 2288 wps
# 0.204 perplexity: 46.896 speed: 2286 wps
# 0.304 perplexity: 45.086 speed: 2289 wps
# 0.404 perplexity: 44.259 speed: 2288 wps
# 0.504 perplexity: 43.556 speed: 2288 wps
# 0.604 perplexity: 42.097 speed: 2288 wps
# 0.703 perplexity: 41.450 speed: 2287 wps
# 0.803 perplexity: 40.755 speed: 2287 wps
# 0.903 perplexity: 39.367 speed: 2288 wps
# Epoch: 10 Train Perplexity: 38.548
# Epoch: 10 Valid Perplexity: 123.225
# Epoch: 11 Learning rate: 0.016
# 0.004 perplexity: 57.617 speed: 2215 wps
# 0.104 perplexity: 41.851 speed: 2279 wps
# 0.204 perplexity: 45.919 speed: 2282 wps
# 0.304 perplexity: 44.157 speed: 2285 wps
# 0.404 perplexity: 43.357 speed: 2287 wps
# 0.504 perplexity: 42.675 speed: 2287 wps
# 0.604 perplexity: 41.244 speed: 2287 wps
# 0.703 perplexity: 40.605 speed: 2287 wps
# 0.803 perplexity: 39.913 speed: 2288 wps
# 0.903 perplexity: 38.545 speed: 2288 wps
# Epoch: 11 Train Perplexity: 37.735
# Epoch: 11 Valid Perplexity: 122.969
# Epoch: 12 Learning rate: 0.008
# 0.004 perplexity: 56.853 speed: 2256 wps
# 0.104 perplexity: 41.319 speed: 2286 wps
# 0.204 perplexity: 45.342 speed: 2291 wps
# 0.304 perplexity: 43.605 speed: 2292 wps
# 0.404 perplexity: 42.826 speed: 2292 wps
# 0.504 perplexity: 42.159 speed: 2290 wps
# 0.604 perplexity: 40.750 speed: 2290 wps
# 0.703 perplexity: 40.118 speed: 2289 wps
# 0.803 perplexity: 39.434 speed: 2290 wps
# 0.903 perplexity: 38.079 speed: 2289 wps
# Epoch: 12 Train Perplexity: 37.275
# Epoch: 12 Valid Perplexity: 122.656
# Epoch: 13 Learning rate: 0.004
# 0.004 perplexity: 56.408 speed: 2175 wps
# 0.104 perplexity: 41.011 speed: 2270 wps
# 0.204 perplexity: 45.014 speed: 2282 wps
# 0.304 perplexity: 43.292 speed: 2285 wps
# 0.404 perplexity: 42.527 speed: 2289 wps
# 0.504 perplexity: 41.872 speed: 2291 wps
# 0.604 perplexity: 40.475 speed: 2291 wps
# 0.703 perplexity: 39.847 speed: 2292 wps
# 0.803 perplexity: 39.168 speed: 2293 wps
# 0.903 perplexity: 37.821 speed: 2292 wps
# Epoch: 13 Train Perplexity: 37.021
# Epoch: 13 Valid Perplexity: 122.427
# Test Perplexity: 116.516
