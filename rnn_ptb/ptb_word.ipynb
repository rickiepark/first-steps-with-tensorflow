# %%
# %pylab
# %matplotlib inline
# %load_ext watermark
# %watermark -v -m -p numpy,tensorflow
# Out:
# Using matplotlib backend: Qt5Agg
# Populating the interactive namespace from numpy and matplotlib
# CPython 3.5.5
# IPython 6.5.0
#
# numpy 1.14.5
# tensorflow 1.10.0
#
# compiler   : GCC 7.2.0
# system     : Linux
# release    : 4.15.0-30-generic
# machine    : x86_64
# processor  : x86_64
# CPU cores  : 4
# interpreter: 64bit

# %% [markdown]
# 텐서플로 1.7.0 버전에서부터는 샘플 데이터를 다운로드하는 기능이 제외될 예정이라는 경고가 발생합니다. 경고를 무시하기 위해 로깅 설정을 변경합니다.

# %%
import tensorflow as tf
tf.logging.set_verbosity(tf.logging.ERROR)

# %%
import time
import tensorflow as tf
from tensorflow.contrib.rnn import BasicLSTMCell, MultiRNNCell, DropoutWrapper

import reader

# %% [markdown]
# Small Config 정보를 사용합니다.

# %%
class SmallConfig(object):
    """Small config."""
    init_scale = 0.1
    learning_rate = 1.0
    max_grad_norm = 5
    num_layers = 2
    num_steps = 20
    hidden_size = 200
    max_epoch = 4
    max_max_epoch = 13
    keep_prob = 1.0
    lr_decay = 0.5
    batch_size = 20
    vocab_size = 10000

# %% [markdown]
# 트레이닝과 테스트에 사용할 두개의 config 오브젝트를 만듭니다.

# %%
config = SmallConfig()
eval_config = SmallConfig()
eval_config.batch_size = 1
eval_config.num_steps = 1

# %% [markdown]
# PTB 모델을 만들어 주는 클래스를 작성합니다.

# %%
class PTBModel(object):
    """The PTB model."""

    def __init__(self, config, is_training=False):
        self.batch_size = config.batch_size
        self.num_steps = config.num_steps
        input_size = [config.batch_size, config.num_steps]
        self.input_data = tf.placeholder(tf.int32, input_size)
        self.targets = tf.placeholder(tf.int32, input_size)

        lstm_fn = lambda: BasicLSTMCell(config.hidden_size, forget_bias=0.0, state_is_tuple=True, 
                                        reuse=tf.get_variable_scope().reuse)
        # SmallConfig에서는 드롭아웃이 적용되지 않습니다.
        if is_training and config.keep_prob < 1:
            lstm_fn = lambda: DropoutWrapper(lstm_fn(), config.keep_prob)
        # 두개의 계층을 가진 신경망 구조를 만듭니다.
        cell = MultiRNNCell([lstm_fn() for _ in range(config.num_layers)], state_is_tuple=True)

        self.initial_state = cell.zero_state(config.batch_size, tf.float32)

        with tf.device("/cpu:0"):
            embedding_size = [config.vocab_size, config.hidden_size]
            embedding = tf.get_variable("embedding", embedding_size)
            inputs = tf.nn.embedding_lookup(embedding, self.input_data)

        # SmallConfig에서는 드롭아웃이 적용되지 않습니다.
        if is_training and config.keep_prob < 1:
            inputs = tf.nn.dropout(inputs, config.keep_prob)

        # 각 배치마다 순서대로 데이터를 뽑아 셀에 입력합니다. 
        outputs = []
        state = self.initial_state
        with tf.variable_scope("RNN"):
            for time_step in range(config.num_steps):
                if time_step > 0: tf.get_variable_scope().reuse_variables()
                (cell_output, state) = cell(inputs[:, time_step, :], state)
                outputs.append(cell_output)

        # output의 크기를 20x20x200에서 400x200으로 변경합니다.
        output = tf.reshape(tf.concat(outputs, 1), [-1, config.hidden_size])
        softmax_w_size = [config.hidden_size, config.vocab_size]
        softmax_w = tf.get_variable("softmax_w", softmax_w_size)
        softmax_b = tf.get_variable("softmax_b", [config.vocab_size])
        # logits의 크기는 400x10000이 됩니다.
        logits = tf.matmul(output, softmax_w) + softmax_b
    
        loss = tf.contrib.legacy_seq2seq.sequence_loss_by_example(
            [logits],
            [tf.reshape(self.targets, [-1])],
            [tf.ones([config.batch_size * config.num_steps])])
        self.cost = tf.reduce_sum(loss) / config.batch_size
        self.final_state = state

        if not is_training:
            return

        self.lr = tf.Variable(0.0, trainable=False)
        tvars = tf.trainable_variables()
        # 기울기 클리핑을 수행합니다.
        grads, _ = tf.clip_by_global_norm(tf.gradients(self.cost, tvars),
                                          config.max_grad_norm)
        optimizer = tf.train.GradientDescentOptimizer(self.lr)
        self.train_op = optimizer.apply_gradients(zip(grads, tvars))

    def assign_lr(self, session, lr_value):
        session.run(tf.assign(self.lr, lr_value))

# %% [markdown]
# 에포크를 처리할 함수를 만듭니다.

# %%
def run_epoch(session, m, data, is_training=False):
    """Runs the model on the given data."""
    epoch_size = ((len(data) // m.batch_size) - 1) // m.num_steps
    start_time = time.time()
    costs = 0.0
    iters = 0
    
    eval_op = m.train_op if is_training else tf.no_op()
    
    # initial_state는 2x20x200 크기의 튜플입니다.
    state_list = []
    for c, h in m.initial_state:
        state_list.extend([c.eval(), h.eval()])
    
    ptb_iter = reader.ptb_iterator(data, m.batch_size, m.num_steps)
    for step, (x, y) in enumerate(ptb_iter):
        fetch_list = [m.cost]
        # final_state 튜플에 담겨있는 상태를 꺼내어 fetch_list에 담습니다. 
        for c, h in m.final_state:
            fetch_list.extend([c, h])
        fetch_list.append(eval_op)
        
        # 이전 스텝에서 구해진 state_list가 feed_dict로 주입됩니다.
        feed_dict = {m.input_data: x, m.targets: y}
        for i in range(len(m.initial_state)):
            c, h = m.initial_state[i]
            feed_dict[c], feed_dict[h] = state_list[i*2:(i+1)*2]
        
        # fetch_list에 담긴 final_state의 결과를 state_list로 전달 받습니다.
        cost, *state_list, _ = session.run(fetch_list, feed_dict)

        costs += cost
        iters += m.num_steps

        if is_training and step % (epoch_size // 10) == 10:
            print("%.3f perplexity: %.3f speed: %.0f wps" %
                    (step * 1.0 / epoch_size, np.exp(costs / iters),
                     iters * m.batch_size / (time.time() - start_time)))

    return np.exp(costs / iters)

# %%
raw_data = reader.ptb_raw_data('simple-examples/data')
train_data, valid_data, test_data, _ = raw_data

# %% [markdown]
# train_data, valid_data, test_data 는 단어를 숫자로 바꾼 리스트입니다.
# 가장 많이 나온 단어 순으로 0번 부터 시작하여 10000번 까지의 번호를 가지고 있습니다.

# %%
with tf.Graph().as_default(), tf.Session() as session:
    initializer = tf.random_uniform_initializer(-config.init_scale, config.init_scale)

    # 학습과 검증, 테스트를 위한 모델을 만듭니다.
    with tf.variable_scope("model", reuse=None, initializer=initializer):
        m = PTBModel(config, is_training=True)
    with tf.variable_scope("model", reuse=True, initializer=initializer):
        mvalid = PTBModel(config)
        mtest = PTBModel(eval_config)
        
    tf.global_variables_initializer().run()
    
    for i in range(config.max_max_epoch):
        # lr_decay는 반복속도를 조절해 주는 역할을 합니다.
        lr_decay = config.lr_decay ** max(i - config.max_epoch, 0.0)
        m.assign_lr(session, config.learning_rate * lr_decay)
        print("Epoch: %d Learning rate: %.3f" % (i + 1, session.run(m.lr)))
        
        perplexity = run_epoch(session, m, train_data, is_training=True)
        print("Epoch: %d Train Perplexity: %.3f" % (i + 1, perplexity))

        perplexity = run_epoch(session, mvalid, valid_data)
        print("Epoch: %d Valid Perplexity: %.3f" % (i + 1, perplexity))

    perplexity = run_epoch(session, mtest, test_data)
    print("Test Perplexity: %.3f" % perplexity)
# Out:
# Epoch: 1 Learning rate: 1.000
# 0.004 perplexity: 5234.107 speed: 10717 wps
# 0.104 perplexity: 827.404 speed: 32033 wps
# 0.204 perplexity: 619.214 speed: 33552 wps
# 0.304 perplexity: 500.958 speed: 33960 wps
# 0.404 perplexity: 431.900 speed: 34018 wps
# 0.504 perplexity: 386.710 speed: 34179 wps
# 0.604 perplexity: 348.351 speed: 34356 wps
# 0.703 perplexity: 322.107 speed: 34404 wps
# 0.803 perplexity: 301.414 speed: 34504 wps
# 0.903 perplexity: 282.166 speed: 34556 wps
# Epoch: 1 Train Perplexity: 267.937
# Epoch: 1 Valid Perplexity: 178.119
# Epoch: 2 Learning rate: 1.000
# 0.004 perplexity: 208.334 speed: 27694 wps
# 0.104 perplexity: 150.069 speed: 34143 wps
# 0.204 perplexity: 157.912 speed: 34793 wps
# 0.304 perplexity: 152.768 speed: 34767 wps
# 0.404 perplexity: 150.007 speed: 34689 wps
# 0.504 perplexity: 147.355 speed: 34695 wps
# 0.604 perplexity: 142.715 speed: 34787 wps
# 0.703 perplexity: 140.599 speed: 34747 wps
# 0.803 perplexity: 138.658 speed: 34793 wps
# 0.903 perplexity: 135.047 speed: 34788 wps
# Epoch: 2 Train Perplexity: 132.985
# Epoch: 2 Valid Perplexity: 142.507
# Epoch: 3 Learning rate: 1.000
# 0.004 perplexity: 142.214 speed: 27612 wps
# 0.104 perplexity: 104.814 speed: 34541 wps
# 0.204 perplexity: 114.026 speed: 34699 wps
# 0.304 perplexity: 111.049 speed: 35132 wps
# 0.404 perplexity: 110.222 speed: 35047 wps
# 0.504 perplexity: 109.224 speed: 35114 wps
# 0.604 perplexity: 106.587 speed: 35001 wps
# 0.703 perplexity: 105.948 speed: 35007 wps
# 0.803 perplexity: 105.374 speed: 35038 wps
# 0.903 perplexity: 103.171 speed: 34990 wps
# Epoch: 3 Train Perplexity: 102.139
# Epoch: 3 Valid Perplexity: 131.650
# Epoch: 4 Learning rate: 1.000
# 0.004 perplexity: 114.207 speed: 27376 wps
# 0.104 perplexity: 85.079 speed: 34012 wps
# 0.204 perplexity: 93.570 speed: 34592 wps
# 0.304 perplexity: 91.210 speed: 34861 wps
# 0.404 perplexity: 90.835 speed: 34768 wps
# 0.504 perplexity: 90.286 speed: 34831 wps
# 0.604 perplexity: 88.416 speed: 34871 wps
# 0.703 perplexity: 88.208 speed: 34925 wps
# 0.803 perplexity: 87.962 speed: 34882 wps
# 0.903 perplexity: 86.348 speed: 34859 wps
# Epoch: 4 Train Perplexity: 85.743
# Epoch: 4 Valid Perplexity: 127.257
# Epoch: 5 Learning rate: 1.000
# 0.004 perplexity: 97.605 speed: 27749 wps
# 0.104 perplexity: 73.521 speed: 33964 wps
# 0.204 perplexity: 81.095 speed: 34293 wps
# 0.304 perplexity: 79.233 speed: 34603 wps
# 0.404 perplexity: 79.097 speed: 34610 wps
# 0.504 perplexity: 78.818 speed: 34486 wps
# 0.604 perplexity: 77.361 speed: 34546 wps
# 0.703 perplexity: 77.376 speed: 34606 wps
# 0.803 perplexity: 77.397 speed: 34617 wps
# 0.903 perplexity: 76.136 speed: 34607 wps
# Epoch: 5 Train Perplexity: 75.741
# Epoch: 5 Valid Perplexity: 126.537
# Epoch: 6 Learning rate: 0.500
# 0.004 perplexity: 88.521 speed: 27606 wps
# 0.104 perplexity: 64.106 speed: 33716 wps
# 0.204 perplexity: 69.470 speed: 34509 wps
# 0.304 perplexity: 66.807 speed: 34686 wps
# 0.404 perplexity: 65.896 speed: 34755 wps
# 0.504 perplexity: 64.950 speed: 34807 wps
# 0.604 perplexity: 63.067 speed: 34836 wps
# 0.703 perplexity: 62.416 speed: 34857 wps
# 0.803 perplexity: 61.749 speed: 34853 wps
# 0.903 perplexity: 60.091 speed: 34838 wps
# Epoch: 6 Train Perplexity: 59.142
# Epoch: 6 Valid Perplexity: 120.244
# Epoch: 7 Learning rate: 0.250
# 0.004 perplexity: 70.738 speed: 27608 wps
# 0.104 perplexity: 53.023 speed: 33984 wps
# 0.204 perplexity: 57.623 speed: 34174 wps
# 0.304 perplexity: 55.333 speed: 34345 wps
# 0.404 perplexity: 54.465 speed: 34397 wps
# 0.504 perplexity: 53.607 speed: 34512 wps
# 0.604 perplexity: 51.952 speed: 34559 wps
# 0.703 perplexity: 51.301 speed: 34516 wps
# 0.803 perplexity: 50.609 speed: 34523 wps
# 0.903 perplexity: 49.096 speed: 34580 wps
# Epoch: 7 Train Perplexity: 48.149
# Epoch: 7 Valid Perplexity: 120.852
# Epoch: 8 Learning rate: 0.125
# 0.004 perplexity: 62.182 speed: 27567 wps
# 0.104 perplexity: 46.871 speed: 34293 wps
# 0.204 perplexity: 51.111 speed: 34428 wps
# 0.304 perplexity: 49.079 speed: 34373 wps
# 0.404 perplexity: 48.300 speed: 34372 wps
# 0.504 perplexity: 47.514 speed: 34426 wps
# 0.604 perplexity: 46.022 speed: 34506 wps
# 0.703 perplexity: 45.403 speed: 34547 wps
# 0.803 perplexity: 44.740 speed: 34518 wps
# 0.903 perplexity: 43.346 speed: 34574 wps
# Epoch: 8 Train Perplexity: 42.448
# Epoch: 8 Valid Perplexity: 122.273
# Epoch: 9 Learning rate: 0.062
# 0.004 perplexity: 58.221 speed: 27931 wps
# 0.104 perplexity: 43.816 speed: 34867 wps
# 0.204 perplexity: 47.864 speed: 34625 wps
# 0.304 perplexity: 45.956 speed: 34664 wps
# 0.404 perplexity: 45.222 speed: 34727 wps
# 0.504 perplexity: 44.480 speed: 34610 wps
# 0.604 perplexity: 43.057 speed: 34577 wps
# 0.703 perplexity: 42.454 speed: 34554 wps
# 0.803 perplexity: 41.804 speed: 34594 wps
# 0.903 perplexity: 40.469 speed: 34655 wps
# Epoch: 9 Train Perplexity: 39.605
# Epoch: 9 Valid Perplexity: 123.002
# Epoch: 10 Learning rate: 0.031
# 0.004 perplexity: 56.397 speed: 27323 wps
# 0.104 perplexity: 42.266 speed: 34453 wps
# 0.204 perplexity: 46.231 speed: 34615 wps
# 0.304 perplexity: 44.380 speed: 34780 wps
# 0.404 perplexity: 43.658 speed: 34781 wps
# 0.504 perplexity: 42.936 speed: 34800 wps
# 0.604 perplexity: 41.543 speed: 34833 wps
# 0.703 perplexity: 40.946 speed: 34852 wps
# 0.803 perplexity: 40.293 speed: 34874 wps
# 0.903 perplexity: 38.980 speed: 34923 wps
# Epoch: 10 Train Perplexity: 38.128
# Epoch: 10 Valid Perplexity: 123.115
# Epoch: 11 Learning rate: 0.016
# 0.004 perplexity: 55.291 speed: 27084 wps
# 0.104 perplexity: 41.352 speed: 33706 wps
# 0.204 perplexity: 45.292 speed: 34325 wps
# 0.304 perplexity: 43.492 speed: 34654 wps
# 0.404 perplexity: 42.780 speed: 34601 wps
# 0.504 perplexity: 42.072 speed: 34778 wps
# 0.604 perplexity: 40.706 speed: 34795 wps
# 0.703 perplexity: 40.118 speed: 34707 wps
# 0.803 perplexity: 39.466 speed: 34644 wps
# 0.903 perplexity: 38.165 speed: 34681 wps
# Epoch: 11 Train Perplexity: 37.319
# Epoch: 11 Valid Perplexity: 122.843
# Epoch: 12 Learning rate: 0.008
# 0.004 perplexity: 54.618 speed: 27611 wps
# 0.104 perplexity: 40.823 speed: 34098 wps
# 0.204 perplexity: 44.739 speed: 34325 wps
# 0.304 perplexity: 42.966 speed: 34456 wps
# 0.404 perplexity: 42.266 speed: 34682 wps
# 0.504 perplexity: 41.571 speed: 34720 wps
# 0.604 perplexity: 40.225 speed: 34753 wps
# 0.703 perplexity: 39.644 speed: 34746 wps
# 0.803 perplexity: 39.000 speed: 34771 wps
# 0.903 perplexity: 37.706 speed: 34756 wps
# Epoch: 12 Train Perplexity: 36.866
# Epoch: 12 Valid Perplexity: 122.497
# Epoch: 13 Learning rate: 0.004
# 0.004 perplexity: 54.250 speed: 27802 wps
# 0.104 perplexity: 40.532 speed: 34445 wps
# 0.204 perplexity: 44.436 speed: 34737 wps
# 0.304 perplexity: 42.674 speed: 34652 wps
# 0.404 perplexity: 41.982 speed: 34729 wps
# 0.504 perplexity: 41.294 speed: 34703 wps
# 0.604 perplexity: 39.960 speed: 34710 wps
# 0.703 perplexity: 39.382 speed: 34679 wps
# 0.803 perplexity: 38.742 speed: 34712 wps
# 0.903 perplexity: 37.455 speed: 34641 wps
# Epoch: 13 Train Perplexity: 36.619
# Epoch: 13 Valid Perplexity: 122.249
# Test Perplexity: 117.322
