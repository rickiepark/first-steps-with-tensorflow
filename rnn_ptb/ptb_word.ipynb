# %%
# %pylab
# %matplotlib inline
# %load_ext watermark
# %watermark -v -m -p numpy,tensorflow
# Out:
# Using matplotlib backend: MacOSX
# Populating the interactive namespace from numpy and matplotlib
# CPython 3.5.2
# IPython 5.1.0
#
# numpy 1.12.0
# tensorflow 1.0.0
#
# compiler   : GCC 4.2.1 Compatible Apple LLVM 4.2 (clang-425.0.28)
# system     : Darwin
# release    : 16.4.0
# machine    : x86_64
# processor  : i386
# CPU cores  : 8
# interpreter: 64bit

# %%
import time
import tensorflow as tf
from tensorflow.contrib.rnn import BasicLSTMCell, MultiRNNCell, DropoutWrapper

import reader

# %% [markdown]
# Small Config 정보를 사용합니다.

# %%
class SmallConfig(object):
    """Small config."""
    init_scale = 0.1
    learning_rate = 1.0
    max_grad_norm = 5
    num_layers = 2
    num_steps = 20
    hidden_size = 200
    max_epoch = 4
    max_max_epoch = 13
    keep_prob = 1.0
    lr_decay = 0.5
    batch_size = 20
    vocab_size = 10000

# %% [markdown]
# 트레이닝과 테스트에 사용할 두개의 config 오브젝트를 만듭니다.

# %%
config = SmallConfig()
eval_config = SmallConfig()
eval_config.batch_size = 1
eval_config.num_steps = 1

# %% [markdown]
# PTB 모델을 만들어 주는 클래스를 작성합니다.

# %%
class PTBModel(object):
    """The PTB model."""

    def __init__(self, config, is_training=False):
        self.batch_size = config.batch_size
        self.num_steps = config.num_steps
        input_size = [config.batch_size, config.num_steps]
        self.input_data = tf.placeholder(tf.int32, input_size)
        self.targets = tf.placeholder(tf.int32, input_size)

        lstm_cell = BasicLSTMCell(config.hidden_size, forget_bias=0.0, state_is_tuple=True)
        # SmallConfig에서는 드롭아웃이 적용되지 않습니다.
        if is_training and config.keep_prob < 1:
            lstm_cell = DropoutWrapper(lstm_cell, config.keep_prob)
        # 두개의 계층을 가진 신경망 구조를 만듭니다.
        cell = MultiRNNCell([lstm_cell] * config.num_layers, state_is_tuple=True)

        self.initial_state = cell.zero_state(config.batch_size, tf.float32)

        with tf.device("/cpu:0"):
            embedding_size = [config.vocab_size, config.hidden_size]
            embedding = tf.get_variable("embedding", embedding_size)
            inputs = tf.nn.embedding_lookup(embedding, self.input_data)

        # SmallConfig에서는 드롭아웃이 적용되지 않습니다.
        if is_training and config.keep_prob < 1:
            inputs = tf.nn.dropout(inputs, config.keep_prob)

        # 각 배치마다 순서대로 데이터를 뽑아 셀에 입력합니다. 
        outputs = []
        state = self.initial_state
        with tf.variable_scope("RNN"):
            for time_step in range(config.num_steps):
                if time_step > 0: tf.get_variable_scope().reuse_variables()
                (cell_output, state) = cell(inputs[:, time_step, :], state)
                outputs.append(cell_output)

        # output의 크기를 20x20x200에서 400x200으로 변경합니다.
        output = tf.reshape(tf.concat(outputs, 1), [-1, config.hidden_size])
        softmax_w_size = [config.hidden_size, config.vocab_size]
        softmax_w = tf.get_variable("softmax_w", softmax_w_size)
        softmax_b = tf.get_variable("softmax_b", [config.vocab_size])
        # logits의 크기는 400x10000이 됩니다.
        logits = tf.matmul(output, softmax_w) + softmax_b
    
        loss = tf.contrib.legacy_seq2seq.sequence_loss_by_example(
            [logits],
            [tf.reshape(self.targets, [-1])],
            [tf.ones([config.batch_size * config.num_steps])])
        self.cost = tf.reduce_sum(loss) / config.batch_size
        self.final_state = state

        if not is_training:
            return

        self.lr = tf.Variable(0.0, trainable=False)
        tvars = tf.trainable_variables()
        # 기울기 클리핑을 수행합니다.
        grads, _ = tf.clip_by_global_norm(tf.gradients(self.cost, tvars),
                                          config.max_grad_norm)
        optimizer = tf.train.GradientDescentOptimizer(self.lr)
        self.train_op = optimizer.apply_gradients(zip(grads, tvars))

    def assign_lr(self, session, lr_value):
        session.run(tf.assign(self.lr, lr_value))

# %% [markdown]
# 에포크를 처리할 함수를 만듭니다.

# %%
def run_epoch(session, m, data, is_training=False):
    """Runs the model on the given data."""
    epoch_size = ((len(data) // m.batch_size) - 1) // m.num_steps
    start_time = time.time()
    costs = 0.0
    iters = 0
    
    eval_op = m.train_op if is_training else tf.no_op()
    
    # initial_state는 2x20x200 크기의 튜플입니다.
    state_list = []
    for c, h in m.initial_state:
        state_list.extend([c.eval(), h.eval()])
    
    ptb_iter = reader.ptb_iterator(data, m.batch_size, m.num_steps)
    for step, (x, y) in enumerate(ptb_iter):
        fetch_list = [m.cost]
        # final_state 튜플에 담겨있는 상태를 꺼내어 fetch_list에 담습니다. 
        for c, h in m.final_state:
            fetch_list.extend([c, h])
        fetch_list.append(eval_op)
        
        # 이전 스텝에서 구해진 state_list가 feed_dict로 주입됩니다.
        feed_dict = {m.input_data: x, m.targets: y}
        for i in range(len(m.initial_state)):
            c, h = m.initial_state[i]
            feed_dict[c], feed_dict[h] = state_list[i*2:(i+1)*2]
        
        # fetch_list에 담긴 final_state의 결과를 state_list로 전달 받습니다.
        cost, *state_list, _ = session.run(fetch_list, feed_dict)

        costs += cost
        iters += m.num_steps

        if is_training and step % (epoch_size // 10) == 10:
            print("%.3f perplexity: %.3f speed: %.0f wps" %
                    (step * 1.0 / epoch_size, np.exp(costs / iters),
                     iters * m.batch_size / (time.time() - start_time)))

    return np.exp(costs / iters)

# %%
raw_data = reader.ptb_raw_data('simple-examples/data')
train_data, valid_data, test_data, _ = raw_data

# %% [markdown]
# train_data, valid_data, test_data 는 단어를 숫자로 바꾼 리스트입니다.
# 가장 많이 나온 단어 순으로 0번 부터 시작하여 10000번 까지의 번호를 가지고 있습니다.

# %%
with tf.Graph().as_default(), tf.Session() as session:
    initializer = tf.random_uniform_initializer(-config.init_scale, config.init_scale)

    # 학습과 검증, 테스트를 위한 모델을 만듭니다.
    with tf.variable_scope("model", reuse=None, initializer=initializer):
        m = PTBModel(config, is_training=True)
    with tf.variable_scope("model", reuse=True, initializer=initializer):
        mvalid = PTBModel(config)
        mtest = PTBModel(eval_config)
        
    tf.global_variables_initializer().run()
    
    for i in range(config.max_max_epoch):
        # lr_decay는 반복속도를 조절해 주는 역할을 합니다.
        lr_decay = config.lr_decay ** max(i - config.max_epoch, 0.0)
        m.assign_lr(session, config.learning_rate * lr_decay)
        print("Epoch: %d Learning rate: %.3f" % (i + 1, session.run(m.lr)))
        
        perplexity = run_epoch(session, m, train_data, is_training=True)
        print("Epoch: %d Train Perplexity: %.3f" % (i + 1, perplexity))

        perplexity = run_epoch(session, mvalid, valid_data)
        print("Epoch: %d Valid Perplexity: %.3f" % (i + 1, perplexity))

    perplexity = run_epoch(session, mtest, test_data)
    print("Test Perplexity: %.3f" % perplexity)
# Out:
# Epoch: 1 Learning rate: 1.000
# 0.004 perplexity: 5109.731 speed: 1078 wps
# 0.104 perplexity: 834.548 speed: 1179 wps
# 0.204 perplexity: 616.517 speed: 1197 wps
# 0.304 perplexity: 498.571 speed: 1203 wps
# 0.404 perplexity: 430.891 speed: 1207 wps
# 0.504 perplexity: 386.814 speed: 1209 wps
# 0.604 perplexity: 349.060 speed: 1210 wps
# 0.703 perplexity: 322.870 speed: 1211 wps
# 0.803 perplexity: 302.130 speed: 1211 wps
# 0.903 perplexity: 283.105 speed: 1211 wps
# Epoch: 1 Train Perplexity: 268.795
# Epoch: 1 Valid Perplexity: 180.063
# Epoch: 2 Learning rate: 1.000
# 0.004 perplexity: 210.382 speed: 1186 wps
# 0.104 perplexity: 151.746 speed: 1213 wps
# 0.204 perplexity: 158.939 speed: 1215 wps
# 0.304 perplexity: 153.962 speed: 1214 wps
# 0.404 perplexity: 151.041 speed: 1216 wps
# 0.504 perplexity: 148.506 speed: 1215 wps
# 0.604 perplexity: 143.831 speed: 1214 wps
# 0.703 perplexity: 141.613 speed: 1213 wps
# 0.803 perplexity: 139.625 speed: 1212 wps
# 0.903 perplexity: 135.985 speed: 1212 wps
# Epoch: 2 Train Perplexity: 133.959
# Epoch: 2 Valid Perplexity: 145.107
# Epoch: 3 Learning rate: 1.000
# 0.004 perplexity: 146.653 speed: 1208 wps
# 0.104 perplexity: 106.082 speed: 1209 wps
# 0.204 perplexity: 115.074 speed: 1212 wps
# 0.304 perplexity: 112.107 speed: 1209 wps
# 0.404 perplexity: 111.219 speed: 1211 wps
# 0.504 perplexity: 110.287 speed: 1211 wps
# 0.604 perplexity: 107.635 speed: 1212 wps
# 0.703 perplexity: 106.881 speed: 1212 wps
# 0.803 perplexity: 106.211 speed: 1212 wps
# 0.903 perplexity: 103.964 speed: 1210 wps
# Epoch: 3 Train Perplexity: 103.009
# Epoch: 3 Valid Perplexity: 133.441
# Epoch: 4 Learning rate: 1.000
# 0.004 perplexity: 117.475 speed: 2050 wps
# 0.104 perplexity: 86.019 speed: 2091 wps
# 0.204 perplexity: 94.341 speed: 2098 wps
# 0.304 perplexity: 92.239 speed: 2102 wps
# 0.404 perplexity: 91.801 speed: 2103 wps
# 0.504 perplexity: 91.339 speed: 2103 wps
# 0.604 perplexity: 89.429 speed: 2103 wps
# 0.703 perplexity: 89.120 speed: 2105 wps
# 0.803 perplexity: 88.857 speed: 2105 wps
# 0.903 perplexity: 87.198 speed: 2105 wps
# Epoch: 4 Train Perplexity: 86.585
# Epoch: 4 Valid Perplexity: 128.453
# Epoch: 5 Learning rate: 1.000
# 0.004 perplexity: 99.487 speed: 2053 wps
# 0.104 perplexity: 73.884 speed: 2106 wps
# 0.204 perplexity: 81.714 speed: 2105 wps
# 0.304 perplexity: 79.961 speed: 2107 wps
# 0.404 perplexity: 79.710 speed: 2106 wps
# 0.504 perplexity: 79.470 speed: 2105 wps
# 0.604 perplexity: 78.013 speed: 2105 wps
# 0.703 perplexity: 77.941 speed: 2106 wps
# 0.803 perplexity: 77.913 speed: 2106 wps
# 0.903 perplexity: 76.614 speed: 2107 wps
# Epoch: 5 Train Perplexity: 76.259
# Epoch: 5 Valid Perplexity: 126.837
# Epoch: 6 Learning rate: 0.500
# 0.004 perplexity: 89.501 speed: 2067 wps
# 0.104 perplexity: 64.290 speed: 2105 wps
# 0.204 perplexity: 69.819 speed: 2109 wps
# 0.304 perplexity: 67.253 speed: 2108 wps
# 0.404 perplexity: 66.262 speed: 2109 wps
# 0.504 perplexity: 65.299 speed: 2109 wps
# 0.604 perplexity: 63.450 speed: 2110 wps
# 0.703 perplexity: 62.732 speed: 2110 wps
# 0.803 perplexity: 62.032 speed: 2110 wps
# 0.903 perplexity: 60.351 speed: 2111 wps
# Epoch: 6 Train Perplexity: 59.451
# Epoch: 6 Valid Perplexity: 120.108
# Epoch: 7 Learning rate: 0.250
# 0.004 perplexity: 72.871 speed: 2076 wps
# 0.104 perplexity: 53.231 speed: 2101 wps
# 0.204 perplexity: 58.055 speed: 2104 wps
# 0.304 perplexity: 55.765 speed: 2105 wps
# 0.404 perplexity: 54.914 speed: 2107 wps
# 0.504 perplexity: 53.982 speed: 2109 wps
# 0.604 perplexity: 52.299 speed: 2107 wps
# 0.703 perplexity: 51.617 speed: 2108 wps
# 0.803 perplexity: 50.896 speed: 2108 wps
# 0.903 perplexity: 49.338 speed: 2108 wps
# Epoch: 7 Train Perplexity: 48.436
# Epoch: 7 Valid Perplexity: 120.944
# Epoch: 8 Learning rate: 0.125
# 0.004 perplexity: 64.768 speed: 2077 wps
# 0.104 perplexity: 47.223 speed: 2099 wps
# 0.204 perplexity: 51.563 speed: 2099 wps
# 0.304 perplexity: 49.489 speed: 2099 wps
# 0.404 perplexity: 48.737 speed: 2102 wps
# 0.504 perplexity: 47.869 speed: 2103 wps
# 0.604 perplexity: 46.336 speed: 2097 wps
# 0.703 perplexity: 45.704 speed: 2098 wps
# 0.803 perplexity: 45.011 speed: 2099 wps
# 0.903 perplexity: 43.563 speed: 2100 wps
# Epoch: 8 Train Perplexity: 42.694
# Epoch: 8 Valid Perplexity: 122.145
# Epoch: 9 Learning rate: 0.062
# 0.004 perplexity: 60.295 speed: 2051 wps
# 0.104 perplexity: 44.211 speed: 2098 wps
# 0.204 perplexity: 48.302 speed: 2103 wps
# 0.304 perplexity: 46.339 speed: 2104 wps
# 0.404 perplexity: 45.611 speed: 2104 wps
# 0.504 perplexity: 44.800 speed: 2103 wps
# 0.604 perplexity: 43.336 speed: 2104 wps
# 0.703 perplexity: 42.729 speed: 2100 wps
# 0.803 perplexity: 42.049 speed: 2101 wps
# 0.903 perplexity: 40.661 speed: 2101 wps
# Epoch: 9 Train Perplexity: 39.825
# Epoch: 9 Valid Perplexity: 122.698
# Epoch: 10 Learning rate: 0.031
# 0.004 perplexity: 58.056 speed: 2064 wps
# 0.104 perplexity: 42.596 speed: 2103 wps
# 0.204 perplexity: 46.563 speed: 2107 wps
# 0.304 perplexity: 44.669 speed: 2104 wps
# 0.404 perplexity: 43.974 speed: 2104 wps
# 0.504 perplexity: 43.204 speed: 2105 wps
# 0.604 perplexity: 41.783 speed: 2104 wps
# 0.703 perplexity: 41.182 speed: 2104 wps
# 0.803 perplexity: 40.511 speed: 2104 wps
# 0.903 perplexity: 39.152 speed: 2104 wps
# Epoch: 10 Train Perplexity: 38.332
# Epoch: 10 Valid Perplexity: 122.737
# Epoch: 11 Learning rate: 0.016
# 0.004 perplexity: 56.844 speed: 2075 wps
# 0.104 perplexity: 41.672 speed: 2100 wps
# 0.204 perplexity: 45.567 speed: 2102 wps
# 0.304 perplexity: 43.713 speed: 2103 wps
# 0.404 perplexity: 43.043 speed: 2103 wps
# 0.504 perplexity: 42.300 speed: 2102 wps
# 0.604 perplexity: 40.911 speed: 2103 wps
# 0.703 perplexity: 40.316 speed: 2104 wps
# 0.803 perplexity: 39.653 speed: 2105 wps
# 0.903 perplexity: 38.310 speed: 2105 wps
# Epoch: 11 Train Perplexity: 37.500
# Epoch: 11 Valid Perplexity: 122.639
# Epoch: 12 Learning rate: 0.008
# 0.004 perplexity: 56.143 speed: 2106 wps
# 0.104 perplexity: 41.147 speed: 2105 wps
# 0.204 perplexity: 45.003 speed: 2104 wps
# 0.304 perplexity: 43.169 speed: 2104 wps
# 0.404 perplexity: 42.512 speed: 2104 wps
# 0.504 perplexity: 41.784 speed: 2103 wps
# 0.604 perplexity: 40.416 speed: 2102 wps
# 0.703 perplexity: 39.827 speed: 2102 wps
# 0.803 perplexity: 39.169 speed: 2102 wps
# 0.903 perplexity: 37.837 speed: 2102 wps
# Epoch: 12 Train Perplexity: 37.032
# Epoch: 12 Valid Perplexity: 122.459
# Epoch: 13 Learning rate: 0.004
# 0.004 perplexity: 55.725 speed: 2079 wps
# 0.104 perplexity: 40.854 speed: 2100 wps
# 0.204 perplexity: 44.700 speed: 2101 wps
# 0.304 perplexity: 42.877 speed: 2102 wps
# 0.404 perplexity: 42.222 speed: 2104 wps
# 0.504 perplexity: 41.501 speed: 2104 wps
# 0.604 perplexity: 40.144 speed: 2105 wps
# 0.703 perplexity: 39.558 speed: 2106 wps
# 0.803 perplexity: 38.903 speed: 2105 wps
# 0.903 perplexity: 37.578 speed: 2105 wps
# Epoch: 13 Train Perplexity: 36.778
# Epoch: 13 Valid Perplexity: 122.255
# Test Perplexity: 118.392
