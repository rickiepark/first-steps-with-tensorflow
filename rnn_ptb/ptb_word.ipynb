# %%
# %pylab
# %matplotlib inline
# %load_ext watermark
# %watermark -v -m -p numpy,tensorflow
# Out:
# Using matplotlib backend: Qt5Agg
# Populating the interactive namespace from numpy and matplotlib
# CPython 3.5.5
# IPython 6.3.1
#
# numpy 1.14.2
# tensorflow 1.8.0
#
# compiler   : GCC 7.2.0
# system     : Linux
# release    : 4.13.0-39-generic
# machine    : x86_64
# processor  : x86_64
# CPU cores  : 4
# interpreter: 64bit

# %% [markdown]
# 텐서플로 1.7.0 버전에서부터는 샘플 데이터를 다운로드하는 기능이 제외될 예정이라는 경고가 발생합니다. 경고를 무시하기 위해 로깅 설정을 변경합니다.

# %%
import tensorflow as tf
tf.logging.set_verbosity(tf.logging.ERROR)

# %%
import time
import tensorflow as tf
from tensorflow.contrib.rnn import BasicLSTMCell, MultiRNNCell, DropoutWrapper

import reader

# %% [markdown]
# Small Config 정보를 사용합니다.

# %%
class SmallConfig(object):
    """Small config."""
    init_scale = 0.1
    learning_rate = 1.0
    max_grad_norm = 5
    num_layers = 2
    num_steps = 20
    hidden_size = 200
    max_epoch = 4
    max_max_epoch = 13
    keep_prob = 1.0
    lr_decay = 0.5
    batch_size = 20
    vocab_size = 10000

# %% [markdown]
# 트레이닝과 테스트에 사용할 두개의 config 오브젝트를 만듭니다.

# %%
config = SmallConfig()
eval_config = SmallConfig()
eval_config.batch_size = 1
eval_config.num_steps = 1

# %% [markdown]
# PTB 모델을 만들어 주는 클래스를 작성합니다.

# %%
class PTBModel(object):
    """The PTB model."""

    def __init__(self, config, is_training=False):
        self.batch_size = config.batch_size
        self.num_steps = config.num_steps
        input_size = [config.batch_size, config.num_steps]
        self.input_data = tf.placeholder(tf.int32, input_size)
        self.targets = tf.placeholder(tf.int32, input_size)

        lstm_fn = lambda: BasicLSTMCell(config.hidden_size, forget_bias=0.0, state_is_tuple=True, 
                                        reuse=tf.get_variable_scope().reuse)
        # SmallConfig에서는 드롭아웃이 적용되지 않습니다.
        if is_training and config.keep_prob < 1:
            lstm_fn = lambda: DropoutWrapper(lstm_fn(), config.keep_prob)
        # 두개의 계층을 가진 신경망 구조를 만듭니다.
        cell = MultiRNNCell([lstm_fn() for _ in range(config.num_layers)], state_is_tuple=True)

        self.initial_state = cell.zero_state(config.batch_size, tf.float32)

        with tf.device("/cpu:0"):
            embedding_size = [config.vocab_size, config.hidden_size]
            embedding = tf.get_variable("embedding", embedding_size)
            inputs = tf.nn.embedding_lookup(embedding, self.input_data)

        # SmallConfig에서는 드롭아웃이 적용되지 않습니다.
        if is_training and config.keep_prob < 1:
            inputs = tf.nn.dropout(inputs, config.keep_prob)

        # 각 배치마다 순서대로 데이터를 뽑아 셀에 입력합니다. 
        outputs = []
        state = self.initial_state
        with tf.variable_scope("RNN"):
            for time_step in range(config.num_steps):
                if time_step > 0: tf.get_variable_scope().reuse_variables()
                (cell_output, state) = cell(inputs[:, time_step, :], state)
                outputs.append(cell_output)

        # output의 크기를 20x20x200에서 400x200으로 변경합니다.
        output = tf.reshape(tf.concat(outputs, 1), [-1, config.hidden_size])
        softmax_w_size = [config.hidden_size, config.vocab_size]
        softmax_w = tf.get_variable("softmax_w", softmax_w_size)
        softmax_b = tf.get_variable("softmax_b", [config.vocab_size])
        # logits의 크기는 400x10000이 됩니다.
        logits = tf.matmul(output, softmax_w) + softmax_b
    
        loss = tf.contrib.legacy_seq2seq.sequence_loss_by_example(
            [logits],
            [tf.reshape(self.targets, [-1])],
            [tf.ones([config.batch_size * config.num_steps])])
        self.cost = tf.reduce_sum(loss) / config.batch_size
        self.final_state = state

        if not is_training:
            return

        self.lr = tf.Variable(0.0, trainable=False)
        tvars = tf.trainable_variables()
        # 기울기 클리핑을 수행합니다.
        grads, _ = tf.clip_by_global_norm(tf.gradients(self.cost, tvars),
                                          config.max_grad_norm)
        optimizer = tf.train.GradientDescentOptimizer(self.lr)
        self.train_op = optimizer.apply_gradients(zip(grads, tvars))

    def assign_lr(self, session, lr_value):
        session.run(tf.assign(self.lr, lr_value))

# %% [markdown]
# 에포크를 처리할 함수를 만듭니다.

# %%
def run_epoch(session, m, data, is_training=False):
    """Runs the model on the given data."""
    epoch_size = ((len(data) // m.batch_size) - 1) // m.num_steps
    start_time = time.time()
    costs = 0.0
    iters = 0
    
    eval_op = m.train_op if is_training else tf.no_op()
    
    # initial_state는 2x20x200 크기의 튜플입니다.
    state_list = []
    for c, h in m.initial_state:
        state_list.extend([c.eval(), h.eval()])
    
    ptb_iter = reader.ptb_iterator(data, m.batch_size, m.num_steps)
    for step, (x, y) in enumerate(ptb_iter):
        fetch_list = [m.cost]
        # final_state 튜플에 담겨있는 상태를 꺼내어 fetch_list에 담습니다. 
        for c, h in m.final_state:
            fetch_list.extend([c, h])
        fetch_list.append(eval_op)
        
        # 이전 스텝에서 구해진 state_list가 feed_dict로 주입됩니다.
        feed_dict = {m.input_data: x, m.targets: y}
        for i in range(len(m.initial_state)):
            c, h = m.initial_state[i]
            feed_dict[c], feed_dict[h] = state_list[i*2:(i+1)*2]
        
        # fetch_list에 담긴 final_state의 결과를 state_list로 전달 받습니다.
        cost, *state_list, _ = session.run(fetch_list, feed_dict)

        costs += cost
        iters += m.num_steps

        if is_training and step % (epoch_size // 10) == 10:
            print("%.3f perplexity: %.3f speed: %.0f wps" %
                    (step * 1.0 / epoch_size, np.exp(costs / iters),
                     iters * m.batch_size / (time.time() - start_time)))

    return np.exp(costs / iters)

# %%
raw_data = reader.ptb_raw_data('simple-examples/data')
train_data, valid_data, test_data, _ = raw_data

# %% [markdown]
# train_data, valid_data, test_data 는 단어를 숫자로 바꾼 리스트입니다.
# 가장 많이 나온 단어 순으로 0번 부터 시작하여 10000번 까지의 번호를 가지고 있습니다.

# %%
with tf.Graph().as_default(), tf.Session() as session:
    initializer = tf.random_uniform_initializer(-config.init_scale, config.init_scale)

    # 학습과 검증, 테스트를 위한 모델을 만듭니다.
    with tf.variable_scope("model", reuse=None, initializer=initializer):
        m = PTBModel(config, is_training=True)
    with tf.variable_scope("model", reuse=True, initializer=initializer):
        mvalid = PTBModel(config)
        mtest = PTBModel(eval_config)
        
    tf.global_variables_initializer().run()
    
    for i in range(config.max_max_epoch):
        # lr_decay는 반복속도를 조절해 주는 역할을 합니다.
        lr_decay = config.lr_decay ** max(i - config.max_epoch, 0.0)
        m.assign_lr(session, config.learning_rate * lr_decay)
        print("Epoch: %d Learning rate: %.3f" % (i + 1, session.run(m.lr)))
        
        perplexity = run_epoch(session, m, train_data, is_training=True)
        print("Epoch: %d Train Perplexity: %.3f" % (i + 1, perplexity))

        perplexity = run_epoch(session, mvalid, valid_data)
        print("Epoch: %d Valid Perplexity: %.3f" % (i + 1, perplexity))

    perplexity = run_epoch(session, mtest, test_data)
    print("Test Perplexity: %.3f" % perplexity)
# Out:
# Epoch: 1 Learning rate: 1.000
# 0.004 perplexity: 6931.951 speed: 10401 wps
# 0.104 perplexity: 856.751 speed: 32077 wps
# 0.204 perplexity: 628.651 speed: 33628 wps
# 0.304 perplexity: 506.739 speed: 34173 wps
# 0.404 perplexity: 436.762 speed: 34300 wps
# 0.504 perplexity: 391.105 speed: 34520 wps
# 0.604 perplexity: 352.186 speed: 34550 wps
# 0.703 perplexity: 325.526 speed: 34683 wps
# 0.803 perplexity: 304.395 speed: 34770 wps
# 0.903 perplexity: 285.138 speed: 34811 wps
# Epoch: 1 Train Perplexity: 270.685
# Epoch: 1 Valid Perplexity: 178.972
# Epoch: 2 Learning rate: 1.000
# 0.004 perplexity: 211.834 speed: 27678 wps
# 0.104 perplexity: 152.275 speed: 34456 wps
# 0.204 perplexity: 159.916 speed: 34882 wps
# 0.304 perplexity: 154.797 speed: 34882 wps
# 0.404 perplexity: 151.882 speed: 34994 wps
# 0.504 perplexity: 149.418 speed: 34952 wps
# 0.604 perplexity: 144.610 speed: 34997 wps
# 0.703 perplexity: 142.518 speed: 34959 wps
# 0.803 perplexity: 140.492 speed: 34980 wps
# 0.903 perplexity: 136.822 speed: 34962 wps
# Epoch: 2 Train Perplexity: 134.724
# Epoch: 2 Valid Perplexity: 143.620
# Epoch: 3 Learning rate: 1.000
# 0.004 perplexity: 145.712 speed: 27434 wps
# 0.104 perplexity: 106.538 speed: 34675 wps
# 0.204 perplexity: 115.711 speed: 34964 wps
# 0.304 perplexity: 112.803 speed: 34936 wps
# 0.404 perplexity: 111.755 speed: 35114 wps
# 0.504 perplexity: 110.713 speed: 35094 wps
# 0.604 perplexity: 108.030 speed: 35011 wps
# 0.703 perplexity: 107.386 speed: 35012 wps
# 0.803 perplexity: 106.753 speed: 34896 wps
# 0.903 perplexity: 104.456 speed: 34839 wps
# Epoch: 3 Train Perplexity: 103.496
# Epoch: 3 Valid Perplexity: 132.930
# Epoch: 4 Learning rate: 1.000
# 0.004 perplexity: 117.042 speed: 27777 wps
# 0.104 perplexity: 86.299 speed: 35317 wps
# 0.204 perplexity: 94.840 speed: 35427 wps
# 0.304 perplexity: 92.655 speed: 35236 wps
# 0.404 perplexity: 92.110 speed: 35216 wps
# 0.504 perplexity: 91.573 speed: 35143 wps
# 0.604 perplexity: 89.646 speed: 35100 wps
# 0.703 perplexity: 89.444 speed: 35089 wps
# 0.803 perplexity: 89.183 speed: 35102 wps
# 0.903 perplexity: 87.534 speed: 35141 wps
# Epoch: 4 Train Perplexity: 86.972
# Epoch: 4 Valid Perplexity: 128.916
# Epoch: 5 Learning rate: 1.000
# 0.004 perplexity: 100.507 speed: 27096 wps
# 0.104 perplexity: 74.360 speed: 33930 wps
# 0.204 perplexity: 81.928 speed: 34226 wps
# 0.304 perplexity: 80.110 speed: 34321 wps
# 0.404 perplexity: 79.882 speed: 34480 wps
# 0.504 perplexity: 79.706 speed: 34562 wps
# 0.604 perplexity: 78.283 speed: 34640 wps
# 0.703 perplexity: 78.266 speed: 34691 wps
# 0.803 perplexity: 78.191 speed: 34698 wps
# 0.903 perplexity: 76.920 speed: 34761 wps
# Epoch: 5 Train Perplexity: 76.579
# Epoch: 5 Valid Perplexity: 127.341
# Epoch: 6 Learning rate: 0.500
# 0.004 perplexity: 88.803 speed: 27721 wps
# 0.104 perplexity: 64.957 speed: 34328 wps
# 0.204 perplexity: 70.346 speed: 34683 wps
# 0.304 perplexity: 67.766 speed: 34833 wps
# 0.404 perplexity: 66.633 speed: 34831 wps
# 0.504 perplexity: 65.688 speed: 34801 wps
# 0.604 perplexity: 63.778 speed: 34795 wps
# 0.703 perplexity: 63.090 speed: 34843 wps
# 0.803 perplexity: 62.352 speed: 34793 wps
# 0.903 perplexity: 60.703 speed: 34819 wps
# Epoch: 6 Train Perplexity: 59.810
# Epoch: 6 Valid Perplexity: 120.543
# Epoch: 7 Learning rate: 0.250
# 0.004 perplexity: 73.210 speed: 27813 wps
# 0.104 perplexity: 53.689 speed: 34225 wps
# 0.204 perplexity: 58.397 speed: 34475 wps
# 0.304 perplexity: 56.121 speed: 34698 wps
# 0.404 perplexity: 55.145 speed: 34642 wps
# 0.504 perplexity: 54.237 speed: 34749 wps
# 0.604 perplexity: 52.533 speed: 34723 wps
# 0.703 perplexity: 51.850 speed: 34721 wps
# 0.803 perplexity: 51.095 speed: 34704 wps
# 0.903 perplexity: 49.589 speed: 34736 wps
# Epoch: 7 Train Perplexity: 48.691
# Epoch: 7 Valid Perplexity: 120.973
# Epoch: 8 Learning rate: 0.125
# 0.004 perplexity: 65.475 speed: 27241 wps
# 0.104 perplexity: 47.597 speed: 34319 wps
# 0.204 perplexity: 51.807 speed: 34647 wps
# 0.304 perplexity: 49.780 speed: 34793 wps
# 0.404 perplexity: 48.893 speed: 34876 wps
# 0.504 perplexity: 48.054 speed: 34893 wps
# 0.604 perplexity: 46.522 speed: 35002 wps
# 0.703 perplexity: 45.888 speed: 34956 wps
# 0.803 perplexity: 45.159 speed: 34922 wps
# 0.903 perplexity: 43.762 speed: 34912 wps
# Epoch: 8 Train Perplexity: 42.915
# Epoch: 8 Valid Perplexity: 122.042
# Epoch: 9 Learning rate: 0.062
# 0.004 perplexity: 61.469 speed: 27622 wps
# 0.104 perplexity: 44.548 speed: 34534 wps
# 0.204 perplexity: 48.495 speed: 34603 wps
# 0.304 perplexity: 46.564 speed: 34805 wps
# 0.404 perplexity: 45.738 speed: 34785 wps
# 0.504 perplexity: 44.953 speed: 34767 wps
# 0.604 perplexity: 43.501 speed: 34771 wps
# 0.703 perplexity: 42.900 speed: 34807 wps
# 0.803 perplexity: 42.185 speed: 34859 wps
# 0.903 perplexity: 40.842 speed: 34749 wps
# Epoch: 9 Train Perplexity: 40.020
# Epoch: 9 Valid Perplexity: 122.854
# Epoch: 10 Learning rate: 0.031
# 0.004 perplexity: 59.545 speed: 27160 wps
# 0.104 perplexity: 42.967 speed: 34739 wps
# 0.204 perplexity: 46.838 speed: 34448 wps
# 0.304 perplexity: 44.914 speed: 34260 wps
# 0.404 perplexity: 44.103 speed: 34374 wps
# 0.504 perplexity: 43.353 speed: 34255 wps
# 0.604 perplexity: 41.942 speed: 34279 wps
# 0.703 perplexity: 41.348 speed: 34382 wps
# 0.803 perplexity: 40.643 speed: 34428 wps
# 0.903 perplexity: 39.325 speed: 34457 wps
# Epoch: 10 Train Perplexity: 38.516
# Epoch: 10 Valid Perplexity: 123.096
# Epoch: 11 Learning rate: 0.016
# 0.004 perplexity: 58.540 speed: 27842 wps
# 0.104 perplexity: 42.083 speed: 34509 wps
# 0.204 perplexity: 45.923 speed: 34415 wps
# 0.304 perplexity: 44.009 speed: 34606 wps
# 0.404 perplexity: 43.199 speed: 34596 wps
# 0.504 perplexity: 42.465 speed: 34695 wps
# 0.604 perplexity: 41.084 speed: 34735 wps
# 0.703 perplexity: 40.492 speed: 34708 wps
# 0.803 perplexity: 39.795 speed: 34692 wps
# 0.903 perplexity: 38.492 speed: 34705 wps
# Epoch: 11 Train Perplexity: 37.691
# Epoch: 11 Valid Perplexity: 122.997
# Epoch: 12 Learning rate: 0.008
# 0.004 perplexity: 57.963 speed: 27652 wps
# 0.104 perplexity: 41.570 speed: 33806 wps
# 0.204 perplexity: 45.389 speed: 34571 wps
# 0.304 perplexity: 43.491 speed: 34613 wps
# 0.404 perplexity: 42.687 speed: 34659 wps
# 0.504 perplexity: 41.958 speed: 34691 wps
# 0.604 perplexity: 40.597 speed: 34692 wps
# 0.703 perplexity: 40.010 speed: 34681 wps
# 0.803 perplexity: 39.320 speed: 34687 wps
# 0.903 perplexity: 38.025 speed: 34708 wps
# Epoch: 12 Train Perplexity: 37.229
# Epoch: 12 Valid Perplexity: 122.715
# Epoch: 13 Learning rate: 0.004
# 0.004 perplexity: 57.588 speed: 27743 wps
# 0.104 perplexity: 41.260 speed: 34495 wps
# 0.204 perplexity: 45.070 speed: 34274 wps
# 0.304 perplexity: 43.194 speed: 34396 wps
# 0.404 perplexity: 42.397 speed: 34500 wps
# 0.504 perplexity: 41.673 speed: 34508 wps
# 0.604 perplexity: 40.323 speed: 34543 wps
# 0.703 perplexity: 39.741 speed: 34588 wps
# 0.803 perplexity: 39.056 speed: 34590 wps
# 0.903 perplexity: 37.767 speed: 34515 wps
# Epoch: 13 Train Perplexity: 36.975
# Epoch: 13 Valid Perplexity: 122.446
# Test Perplexity: 117.590
