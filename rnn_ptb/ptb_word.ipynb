# %%
# %pylab
# %matplotlib inline
# %load_ext watermark
# %watermark -v -m -p numpy,tensorflow
# Out:
# Using matplotlib backend: Qt5Agg
# Populating the interactive namespace from numpy and matplotlib
# CPython 3.5.3
# IPython 6.1.0
#
# numpy 1.13.0
# tensorflow 1.2.0
#
# compiler   : GCC 4.4.7 20120313 (Red Hat 4.4.7-1)
# system     : Linux
# release    : 4.8.0-54-generic
# machine    : x86_64
# processor  : x86_64
# CPU cores  : 4
# interpreter: 64bit

# %%
import time
import tensorflow as tf
from tensorflow.contrib.rnn import BasicLSTMCell, MultiRNNCell, DropoutWrapper

import reader

# %% [markdown]
# Small Config 정보를 사용합니다.

# %%
class SmallConfig(object):
    """Small config."""
    init_scale = 0.1
    learning_rate = 1.0
    max_grad_norm = 5
    num_layers = 2
    num_steps = 20
    hidden_size = 200
    max_epoch = 4
    max_max_epoch = 13
    keep_prob = 1.0
    lr_decay = 0.5
    batch_size = 20
    vocab_size = 10000

# %% [markdown]
# 트레이닝과 테스트에 사용할 두개의 config 오브젝트를 만듭니다.

# %%
config = SmallConfig()
eval_config = SmallConfig()
eval_config.batch_size = 1
eval_config.num_steps = 1

# %% [markdown]
# PTB 모델을 만들어 주는 클래스를 작성합니다.

# %%
class PTBModel(object):
    """The PTB model."""

    def __init__(self, config, is_training=False):
        self.batch_size = config.batch_size
        self.num_steps = config.num_steps
        input_size = [config.batch_size, config.num_steps]
        self.input_data = tf.placeholder(tf.int32, input_size)
        self.targets = tf.placeholder(tf.int32, input_size)

        lstm_fn = lambda: BasicLSTMCell(config.hidden_size, forget_bias=0.0, state_is_tuple=True, 
                                        reuse=tf.get_variable_scope().reuse)
        # SmallConfig에서는 드롭아웃이 적용되지 않습니다.
        if is_training and config.keep_prob < 1:
            lstm_fn = lambda: DropoutWrapper(lstm_fn(), config.keep_prob)
        # 두개의 계층을 가진 신경망 구조를 만듭니다.
        cell = MultiRNNCell([lstm_fn() for _ in range(config.num_layers)], state_is_tuple=True)

        self.initial_state = cell.zero_state(config.batch_size, tf.float32)

        with tf.device("/cpu:0"):
            embedding_size = [config.vocab_size, config.hidden_size]
            embedding = tf.get_variable("embedding", embedding_size)
            inputs = tf.nn.embedding_lookup(embedding, self.input_data)

        # SmallConfig에서는 드롭아웃이 적용되지 않습니다.
        if is_training and config.keep_prob < 1:
            inputs = tf.nn.dropout(inputs, config.keep_prob)

        # 각 배치마다 순서대로 데이터를 뽑아 셀에 입력합니다. 
        outputs = []
        state = self.initial_state
        with tf.variable_scope("RNN"):
            for time_step in range(config.num_steps):
                if time_step > 0: tf.get_variable_scope().reuse_variables()
                (cell_output, state) = cell(inputs[:, time_step, :], state)
                outputs.append(cell_output)

        # output의 크기를 20x20x200에서 400x200으로 변경합니다.
        output = tf.reshape(tf.concat(outputs, 1), [-1, config.hidden_size])
        softmax_w_size = [config.hidden_size, config.vocab_size]
        softmax_w = tf.get_variable("softmax_w", softmax_w_size)
        softmax_b = tf.get_variable("softmax_b", [config.vocab_size])
        # logits의 크기는 400x10000이 됩니다.
        logits = tf.matmul(output, softmax_w) + softmax_b
    
        loss = tf.contrib.legacy_seq2seq.sequence_loss_by_example(
            [logits],
            [tf.reshape(self.targets, [-1])],
            [tf.ones([config.batch_size * config.num_steps])])
        self.cost = tf.reduce_sum(loss) / config.batch_size
        self.final_state = state

        if not is_training:
            return

        self.lr = tf.Variable(0.0, trainable=False)
        tvars = tf.trainable_variables()
        # 기울기 클리핑을 수행합니다.
        grads, _ = tf.clip_by_global_norm(tf.gradients(self.cost, tvars),
                                          config.max_grad_norm)
        optimizer = tf.train.GradientDescentOptimizer(self.lr)
        self.train_op = optimizer.apply_gradients(zip(grads, tvars))

    def assign_lr(self, session, lr_value):
        session.run(tf.assign(self.lr, lr_value))

# %% [markdown]
# 에포크를 처리할 함수를 만듭니다.

# %%
def run_epoch(session, m, data, is_training=False):
    """Runs the model on the given data."""
    epoch_size = ((len(data) // m.batch_size) - 1) // m.num_steps
    start_time = time.time()
    costs = 0.0
    iters = 0
    
    eval_op = m.train_op if is_training else tf.no_op()
    
    # initial_state는 2x20x200 크기의 튜플입니다.
    state_list = []
    for c, h in m.initial_state:
        state_list.extend([c.eval(), h.eval()])
    
    ptb_iter = reader.ptb_iterator(data, m.batch_size, m.num_steps)
    for step, (x, y) in enumerate(ptb_iter):
        fetch_list = [m.cost]
        # final_state 튜플에 담겨있는 상태를 꺼내어 fetch_list에 담습니다. 
        for c, h in m.final_state:
            fetch_list.extend([c, h])
        fetch_list.append(eval_op)
        
        # 이전 스텝에서 구해진 state_list가 feed_dict로 주입됩니다.
        feed_dict = {m.input_data: x, m.targets: y}
        for i in range(len(m.initial_state)):
            c, h = m.initial_state[i]
            feed_dict[c], feed_dict[h] = state_list[i*2:(i+1)*2]
        
        # fetch_list에 담긴 final_state의 결과를 state_list로 전달 받습니다.
        cost, *state_list, _ = session.run(fetch_list, feed_dict)

        costs += cost
        iters += m.num_steps

        if is_training and step % (epoch_size // 10) == 10:
            print("%.3f perplexity: %.3f speed: %.0f wps" %
                    (step * 1.0 / epoch_size, np.exp(costs / iters),
                     iters * m.batch_size / (time.time() - start_time)))

    return np.exp(costs / iters)

# %%
raw_data = reader.ptb_raw_data('simple-examples/data')
train_data, valid_data, test_data, _ = raw_data

# %% [markdown]
# train_data, valid_data, test_data 는 단어를 숫자로 바꾼 리스트입니다.
# 가장 많이 나온 단어 순으로 0번 부터 시작하여 10000번 까지의 번호를 가지고 있습니다.

# %%
with tf.Graph().as_default(), tf.Session() as session:
    initializer = tf.random_uniform_initializer(-config.init_scale, config.init_scale)

    # 학습과 검증, 테스트를 위한 모델을 만듭니다.
    with tf.variable_scope("model", reuse=None, initializer=initializer):
        m = PTBModel(config, is_training=True)
    with tf.variable_scope("model", reuse=True, initializer=initializer):
        mvalid = PTBModel(config)
        mtest = PTBModel(eval_config)
        
    tf.global_variables_initializer().run()
    
    for i in range(config.max_max_epoch):
        # lr_decay는 반복속도를 조절해 주는 역할을 합니다.
        lr_decay = config.lr_decay ** max(i - config.max_epoch, 0.0)
        m.assign_lr(session, config.learning_rate * lr_decay)
        print("Epoch: %d Learning rate: %.3f" % (i + 1, session.run(m.lr)))
        
        perplexity = run_epoch(session, m, train_data, is_training=True)
        print("Epoch: %d Train Perplexity: %.3f" % (i + 1, perplexity))

        perplexity = run_epoch(session, mvalid, valid_data)
        print("Epoch: %d Valid Perplexity: %.3f" % (i + 1, perplexity))

    perplexity = run_epoch(session, mtest, test_data)
    print("Test Perplexity: %.3f" % perplexity)
# Out:
# Epoch: 1 Learning rate: 1.000
# 0.004 perplexity: 6928.471 speed: 9544 wps
# 0.104 perplexity: 846.083 speed: 25735 wps
# 0.204 perplexity: 624.978 speed: 26835 wps
# 0.304 perplexity: 504.199 speed: 27129 wps
# 0.404 perplexity: 435.025 speed: 27191 wps
# 0.504 perplexity: 390.055 speed: 27267 wps
# 0.604 perplexity: 351.587 speed: 27263 wps
# 0.703 perplexity: 325.313 speed: 27303 wps
# 0.803 perplexity: 304.495 speed: 27345 wps
# 0.903 perplexity: 285.380 speed: 27400 wps
# Epoch: 1 Train Perplexity: 270.934
# Epoch: 1 Valid Perplexity: 180.760
# Epoch: 2 Learning rate: 1.000
# 0.004 perplexity: 210.965 speed: 23230 wps
# 0.104 perplexity: 152.200 speed: 27338 wps
# 0.204 perplexity: 160.027 speed: 27810 wps
# 0.304 perplexity: 154.977 speed: 27687 wps
# 0.404 perplexity: 152.051 speed: 27778 wps
# 0.504 perplexity: 149.601 speed: 27715 wps
# 0.604 perplexity: 144.842 speed: 27702 wps
# 0.703 perplexity: 142.743 speed: 27607 wps
# 0.803 perplexity: 140.756 speed: 27585 wps
# 0.903 perplexity: 137.117 speed: 27545 wps
# Epoch: 2 Train Perplexity: 134.992
# Epoch: 2 Valid Perplexity: 144.209
# Epoch: 3 Learning rate: 1.000
# 0.004 perplexity: 146.523 speed: 22952 wps
# 0.104 perplexity: 106.467 speed: 26982 wps
# 0.204 perplexity: 115.755 speed: 27198 wps
# 0.304 perplexity: 112.624 speed: 27261 wps
# 0.404 perplexity: 111.655 speed: 27328 wps
# 0.504 perplexity: 110.748 speed: 27390 wps
# 0.604 perplexity: 108.130 speed: 27387 wps
# 0.703 perplexity: 107.525 speed: 27421 wps
# 0.803 perplexity: 106.874 speed: 27434 wps
# 0.903 perplexity: 104.656 speed: 27429 wps
# Epoch: 3 Train Perplexity: 103.675
# Epoch: 3 Valid Perplexity: 132.651
# Epoch: 4 Learning rate: 1.000
# 0.004 perplexity: 117.853 speed: 23024 wps
# 0.104 perplexity: 85.959 speed: 27459 wps
# 0.204 perplexity: 94.618 speed: 27577 wps
# 0.304 perplexity: 92.288 speed: 27673 wps
# 0.404 perplexity: 91.798 speed: 27572 wps
# 0.504 perplexity: 91.407 speed: 27456 wps
# 0.604 perplexity: 89.565 speed: 27433 wps
# 0.703 perplexity: 89.451 speed: 27471 wps
# 0.803 perplexity: 89.223 speed: 27431 wps
# 0.903 perplexity: 87.600 speed: 27476 wps
# Epoch: 4 Train Perplexity: 87.024
# Epoch: 4 Valid Perplexity: 127.957
# Epoch: 5 Learning rate: 1.000
# 0.004 perplexity: 100.046 speed: 21655 wps
# 0.104 perplexity: 74.117 speed: 27056 wps
# 0.204 perplexity: 82.074 speed: 27400 wps
# 0.304 perplexity: 80.155 speed: 27425 wps
# 0.404 perplexity: 79.994 speed: 27383 wps
# 0.504 perplexity: 79.875 speed: 27400 wps
# 0.604 perplexity: 78.511 speed: 27420 wps
# 0.703 perplexity: 78.516 speed: 27457 wps
# 0.803 perplexity: 78.436 speed: 27464 wps
# 0.903 perplexity: 77.139 speed: 27483 wps
# Epoch: 5 Train Perplexity: 76.750
# Epoch: 5 Valid Perplexity: 126.271
# Epoch: 6 Learning rate: 0.500
# 0.004 perplexity: 90.640 speed: 22368 wps
# 0.104 perplexity: 64.401 speed: 27390 wps
# 0.204 perplexity: 70.171 speed: 27435 wps
# 0.304 perplexity: 67.569 speed: 27331 wps
# 0.404 perplexity: 66.534 speed: 27382 wps
# 0.504 perplexity: 65.705 speed: 27464 wps
# 0.604 perplexity: 63.845 speed: 27423 wps
# 0.703 perplexity: 63.198 speed: 27434 wps
# 0.803 perplexity: 62.490 speed: 27405 wps
# 0.903 perplexity: 60.821 speed: 27408 wps
# Epoch: 6 Train Perplexity: 59.890
# Epoch: 6 Valid Perplexity: 119.113
# Epoch: 7 Learning rate: 0.250
# 0.004 perplexity: 75.006 speed: 22363 wps
# 0.104 perplexity: 53.534 speed: 27189 wps
# 0.204 perplexity: 58.421 speed: 27111 wps
# 0.304 perplexity: 56.138 speed: 27181 wps
# 0.404 perplexity: 55.223 speed: 27314 wps
# 0.504 perplexity: 54.452 speed: 27221 wps
# 0.604 perplexity: 52.761 speed: 27289 wps
# 0.703 perplexity: 52.096 speed: 27282 wps
# 0.803 perplexity: 51.357 speed: 27301 wps
# 0.903 perplexity: 49.794 speed: 27356 wps
# Epoch: 7 Train Perplexity: 48.863
# Epoch: 7 Valid Perplexity: 119.736
# Epoch: 8 Learning rate: 0.125
# 0.004 perplexity: 66.305 speed: 22782 wps
# 0.104 perplexity: 47.470 speed: 27529 wps
# 0.204 perplexity: 51.957 speed: 27571 wps
# 0.304 perplexity: 49.886 speed: 27476 wps
# 0.404 perplexity: 49.087 speed: 27332 wps
# 0.504 perplexity: 48.378 speed: 27316 wps
# 0.604 perplexity: 46.832 speed: 27378 wps
# 0.703 perplexity: 46.205 speed: 27364 wps
# 0.803 perplexity: 45.489 speed: 27367 wps
# 0.903 perplexity: 44.031 speed: 27368 wps
# Epoch: 8 Train Perplexity: 43.150
# Epoch: 8 Valid Perplexity: 121.203
# Epoch: 9 Learning rate: 0.062
# 0.004 perplexity: 61.504 speed: 22423 wps
# 0.104 perplexity: 44.417 speed: 26920 wps
# 0.204 perplexity: 48.688 speed: 27294 wps
# 0.304 perplexity: 46.707 speed: 27261 wps
# 0.404 perplexity: 45.968 speed: 27333 wps
# 0.504 perplexity: 45.291 speed: 27251 wps
# 0.604 perplexity: 43.832 speed: 27309 wps
# 0.703 perplexity: 43.221 speed: 27350 wps
# 0.803 perplexity: 42.521 speed: 27337 wps
# 0.903 perplexity: 41.121 speed: 27343 wps
# Epoch: 9 Train Perplexity: 40.269
# Epoch: 9 Valid Perplexity: 122.017
# Epoch: 10 Learning rate: 0.031
# 0.004 perplexity: 59.204 speed: 21977 wps
# 0.104 perplexity: 42.849 speed: 26752 wps
# 0.204 perplexity: 47.011 speed: 27145 wps
# 0.304 perplexity: 45.080 speed: 27354 wps
# 0.404 perplexity: 44.357 speed: 27374 wps
# 0.504 perplexity: 43.705 speed: 27396 wps
# 0.604 perplexity: 42.290 speed: 27410 wps
# 0.703 perplexity: 41.681 speed: 27342 wps
# 0.803 perplexity: 40.985 speed: 27369 wps
# 0.903 perplexity: 39.615 speed: 27405 wps
# Epoch: 10 Train Perplexity: 38.772
# Epoch: 10 Valid Perplexity: 122.223
# Epoch: 11 Learning rate: 0.016
# 0.004 perplexity: 57.947 speed: 22147 wps
# 0.104 perplexity: 41.950 speed: 27094 wps
# 0.204 perplexity: 46.056 speed: 27126 wps
# 0.304 perplexity: 44.166 speed: 27169 wps
# 0.404 perplexity: 43.462 speed: 27269 wps
# 0.504 perplexity: 42.831 speed: 27288 wps
# 0.604 perplexity: 41.445 speed: 27290 wps
# 0.703 perplexity: 40.837 speed: 27332 wps
# 0.803 perplexity: 40.141 speed: 27362 wps
# 0.903 perplexity: 38.789 speed: 27337 wps
# Epoch: 11 Train Perplexity: 37.953
# Epoch: 11 Valid Perplexity: 122.116
# Epoch: 12 Learning rate: 0.008
# 0.004 perplexity: 57.213 speed: 22537 wps
# 0.104 perplexity: 41.414 speed: 27234 wps
# 0.204 perplexity: 45.493 speed: 27382 wps
# 0.304 perplexity: 43.632 speed: 27357 wps
# 0.404 perplexity: 42.944 speed: 27352 wps
# 0.504 perplexity: 42.326 speed: 27309 wps
# 0.604 perplexity: 40.960 speed: 27337 wps
# 0.703 perplexity: 40.356 speed: 27323 wps
# 0.803 perplexity: 39.664 speed: 27327 wps
# 0.903 perplexity: 38.322 speed: 27326 wps
# Epoch: 12 Train Perplexity: 37.491
# Epoch: 12 Valid Perplexity: 121.867
# Epoch: 13 Learning rate: 0.004
# 0.004 perplexity: 56.789 speed: 23055 wps
# 0.104 perplexity: 41.111 speed: 27153 wps
# 0.204 perplexity: 45.172 speed: 27321 wps
# 0.304 perplexity: 43.333 speed: 27416 wps
# 0.404 perplexity: 42.653 speed: 27400 wps
# 0.504 perplexity: 42.042 speed: 27482 wps
# 0.604 perplexity: 40.688 speed: 27513 wps
# 0.703 perplexity: 40.088 speed: 27496 wps
# 0.803 perplexity: 39.400 speed: 27450 wps
# 0.903 perplexity: 38.063 speed: 27442 wps
# Epoch: 13 Train Perplexity: 37.237
# Epoch: 13 Valid Perplexity: 121.641
# Test Perplexity: 115.614
