# %%
# %pylab
# %matplotlib inline
# %load_ext watermark
# %watermark -v -m -p numpy,tensorflow
# Out:
# Using matplotlib backend: Qt5Agg
# Populating the interactive namespace from numpy and matplotlib
# CPython 3.5.4
# IPython 6.2.1
#
# numpy 1.14.1
# tensorflow 1.6.0
#
# compiler   : GCC 7.2.0
# system     : Linux
# release    : 4.13.0-36-generic
# machine    : x86_64
# processor  : x86_64
# CPU cores  : 4
# interpreter: 64bit

# %%
import time
import tensorflow as tf
from tensorflow.contrib.rnn import BasicLSTMCell, MultiRNNCell, DropoutWrapper

import reader

# %% [markdown]
# Small Config 정보를 사용합니다.

# %%
class SmallConfig(object):
    """Small config."""
    init_scale = 0.1
    learning_rate = 1.0
    max_grad_norm = 5
    num_layers = 2
    num_steps = 20
    hidden_size = 200
    max_epoch = 4
    max_max_epoch = 13
    keep_prob = 1.0
    lr_decay = 0.5
    batch_size = 20
    vocab_size = 10000

# %% [markdown]
# 트레이닝과 테스트에 사용할 두개의 config 오브젝트를 만듭니다.

# %%
config = SmallConfig()
eval_config = SmallConfig()
eval_config.batch_size = 1
eval_config.num_steps = 1

# %% [markdown]
# PTB 모델을 만들어 주는 클래스를 작성합니다.

# %%
class PTBModel(object):
    """The PTB model."""

    def __init__(self, config, is_training=False):
        self.batch_size = config.batch_size
        self.num_steps = config.num_steps
        input_size = [config.batch_size, config.num_steps]
        self.input_data = tf.placeholder(tf.int32, input_size)
        self.targets = tf.placeholder(tf.int32, input_size)

        lstm_fn = lambda: BasicLSTMCell(config.hidden_size, forget_bias=0.0, state_is_tuple=True, 
                                        reuse=tf.get_variable_scope().reuse)
        # SmallConfig에서는 드롭아웃이 적용되지 않습니다.
        if is_training and config.keep_prob < 1:
            lstm_fn = lambda: DropoutWrapper(lstm_fn(), config.keep_prob)
        # 두개의 계층을 가진 신경망 구조를 만듭니다.
        cell = MultiRNNCell([lstm_fn() for _ in range(config.num_layers)], state_is_tuple=True)

        self.initial_state = cell.zero_state(config.batch_size, tf.float32)

        with tf.device("/cpu:0"):
            embedding_size = [config.vocab_size, config.hidden_size]
            embedding = tf.get_variable("embedding", embedding_size)
            inputs = tf.nn.embedding_lookup(embedding, self.input_data)

        # SmallConfig에서는 드롭아웃이 적용되지 않습니다.
        if is_training and config.keep_prob < 1:
            inputs = tf.nn.dropout(inputs, config.keep_prob)

        # 각 배치마다 순서대로 데이터를 뽑아 셀에 입력합니다. 
        outputs = []
        state = self.initial_state
        with tf.variable_scope("RNN"):
            for time_step in range(config.num_steps):
                if time_step > 0: tf.get_variable_scope().reuse_variables()
                (cell_output, state) = cell(inputs[:, time_step, :], state)
                outputs.append(cell_output)

        # output의 크기를 20x20x200에서 400x200으로 변경합니다.
        output = tf.reshape(tf.concat(outputs, 1), [-1, config.hidden_size])
        softmax_w_size = [config.hidden_size, config.vocab_size]
        softmax_w = tf.get_variable("softmax_w", softmax_w_size)
        softmax_b = tf.get_variable("softmax_b", [config.vocab_size])
        # logits의 크기는 400x10000이 됩니다.
        logits = tf.matmul(output, softmax_w) + softmax_b
    
        loss = tf.contrib.legacy_seq2seq.sequence_loss_by_example(
            [logits],
            [tf.reshape(self.targets, [-1])],
            [tf.ones([config.batch_size * config.num_steps])])
        self.cost = tf.reduce_sum(loss) / config.batch_size
        self.final_state = state

        if not is_training:
            return

        self.lr = tf.Variable(0.0, trainable=False)
        tvars = tf.trainable_variables()
        # 기울기 클리핑을 수행합니다.
        grads, _ = tf.clip_by_global_norm(tf.gradients(self.cost, tvars),
                                          config.max_grad_norm)
        optimizer = tf.train.GradientDescentOptimizer(self.lr)
        self.train_op = optimizer.apply_gradients(zip(grads, tvars))

    def assign_lr(self, session, lr_value):
        session.run(tf.assign(self.lr, lr_value))

# %% [markdown]
# 에포크를 처리할 함수를 만듭니다.

# %%
def run_epoch(session, m, data, is_training=False):
    """Runs the model on the given data."""
    epoch_size = ((len(data) // m.batch_size) - 1) // m.num_steps
    start_time = time.time()
    costs = 0.0
    iters = 0
    
    eval_op = m.train_op if is_training else tf.no_op()
    
    # initial_state는 2x20x200 크기의 튜플입니다.
    state_list = []
    for c, h in m.initial_state:
        state_list.extend([c.eval(), h.eval()])
    
    ptb_iter = reader.ptb_iterator(data, m.batch_size, m.num_steps)
    for step, (x, y) in enumerate(ptb_iter):
        fetch_list = [m.cost]
        # final_state 튜플에 담겨있는 상태를 꺼내어 fetch_list에 담습니다. 
        for c, h in m.final_state:
            fetch_list.extend([c, h])
        fetch_list.append(eval_op)
        
        # 이전 스텝에서 구해진 state_list가 feed_dict로 주입됩니다.
        feed_dict = {m.input_data: x, m.targets: y}
        for i in range(len(m.initial_state)):
            c, h = m.initial_state[i]
            feed_dict[c], feed_dict[h] = state_list[i*2:(i+1)*2]
        
        # fetch_list에 담긴 final_state의 결과를 state_list로 전달 받습니다.
        cost, *state_list, _ = session.run(fetch_list, feed_dict)

        costs += cost
        iters += m.num_steps

        if is_training and step % (epoch_size // 10) == 10:
            print("%.3f perplexity: %.3f speed: %.0f wps" %
                    (step * 1.0 / epoch_size, np.exp(costs / iters),
                     iters * m.batch_size / (time.time() - start_time)))

    return np.exp(costs / iters)

# %%
raw_data = reader.ptb_raw_data('simple-examples/data')
train_data, valid_data, test_data, _ = raw_data

# %% [markdown]
# train_data, valid_data, test_data 는 단어를 숫자로 바꾼 리스트입니다.
# 가장 많이 나온 단어 순으로 0번 부터 시작하여 10000번 까지의 번호를 가지고 있습니다.

# %%
with tf.Graph().as_default(), tf.Session() as session:
    initializer = tf.random_uniform_initializer(-config.init_scale, config.init_scale)

    # 학습과 검증, 테스트를 위한 모델을 만듭니다.
    with tf.variable_scope("model", reuse=None, initializer=initializer):
        m = PTBModel(config, is_training=True)
    with tf.variable_scope("model", reuse=True, initializer=initializer):
        mvalid = PTBModel(config)
        mtest = PTBModel(eval_config)
        
    tf.global_variables_initializer().run()
    
    for i in range(config.max_max_epoch):
        # lr_decay는 반복속도를 조절해 주는 역할을 합니다.
        lr_decay = config.lr_decay ** max(i - config.max_epoch, 0.0)
        m.assign_lr(session, config.learning_rate * lr_decay)
        print("Epoch: %d Learning rate: %.3f" % (i + 1, session.run(m.lr)))
        
        perplexity = run_epoch(session, m, train_data, is_training=True)
        print("Epoch: %d Train Perplexity: %.3f" % (i + 1, perplexity))

        perplexity = run_epoch(session, mvalid, valid_data)
        print("Epoch: %d Valid Perplexity: %.3f" % (i + 1, perplexity))

    perplexity = run_epoch(session, mtest, test_data)
    print("Test Perplexity: %.3f" % perplexity)
# Out:
# Epoch: 1 Learning rate: 1.000
# 0.004 perplexity: 6554.388 speed: 11054 wps
# 0.104 perplexity: 841.641 speed: 31775 wps
# 0.204 perplexity: 623.460 speed: 33453 wps
# 0.304 perplexity: 506.229 speed: 33936 wps
# 0.404 perplexity: 436.317 speed: 34285 wps
# 0.504 perplexity: 391.010 speed: 34625 wps
# 0.604 perplexity: 352.319 speed: 34768 wps
# 0.703 perplexity: 325.736 speed: 34808 wps
# 0.803 perplexity: 304.580 speed: 34930 wps
# 0.903 perplexity: 285.284 speed: 34979 wps
# Epoch: 1 Train Perplexity: 270.738
# Epoch: 1 Valid Perplexity: 179.974
# Epoch: 2 Learning rate: 1.000
# 0.004 perplexity: 211.120 speed: 27954 wps
# 0.104 perplexity: 152.113 speed: 35336 wps
# 0.204 perplexity: 159.113 speed: 35595 wps
# 0.304 perplexity: 154.264 speed: 35605 wps
# 0.404 perplexity: 151.318 speed: 35603 wps
# 0.504 perplexity: 148.860 speed: 35482 wps
# 0.604 perplexity: 144.135 speed: 35485 wps
# 0.703 perplexity: 141.906 speed: 35401 wps
# 0.803 perplexity: 139.856 speed: 35426 wps
# 0.903 perplexity: 136.122 speed: 35396 wps
# Epoch: 2 Train Perplexity: 133.981
# Epoch: 2 Valid Perplexity: 143.428
# Epoch: 3 Learning rate: 1.000
# 0.004 perplexity: 144.165 speed: 27561 wps
# 0.104 perplexity: 105.537 speed: 34395 wps
# 0.204 perplexity: 114.332 speed: 34775 wps
# 0.304 perplexity: 111.734 speed: 34309 wps
# 0.404 perplexity: 110.760 speed: 34381 wps
# 0.504 perplexity: 109.825 speed: 34461 wps
# 0.604 perplexity: 107.141 speed: 34501 wps
# 0.703 perplexity: 106.389 speed: 34578 wps
# 0.803 perplexity: 105.700 speed: 34670 wps
# 0.903 perplexity: 103.469 speed: 34696 wps
# Epoch: 3 Train Perplexity: 102.447
# Epoch: 3 Valid Perplexity: 132.564
# Epoch: 4 Learning rate: 1.000
# 0.004 perplexity: 115.042 speed: 27981 wps
# 0.104 perplexity: 85.459 speed: 35360 wps
# 0.204 perplexity: 93.544 speed: 35723 wps
# 0.304 perplexity: 91.573 speed: 35587 wps
# 0.404 perplexity: 91.119 speed: 35462 wps
# 0.504 perplexity: 90.758 speed: 35480 wps
# 0.604 perplexity: 88.804 speed: 35432 wps
# 0.703 perplexity: 88.483 speed: 35329 wps
# 0.803 perplexity: 88.224 speed: 35224 wps
# 0.903 perplexity: 86.577 speed: 35157 wps
# Epoch: 4 Train Perplexity: 86.001
# Epoch: 4 Valid Perplexity: 128.540
# Epoch: 5 Learning rate: 1.000
# 0.004 perplexity: 99.616 speed: 27283 wps
# 0.104 perplexity: 73.843 speed: 34655 wps
# 0.204 perplexity: 81.043 speed: 34835 wps
# 0.304 perplexity: 79.357 speed: 34874 wps
# 0.404 perplexity: 79.180 speed: 34925 wps
# 0.504 perplexity: 79.030 speed: 34903 wps
# 0.604 perplexity: 77.526 speed: 34927 wps
# 0.703 perplexity: 77.512 speed: 35050 wps
# 0.803 perplexity: 77.495 speed: 35024 wps
# 0.903 perplexity: 76.190 speed: 35051 wps
# Epoch: 5 Train Perplexity: 75.831
# Epoch: 5 Valid Perplexity: 126.824
# Epoch: 6 Learning rate: 0.500
# 0.004 perplexity: 90.851 speed: 27996 wps
# 0.104 perplexity: 64.524 speed: 34487 wps
# 0.204 perplexity: 69.557 speed: 34726 wps
# 0.304 perplexity: 66.974 speed: 34685 wps
# 0.404 perplexity: 65.997 speed: 34756 wps
# 0.504 perplexity: 65.145 speed: 34711 wps
# 0.604 perplexity: 63.239 speed: 34833 wps
# 0.703 perplexity: 62.517 speed: 34841 wps
# 0.803 perplexity: 61.854 speed: 34801 wps
# 0.903 perplexity: 60.116 speed: 34843 wps
# Epoch: 6 Train Perplexity: 59.226
# Epoch: 6 Valid Perplexity: 120.059
# Epoch: 7 Learning rate: 0.250
# 0.004 perplexity: 74.080 speed: 28050 wps
# 0.104 perplexity: 53.401 speed: 35010 wps
# 0.204 perplexity: 57.730 speed: 35027 wps
# 0.304 perplexity: 55.519 speed: 34867 wps
# 0.404 perplexity: 54.648 speed: 34866 wps
# 0.504 perplexity: 53.892 speed: 34976 wps
# 0.604 perplexity: 52.189 speed: 34940 wps
# 0.703 perplexity: 51.468 speed: 34935 wps
# 0.803 perplexity: 50.766 speed: 34906 wps
# 0.903 perplexity: 49.187 speed: 34894 wps
# Epoch: 7 Train Perplexity: 48.302
# Epoch: 7 Valid Perplexity: 121.325
# Epoch: 8 Learning rate: 0.125
# 0.004 perplexity: 65.924 speed: 28127 wps
# 0.104 perplexity: 47.404 speed: 34597 wps
# 0.204 perplexity: 51.300 speed: 34953 wps
# 0.304 perplexity: 49.297 speed: 34929 wps
# 0.404 perplexity: 48.498 speed: 35043 wps
# 0.504 perplexity: 47.796 speed: 34922 wps
# 0.604 perplexity: 46.254 speed: 34974 wps
# 0.703 perplexity: 45.568 speed: 34956 wps
# 0.803 perplexity: 44.890 speed: 34973 wps
# 0.903 perplexity: 43.425 speed: 35005 wps
# Epoch: 8 Train Perplexity: 42.579
# Epoch: 8 Valid Perplexity: 122.978
# Epoch: 9 Learning rate: 0.062
# 0.004 perplexity: 61.793 speed: 28305 wps
# 0.104 perplexity: 44.427 speed: 34755 wps
# 0.204 perplexity: 48.107 speed: 34892 wps
# 0.304 perplexity: 46.180 speed: 34835 wps
# 0.404 perplexity: 45.418 speed: 34913 wps
# 0.504 perplexity: 44.746 speed: 35045 wps
# 0.604 perplexity: 43.281 speed: 35021 wps
# 0.703 perplexity: 42.608 speed: 35080 wps
# 0.803 perplexity: 41.936 speed: 35057 wps
# 0.903 perplexity: 40.536 speed: 35044 wps
# Epoch: 9 Train Perplexity: 39.713
# Epoch: 9 Valid Perplexity: 123.628
# Epoch: 10 Learning rate: 0.031
# 0.004 perplexity: 59.819 speed: 27521 wps
# 0.104 perplexity: 42.868 speed: 34568 wps
# 0.204 perplexity: 46.460 speed: 34942 wps
# 0.304 perplexity: 44.563 speed: 34844 wps
# 0.404 perplexity: 43.821 speed: 34879 wps
# 0.504 perplexity: 43.170 speed: 34953 wps
# 0.604 perplexity: 41.745 speed: 34978 wps
# 0.703 perplexity: 41.076 speed: 34901 wps
# 0.803 perplexity: 40.400 speed: 34802 wps
# 0.903 perplexity: 39.035 speed: 34870 wps
# Epoch: 10 Train Perplexity: 38.221
# Epoch: 10 Valid Perplexity: 123.755
# Epoch: 11 Learning rate: 0.016
# 0.004 perplexity: 58.536 speed: 28002 wps
# 0.104 perplexity: 41.949 speed: 34639 wps
# 0.204 perplexity: 45.527 speed: 34462 wps
# 0.304 perplexity: 43.657 speed: 34155 wps
# 0.404 perplexity: 42.926 speed: 34012 wps
# 0.504 perplexity: 42.292 speed: 33840 wps
# 0.604 perplexity: 40.894 speed: 33922 wps
# 0.703 perplexity: 40.232 speed: 34018 wps
# 0.803 perplexity: 39.553 speed: 34114 wps
# 0.903 perplexity: 38.207 speed: 34263 wps
# Epoch: 11 Train Perplexity: 37.399
# Epoch: 11 Valid Perplexity: 123.589
# Epoch: 12 Learning rate: 0.008
# 0.004 perplexity: 57.732 speed: 28111 wps
# 0.104 perplexity: 41.406 speed: 35013 wps
# 0.204 perplexity: 44.974 speed: 35124 wps
# 0.304 perplexity: 43.130 speed: 35103 wps
# 0.404 perplexity: 42.406 speed: 35156 wps
# 0.504 perplexity: 41.783 speed: 35089 wps
# 0.604 perplexity: 40.405 speed: 35063 wps
# 0.703 perplexity: 39.751 speed: 35043 wps
# 0.803 perplexity: 39.075 speed: 34967 wps
# 0.903 perplexity: 37.739 speed: 34966 wps
# Epoch: 12 Train Perplexity: 36.937
# Epoch: 12 Valid Perplexity: 123.271
# Epoch: 13 Learning rate: 0.004
# 0.004 perplexity: 57.274 speed: 27413 wps
# 0.104 perplexity: 41.092 speed: 33841 wps
# 0.204 perplexity: 44.655 speed: 34354 wps
# 0.304 perplexity: 42.831 speed: 34548 wps
# 0.404 perplexity: 42.115 speed: 34558 wps
# 0.504 perplexity: 41.497 speed: 34704 wps
# 0.604 perplexity: 40.132 speed: 34781 wps
# 0.703 perplexity: 39.484 speed: 34812 wps
# 0.803 perplexity: 38.811 speed: 34789 wps
# 0.903 perplexity: 37.483 speed: 34706 wps
# Epoch: 13 Train Perplexity: 36.685
# Epoch: 13 Valid Perplexity: 122.993
# Test Perplexity: 117.683
