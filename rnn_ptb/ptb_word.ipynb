# %%
# %pylab
# %matplotlib inline
# %load_ext watermark
# %watermark -v -m -p numpy,tensorflow
# Out:
# Using matplotlib backend: MacOSX
# Populating the interactive namespace from numpy and matplotlib
# CPython 3.5.4
# IPython 6.1.0
#
# numpy 1.13.3
# tensorflow 1.4.0
#
# compiler   : GCC 4.2.1 Compatible Clang 4.0.1 (tags/RELEASE_401/final)
# system     : Darwin
# release    : 17.2.0
# machine    : x86_64
# processor  : i386
# CPU cores  : 8
# interpreter: 64bit

# %%
import time
import tensorflow as tf
from tensorflow.contrib.rnn import BasicLSTMCell, MultiRNNCell, DropoutWrapper

import reader

# %% [markdown]
# Small Config 정보를 사용합니다.

# %%
class SmallConfig(object):
    """Small config."""
    init_scale = 0.1
    learning_rate = 1.0
    max_grad_norm = 5
    num_layers = 2
    num_steps = 20
    hidden_size = 200
    max_epoch = 4
    max_max_epoch = 13
    keep_prob = 1.0
    lr_decay = 0.5
    batch_size = 20
    vocab_size = 10000

# %% [markdown]
# 트레이닝과 테스트에 사용할 두개의 config 오브젝트를 만듭니다.

# %%
config = SmallConfig()
eval_config = SmallConfig()
eval_config.batch_size = 1
eval_config.num_steps = 1

# %% [markdown]
# PTB 모델을 만들어 주는 클래스를 작성합니다.

# %%
class PTBModel(object):
    """The PTB model."""

    def __init__(self, config, is_training=False):
        self.batch_size = config.batch_size
        self.num_steps = config.num_steps
        input_size = [config.batch_size, config.num_steps]
        self.input_data = tf.placeholder(tf.int32, input_size)
        self.targets = tf.placeholder(tf.int32, input_size)

        lstm_fn = lambda: BasicLSTMCell(config.hidden_size, forget_bias=0.0, state_is_tuple=True, 
                                        reuse=tf.get_variable_scope().reuse)
        # SmallConfig에서는 드롭아웃이 적용되지 않습니다.
        if is_training and config.keep_prob < 1:
            lstm_fn = lambda: DropoutWrapper(lstm_fn(), config.keep_prob)
        # 두개의 계층을 가진 신경망 구조를 만듭니다.
        cell = MultiRNNCell([lstm_fn() for _ in range(config.num_layers)], state_is_tuple=True)

        self.initial_state = cell.zero_state(config.batch_size, tf.float32)

        with tf.device("/cpu:0"):
            embedding_size = [config.vocab_size, config.hidden_size]
            embedding = tf.get_variable("embedding", embedding_size)
            inputs = tf.nn.embedding_lookup(embedding, self.input_data)

        # SmallConfig에서는 드롭아웃이 적용되지 않습니다.
        if is_training and config.keep_prob < 1:
            inputs = tf.nn.dropout(inputs, config.keep_prob)

        # 각 배치마다 순서대로 데이터를 뽑아 셀에 입력합니다. 
        outputs = []
        state = self.initial_state
        with tf.variable_scope("RNN"):
            for time_step in range(config.num_steps):
                if time_step > 0: tf.get_variable_scope().reuse_variables()
                (cell_output, state) = cell(inputs[:, time_step, :], state)
                outputs.append(cell_output)

        # output의 크기를 20x20x200에서 400x200으로 변경합니다.
        output = tf.reshape(tf.concat(outputs, 1), [-1, config.hidden_size])
        softmax_w_size = [config.hidden_size, config.vocab_size]
        softmax_w = tf.get_variable("softmax_w", softmax_w_size)
        softmax_b = tf.get_variable("softmax_b", [config.vocab_size])
        # logits의 크기는 400x10000이 됩니다.
        logits = tf.matmul(output, softmax_w) + softmax_b
    
        loss = tf.contrib.legacy_seq2seq.sequence_loss_by_example(
            [logits],
            [tf.reshape(self.targets, [-1])],
            [tf.ones([config.batch_size * config.num_steps])])
        self.cost = tf.reduce_sum(loss) / config.batch_size
        self.final_state = state

        if not is_training:
            return

        self.lr = tf.Variable(0.0, trainable=False)
        tvars = tf.trainable_variables()
        # 기울기 클리핑을 수행합니다.
        grads, _ = tf.clip_by_global_norm(tf.gradients(self.cost, tvars),
                                          config.max_grad_norm)
        optimizer = tf.train.GradientDescentOptimizer(self.lr)
        self.train_op = optimizer.apply_gradients(zip(grads, tvars))

    def assign_lr(self, session, lr_value):
        session.run(tf.assign(self.lr, lr_value))

# %% [markdown]
# 에포크를 처리할 함수를 만듭니다.

# %%
def run_epoch(session, m, data, is_training=False):
    """Runs the model on the given data."""
    epoch_size = ((len(data) // m.batch_size) - 1) // m.num_steps
    start_time = time.time()
    costs = 0.0
    iters = 0
    
    eval_op = m.train_op if is_training else tf.no_op()
    
    # initial_state는 2x20x200 크기의 튜플입니다.
    state_list = []
    for c, h in m.initial_state:
        state_list.extend([c.eval(), h.eval()])
    
    ptb_iter = reader.ptb_iterator(data, m.batch_size, m.num_steps)
    for step, (x, y) in enumerate(ptb_iter):
        fetch_list = [m.cost]
        # final_state 튜플에 담겨있는 상태를 꺼내어 fetch_list에 담습니다. 
        for c, h in m.final_state:
            fetch_list.extend([c, h])
        fetch_list.append(eval_op)
        
        # 이전 스텝에서 구해진 state_list가 feed_dict로 주입됩니다.
        feed_dict = {m.input_data: x, m.targets: y}
        for i in range(len(m.initial_state)):
            c, h = m.initial_state[i]
            feed_dict[c], feed_dict[h] = state_list[i*2:(i+1)*2]
        
        # fetch_list에 담긴 final_state의 결과를 state_list로 전달 받습니다.
        cost, *state_list, _ = session.run(fetch_list, feed_dict)

        costs += cost
        iters += m.num_steps

        if is_training and step % (epoch_size // 10) == 10:
            print("%.3f perplexity: %.3f speed: %.0f wps" %
                    (step * 1.0 / epoch_size, np.exp(costs / iters),
                     iters * m.batch_size / (time.time() - start_time)))

    return np.exp(costs / iters)

# %%
raw_data = reader.ptb_raw_data('simple-examples/data')
train_data, valid_data, test_data, _ = raw_data

# %% [markdown]
# train_data, valid_data, test_data 는 단어를 숫자로 바꾼 리스트입니다.
# 가장 많이 나온 단어 순으로 0번 부터 시작하여 10000번 까지의 번호를 가지고 있습니다.

# %%
with tf.Graph().as_default(), tf.Session() as session:
    initializer = tf.random_uniform_initializer(-config.init_scale, config.init_scale)

    # 학습과 검증, 테스트를 위한 모델을 만듭니다.
    with tf.variable_scope("model", reuse=None, initializer=initializer):
        m = PTBModel(config, is_training=True)
    with tf.variable_scope("model", reuse=True, initializer=initializer):
        mvalid = PTBModel(config)
        mtest = PTBModel(eval_config)
        
    tf.global_variables_initializer().run()
    
    for i in range(config.max_max_epoch):
        # lr_decay는 반복속도를 조절해 주는 역할을 합니다.
        lr_decay = config.lr_decay ** max(i - config.max_epoch, 0.0)
        m.assign_lr(session, config.learning_rate * lr_decay)
        print("Epoch: %d Learning rate: %.3f" % (i + 1, session.run(m.lr)))
        
        perplexity = run_epoch(session, m, train_data, is_training=True)
        print("Epoch: %d Train Perplexity: %.3f" % (i + 1, perplexity))

        perplexity = run_epoch(session, mvalid, valid_data)
        print("Epoch: %d Valid Perplexity: %.3f" % (i + 1, perplexity))

    perplexity = run_epoch(session, mtest, test_data)
    print("Test Perplexity: %.3f" % perplexity)
# Out:
# Epoch: 1 Learning rate: 1.000
# 0.004 perplexity: 6185.469 speed: 2341 wps
# 0.104 perplexity: 849.764 speed: 2560 wps
# 0.204 perplexity: 626.225 speed: 2465 wps
# 0.304 perplexity: 505.544 speed: 2396 wps
# 0.404 perplexity: 435.461 speed: 2388 wps
# 0.504 perplexity: 389.923 speed: 2369 wps
# 0.604 perplexity: 351.226 speed: 2366 wps
# 0.703 perplexity: 324.626 speed: 2368 wps
# 0.803 perplexity: 303.514 speed: 2357 wps
# 0.903 perplexity: 284.244 speed: 2359 wps
# Epoch: 1 Train Perplexity: 269.857
# Epoch: 1 Valid Perplexity: 179.954
# Epoch: 2 Learning rate: 1.000
# 0.004 perplexity: 213.015 speed: 2357 wps
# 0.104 perplexity: 152.082 speed: 2402 wps
# 0.204 perplexity: 159.336 speed: 2381 wps
# 0.304 perplexity: 154.375 speed: 2345 wps
# 0.404 perplexity: 151.408 speed: 2314 wps
# 0.504 perplexity: 148.965 speed: 2310 wps
# 0.604 perplexity: 144.299 speed: 2305 wps
# 0.703 perplexity: 142.218 speed: 2308 wps
# 0.803 perplexity: 140.160 speed: 2316 wps
# 0.903 perplexity: 136.539 speed: 2324 wps
# Epoch: 2 Train Perplexity: 134.416
# Epoch: 2 Valid Perplexity: 142.918
# Epoch: 3 Learning rate: 1.000
# 0.004 perplexity: 148.743 speed: 2370 wps
# 0.104 perplexity: 106.017 speed: 2371 wps
# 0.204 perplexity: 115.315 speed: 2370 wps
# 0.304 perplexity: 112.401 speed: 2369 wps
# 0.404 perplexity: 111.317 speed: 2371 wps
# 0.504 perplexity: 110.436 speed: 2372 wps
# 0.604 perplexity: 107.699 speed: 2371 wps
# 0.703 perplexity: 107.027 speed: 2371 wps
# 0.803 perplexity: 106.328 speed: 2363 wps
# 0.903 perplexity: 104.102 speed: 2350 wps
# Epoch: 3 Train Perplexity: 103.130
# Epoch: 3 Valid Perplexity: 130.932
# Epoch: 4 Learning rate: 1.000
# 0.004 perplexity: 117.727 speed: 2220 wps
# 0.104 perplexity: 86.092 speed: 2308 wps
# 0.204 perplexity: 94.517 speed: 2322 wps
# 0.304 perplexity: 92.290 speed: 2303 wps
# 0.404 perplexity: 91.643 speed: 2308 wps
# 0.504 perplexity: 91.191 speed: 2308 wps
# 0.604 perplexity: 89.237 speed: 2315 wps
# 0.703 perplexity: 89.055 speed: 2315 wps
# 0.803 perplexity: 88.769 speed: 2296 wps
# 0.903 perplexity: 87.162 speed: 2291 wps
# Epoch: 4 Train Perplexity: 86.601
# Epoch: 4 Valid Perplexity: 127.979
# Epoch: 5 Learning rate: 1.000
# 0.004 perplexity: 99.794 speed: 2312 wps
# 0.104 perplexity: 74.437 speed: 2303 wps
# 0.204 perplexity: 81.911 speed: 2242 wps
# 0.304 perplexity: 80.064 speed: 2233 wps
# 0.404 perplexity: 79.717 speed: 2212 wps
# 0.504 perplexity: 79.538 speed: 2227 wps
# 0.604 perplexity: 78.069 speed: 2218 wps
# 0.703 perplexity: 78.056 speed: 2215 wps
# 0.803 perplexity: 78.012 speed: 2212 wps
# 0.903 perplexity: 76.717 speed: 2207 wps
# Epoch: 5 Train Perplexity: 76.387
# Epoch: 5 Valid Perplexity: 126.359
# Epoch: 6 Learning rate: 0.500
# 0.004 perplexity: 90.648 speed: 1949 wps
# 0.104 perplexity: 64.845 speed: 2029 wps
# 0.204 perplexity: 70.188 speed: 2035 wps
# 0.304 perplexity: 67.663 speed: 2036 wps
# 0.404 perplexity: 66.484 speed: 2078 wps
# 0.504 perplexity: 65.545 speed: 2099 wps
# 0.604 perplexity: 63.617 speed: 2112 wps
# 0.703 perplexity: 62.923 speed: 2123 wps
# 0.803 perplexity: 62.204 speed: 2131 wps
# 0.903 perplexity: 60.495 speed: 2145 wps
# Epoch: 6 Train Perplexity: 59.607
# Epoch: 6 Valid Perplexity: 119.489
# Epoch: 7 Learning rate: 0.250
# 0.004 perplexity: 73.550 speed: 2224 wps
# 0.104 perplexity: 53.649 speed: 2177 wps
# 0.204 perplexity: 58.264 speed: 2168 wps
# 0.304 perplexity: 56.034 speed: 2212 wps
# 0.404 perplexity: 54.952 speed: 2237 wps
# 0.504 perplexity: 54.108 speed: 2251 wps
# 0.604 perplexity: 52.391 speed: 2260 wps
# 0.703 perplexity: 51.693 speed: 2246 wps
# 0.803 perplexity: 50.961 speed: 2241 wps
# 0.903 perplexity: 49.392 speed: 2240 wps
# Epoch: 7 Train Perplexity: 48.508
# Epoch: 7 Valid Perplexity: 120.220
# Epoch: 8 Learning rate: 0.125
# 0.004 perplexity: 64.960 speed: 2193 wps
# 0.104 perplexity: 47.660 speed: 2144 wps
# 0.204 perplexity: 51.823 speed: 2188 wps
# 0.304 perplexity: 49.767 speed: 2196 wps
# 0.404 perplexity: 48.787 speed: 2185 wps
# 0.504 perplexity: 48.020 speed: 2192 wps
# 0.604 perplexity: 46.463 speed: 2189 wps
# 0.703 perplexity: 45.788 speed: 2192 wps
# 0.803 perplexity: 45.077 speed: 2194 wps
# 0.903 perplexity: 43.613 speed: 2197 wps
# Epoch: 8 Train Perplexity: 42.772
# Epoch: 8 Valid Perplexity: 122.023
# Epoch: 9 Learning rate: 0.062
# 0.004 perplexity: 60.654 speed: 2260 wps
# 0.104 perplexity: 44.604 speed: 2202 wps
# 0.204 perplexity: 48.523 speed: 2212 wps
# 0.304 perplexity: 46.575 speed: 2227 wps
# 0.404 perplexity: 45.643 speed: 2232 wps
# 0.504 perplexity: 44.911 speed: 2233 wps
# 0.604 perplexity: 43.438 speed: 2233 wps
# 0.703 perplexity: 42.782 speed: 2234 wps
# 0.803 perplexity: 42.085 speed: 2235 wps
# 0.903 perplexity: 40.680 speed: 2232 wps
# Epoch: 9 Train Perplexity: 39.871
# Epoch: 9 Valid Perplexity: 122.914
# Epoch: 10 Learning rate: 0.031
# 0.004 perplexity: 58.527 speed: 2053 wps
# 0.104 perplexity: 43.038 speed: 2122 wps
# 0.204 perplexity: 46.818 speed: 2148 wps
# 0.304 perplexity: 44.909 speed: 2157 wps
# 0.404 perplexity: 44.009 speed: 2162 wps
# 0.504 perplexity: 43.290 speed: 2163 wps
# 0.604 perplexity: 41.867 speed: 2164 wps
# 0.703 perplexity: 41.223 speed: 2161 wps
# 0.803 perplexity: 40.530 speed: 2152 wps
# 0.903 perplexity: 39.151 speed: 2147 wps
# Epoch: 10 Train Perplexity: 38.357
# Epoch: 10 Valid Perplexity: 123.215
# Epoch: 11 Learning rate: 0.016
# 0.004 perplexity: 57.302 speed: 2184 wps
# 0.104 perplexity: 42.208 speed: 2149 wps
# 0.204 perplexity: 45.931 speed: 2146 wps
# 0.304 perplexity: 44.015 speed: 2146 wps
# 0.404 perplexity: 43.122 speed: 2148 wps
# 0.504 perplexity: 42.407 speed: 2142 wps
# 0.604 perplexity: 41.011 speed: 2136 wps
# 0.703 perplexity: 40.380 speed: 2137 wps
# 0.803 perplexity: 39.691 speed: 2137 wps
# 0.903 perplexity: 38.324 speed: 2137 wps
# Epoch: 11 Train Perplexity: 37.534
# Epoch: 11 Valid Perplexity: 123.107
# Epoch: 12 Learning rate: 0.008
# 0.004 perplexity: 56.606 speed: 2071 wps
# 0.104 perplexity: 41.714 speed: 2073 wps
# 0.204 perplexity: 45.416 speed: 2079 wps
# 0.304 perplexity: 43.505 speed: 2101 wps
# 0.404 perplexity: 42.620 speed: 2113 wps
# 0.504 perplexity: 41.911 speed: 2120 wps
# 0.604 perplexity: 40.532 speed: 2125 wps
# 0.703 perplexity: 39.907 speed: 2129 wps
# 0.803 perplexity: 39.224 speed: 2128 wps
# 0.903 perplexity: 37.865 speed: 2129 wps
# Epoch: 12 Train Perplexity: 37.077
# Epoch: 12 Valid Perplexity: 122.825
# Epoch: 13 Learning rate: 0.004
# 0.004 perplexity: 56.178 speed: 2112 wps
# 0.104 perplexity: 41.413 speed: 2133 wps
# 0.204 perplexity: 45.109 speed: 2105 wps
# 0.304 perplexity: 43.210 speed: 2094 wps
# 0.404 perplexity: 42.337 speed: 2086 wps
# 0.504 perplexity: 41.635 speed: 2078 wps
# 0.604 perplexity: 40.265 speed: 2080 wps
# 0.703 perplexity: 39.643 speed: 2085 wps
# 0.803 perplexity: 38.964 speed: 2086 wps
# 0.903 perplexity: 37.612 speed: 2090 wps
# Epoch: 13 Train Perplexity: 36.826
# Epoch: 13 Valid Perplexity: 122.561
# Test Perplexity: 117.959
