# %%
# %pylab
# %matplotlib inline
# %load_ext watermark
# %watermark -v -m -p numpy,tensorflow
# Out:
# Using matplotlib backend: Qt5Agg
# Populating the interactive namespace from numpy and matplotlib
# CPython 3.5.6
# IPython 6.5.0
#
# numpy 1.15.2
# tensorflow 1.12.0
#
# compiler   : GCC 7.3.0
# system     : Linux
# release    : 4.15.0-36-generic
# machine    : x86_64
# processor  : x86_64
# CPU cores  : 4
# interpreter: 64bit

# %% [markdown]
# 텐서플로 1.7.0 버전에서부터는 샘플 데이터를 다운로드하는 기능이 제외될 예정이라는 경고가 발생합니다. 경고를 무시하기 위해 로깅 설정을 변경합니다.

# %%
import tensorflow as tf
tf.logging.set_verbosity(tf.logging.ERROR)

# %%
import time
import tensorflow as tf
from tensorflow.contrib.rnn import BasicLSTMCell, MultiRNNCell, DropoutWrapper

import reader

# %% [markdown]
# Small Config 정보를 사용합니다.

# %%
class SmallConfig(object):
    """Small config."""
    init_scale = 0.1
    learning_rate = 1.0
    max_grad_norm = 5
    num_layers = 2
    num_steps = 20
    hidden_size = 200
    max_epoch = 4
    max_max_epoch = 13
    keep_prob = 1.0
    lr_decay = 0.5
    batch_size = 20
    vocab_size = 10000

# %% [markdown]
# 트레이닝과 테스트에 사용할 두개의 config 오브젝트를 만듭니다.

# %%
config = SmallConfig()
eval_config = SmallConfig()
eval_config.batch_size = 1
eval_config.num_steps = 1

# %% [markdown]
# PTB 모델을 만들어 주는 클래스를 작성합니다.

# %%
class PTBModel(object):
    """The PTB model."""

    def __init__(self, config, is_training=False):
        self.batch_size = config.batch_size
        self.num_steps = config.num_steps
        input_size = [config.batch_size, config.num_steps]
        self.input_data = tf.placeholder(tf.int32, input_size)
        self.targets = tf.placeholder(tf.int32, input_size)

        lstm_fn = lambda: BasicLSTMCell(config.hidden_size, forget_bias=0.0, state_is_tuple=True, 
                                        reuse=tf.get_variable_scope().reuse)
        # SmallConfig에서는 드롭아웃이 적용되지 않습니다.
        if is_training and config.keep_prob < 1:
            lstm_fn = lambda: DropoutWrapper(lstm_fn(), config.keep_prob)
        # 두개의 계층을 가진 신경망 구조를 만듭니다.
        cell = MultiRNNCell([lstm_fn() for _ in range(config.num_layers)], state_is_tuple=True)

        self.initial_state = cell.zero_state(config.batch_size, tf.float32)

        with tf.device("/cpu:0"):
            embedding_size = [config.vocab_size, config.hidden_size]
            embedding = tf.get_variable("embedding", embedding_size)
            inputs = tf.nn.embedding_lookup(embedding, self.input_data)

        # SmallConfig에서는 드롭아웃이 적용되지 않습니다.
        if is_training and config.keep_prob < 1:
            inputs = tf.nn.dropout(inputs, config.keep_prob)

        # 각 배치마다 순서대로 데이터를 뽑아 셀에 입력합니다. 
        outputs = []
        state = self.initial_state
        with tf.variable_scope("RNN"):
            for time_step in range(config.num_steps):
                if time_step > 0: tf.get_variable_scope().reuse_variables()
                (cell_output, state) = cell(inputs[:, time_step, :], state)
                outputs.append(cell_output)

        # output의 크기를 20x20x200에서 400x200으로 변경합니다.
        output = tf.reshape(tf.concat(outputs, 1), [-1, config.hidden_size])
        softmax_w_size = [config.hidden_size, config.vocab_size]
        softmax_w = tf.get_variable("softmax_w", softmax_w_size)
        softmax_b = tf.get_variable("softmax_b", [config.vocab_size])
        # logits의 크기는 400x10000이 됩니다.
        logits = tf.matmul(output, softmax_w) + softmax_b
    
        loss = tf.contrib.legacy_seq2seq.sequence_loss_by_example(
            [logits],
            [tf.reshape(self.targets, [-1])],
            [tf.ones([config.batch_size * config.num_steps])])
        self.cost = tf.reduce_sum(loss) / config.batch_size
        self.final_state = state

        if not is_training:
            return

        self.lr = tf.Variable(0.0, trainable=False)
        tvars = tf.trainable_variables()
        # 기울기 클리핑을 수행합니다.
        grads, _ = tf.clip_by_global_norm(tf.gradients(self.cost, tvars),
                                          config.max_grad_norm)
        optimizer = tf.train.GradientDescentOptimizer(self.lr)
        self.train_op = optimizer.apply_gradients(zip(grads, tvars))

    def assign_lr(self, session, lr_value):
        session.run(tf.assign(self.lr, lr_value))

# %% [markdown]
# 에포크를 처리할 함수를 만듭니다.

# %%
def run_epoch(session, m, data, is_training=False):
    """Runs the model on the given data."""
    epoch_size = ((len(data) // m.batch_size) - 1) // m.num_steps
    start_time = time.time()
    costs = 0.0
    iters = 0
    
    eval_op = m.train_op if is_training else tf.no_op()
    
    # initial_state는 2x20x200 크기의 튜플입니다.
    state_list = []
    for c, h in m.initial_state:
        state_list.extend([c.eval(), h.eval()])
    
    ptb_iter = reader.ptb_iterator(data, m.batch_size, m.num_steps)
    for step, (x, y) in enumerate(ptb_iter):
        fetch_list = [m.cost]
        # final_state 튜플에 담겨있는 상태를 꺼내어 fetch_list에 담습니다. 
        for c, h in m.final_state:
            fetch_list.extend([c, h])
        fetch_list.append(eval_op)
        
        # 이전 스텝에서 구해진 state_list가 feed_dict로 주입됩니다.
        feed_dict = {m.input_data: x, m.targets: y}
        for i in range(len(m.initial_state)):
            c, h = m.initial_state[i]
            feed_dict[c], feed_dict[h] = state_list[i*2:(i+1)*2]
        
        # fetch_list에 담긴 final_state의 결과를 state_list로 전달 받습니다.
        cost, *state_list, _ = session.run(fetch_list, feed_dict)

        costs += cost
        iters += m.num_steps

        if is_training and step % (epoch_size // 10) == 10:
            print("%.3f perplexity: %.3f speed: %.0f wps" %
                    (step * 1.0 / epoch_size, np.exp(costs / iters),
                     iters * m.batch_size / (time.time() - start_time)))

    return np.exp(costs / iters)

# %%
raw_data = reader.ptb_raw_data('simple-examples/data')
train_data, valid_data, test_data, _ = raw_data

# %% [markdown]
# train_data, valid_data, test_data 는 단어를 숫자로 바꾼 리스트입니다.
# 가장 많이 나온 단어 순으로 0번 부터 시작하여 10000번 까지의 번호를 가지고 있습니다.

# %%
with tf.Graph().as_default(), tf.Session() as session:
    initializer = tf.random_uniform_initializer(-config.init_scale, config.init_scale)

    # 학습과 검증, 테스트를 위한 모델을 만듭니다.
    with tf.variable_scope("model", reuse=None, initializer=initializer):
        m = PTBModel(config, is_training=True)
    with tf.variable_scope("model", reuse=True, initializer=initializer):
        mvalid = PTBModel(config)
        mtest = PTBModel(eval_config)
        
    tf.global_variables_initializer().run()
    
    for i in range(config.max_max_epoch):
        # lr_decay는 반복속도를 조절해 주는 역할을 합니다.
        lr_decay = config.lr_decay ** max(i - config.max_epoch, 0.0)
        m.assign_lr(session, config.learning_rate * lr_decay)
        print("Epoch: %d Learning rate: %.3f" % (i + 1, session.run(m.lr)))
        
        perplexity = run_epoch(session, m, train_data, is_training=True)
        print("Epoch: %d Train Perplexity: %.3f" % (i + 1, perplexity))

        perplexity = run_epoch(session, mvalid, valid_data)
        print("Epoch: %d Valid Perplexity: %.3f" % (i + 1, perplexity))

    perplexity = run_epoch(session, mtest, test_data)
    print("Test Perplexity: %.3f" % perplexity)
# Out:
# Epoch: 1 Learning rate: 1.000
# 0.004 perplexity: 5747.474 speed: 10137 wps
# 0.104 perplexity: 841.313 speed: 31427 wps
# 0.204 perplexity: 624.472 speed: 32993 wps
# 0.304 perplexity: 503.287 speed: 33756 wps
# 0.404 perplexity: 434.353 speed: 34086 wps
# 0.504 perplexity: 389.761 speed: 34263 wps
# 0.604 perplexity: 351.291 speed: 34330 wps
# 0.703 perplexity: 324.781 speed: 34437 wps
# 0.803 perplexity: 303.720 speed: 34546 wps
# 0.903 perplexity: 284.400 speed: 34337 wps
# Epoch: 1 Train Perplexity: 269.879
# Epoch: 1 Valid Perplexity: 179.698
# Epoch: 2 Learning rate: 1.000
# 0.004 perplexity: 212.897 speed: 26368 wps
# 0.104 perplexity: 151.360 speed: 34608 wps
# 0.204 perplexity: 158.601 speed: 34882 wps
# 0.304 perplexity: 153.633 speed: 34883 wps
# 0.404 perplexity: 150.759 speed: 34937 wps
# 0.504 perplexity: 148.298 speed: 34925 wps
# 0.604 perplexity: 143.663 speed: 34837 wps
# 0.703 perplexity: 141.441 speed: 34836 wps
# 0.803 perplexity: 139.381 speed: 34854 wps
# 0.903 perplexity: 135.748 speed: 34823 wps
# Epoch: 2 Train Perplexity: 133.676
# Epoch: 2 Valid Perplexity: 142.818
# Epoch: 3 Learning rate: 1.000
# 0.004 perplexity: 146.417 speed: 26222 wps
# 0.104 perplexity: 105.130 speed: 34468 wps
# 0.204 perplexity: 114.088 speed: 34614 wps
# 0.304 perplexity: 111.326 speed: 34764 wps
# 0.404 perplexity: 110.416 speed: 34797 wps
# 0.504 perplexity: 109.580 speed: 34627 wps
# 0.604 perplexity: 106.989 speed: 34607 wps
# 0.703 perplexity: 106.280 speed: 34647 wps
# 0.803 perplexity: 105.587 speed: 34678 wps
# 0.903 perplexity: 103.311 speed: 34648 wps
# Epoch: 3 Train Perplexity: 102.311
# Epoch: 3 Valid Perplexity: 131.683
# Epoch: 4 Learning rate: 1.000
# 0.004 perplexity: 115.602 speed: 24567 wps
# 0.104 perplexity: 85.295 speed: 34477 wps
# 0.204 perplexity: 93.515 speed: 34735 wps
# 0.304 perplexity: 91.415 speed: 34746 wps
# 0.404 perplexity: 90.929 speed: 34724 wps
# 0.504 perplexity: 90.603 speed: 34712 wps
# 0.604 perplexity: 88.808 speed: 34635 wps
# 0.703 perplexity: 88.504 speed: 34689 wps
# 0.803 perplexity: 88.232 speed: 34705 wps
# 0.903 perplexity: 86.564 speed: 34713 wps
# Epoch: 4 Train Perplexity: 85.918
# Epoch: 4 Valid Perplexity: 127.743
# Epoch: 5 Learning rate: 1.000
# 0.004 perplexity: 99.903 speed: 26522 wps
# 0.104 perplexity: 73.529 speed: 34351 wps
# 0.204 perplexity: 80.918 speed: 34440 wps
# 0.304 perplexity: 79.213 speed: 34400 wps
# 0.404 perplexity: 79.002 speed: 34419 wps
# 0.504 perplexity: 78.879 speed: 34555 wps
# 0.604 perplexity: 77.470 speed: 34503 wps
# 0.703 perplexity: 77.381 speed: 34545 wps
# 0.803 perplexity: 77.331 speed: 34563 wps
# 0.903 perplexity: 76.027 speed: 34616 wps
# Epoch: 5 Train Perplexity: 75.652
# Epoch: 5 Valid Perplexity: 126.175
# Epoch: 6 Learning rate: 0.500
# 0.004 perplexity: 88.903 speed: 26564 wps
# 0.104 perplexity: 64.413 speed: 33900 wps
# 0.204 perplexity: 69.661 speed: 34060 wps
# 0.304 perplexity: 67.105 speed: 34226 wps
# 0.404 perplexity: 66.072 speed: 34198 wps
# 0.504 perplexity: 65.157 speed: 34284 wps
# 0.604 perplexity: 63.215 speed: 34366 wps
# 0.703 perplexity: 62.471 speed: 34443 wps
# 0.803 perplexity: 61.742 speed: 34485 wps
# 0.903 perplexity: 60.011 speed: 34504 wps
# Epoch: 6 Train Perplexity: 59.049
# Epoch: 6 Valid Perplexity: 119.980
# Epoch: 7 Learning rate: 0.250
# 0.004 perplexity: 71.586 speed: 26617 wps
# 0.104 perplexity: 52.964 speed: 34463 wps
# 0.204 perplexity: 57.677 speed: 34466 wps
# 0.304 perplexity: 55.490 speed: 34411 wps
# 0.404 perplexity: 54.566 speed: 34428 wps
# 0.504 perplexity: 53.744 speed: 34529 wps
# 0.604 perplexity: 52.036 speed: 34540 wps
# 0.703 perplexity: 51.312 speed: 34583 wps
# 0.803 perplexity: 50.564 speed: 34600 wps
# 0.903 perplexity: 48.981 speed: 34589 wps
# Epoch: 7 Train Perplexity: 48.042
# Epoch: 7 Valid Perplexity: 121.128
# Epoch: 8 Learning rate: 0.125
# 0.004 perplexity: 63.726 speed: 26471 wps
# 0.104 perplexity: 46.959 speed: 34271 wps
# 0.204 perplexity: 51.303 speed: 34707 wps
# 0.304 perplexity: 49.294 speed: 34667 wps
# 0.404 perplexity: 48.433 speed: 34745 wps
# 0.504 perplexity: 47.676 speed: 34736 wps
# 0.604 perplexity: 46.107 speed: 34710 wps
# 0.703 perplexity: 45.424 speed: 34645 wps
# 0.803 perplexity: 44.697 speed: 34702 wps
# 0.903 perplexity: 43.226 speed: 34699 wps
# Epoch: 8 Train Perplexity: 42.337
# Epoch: 8 Valid Perplexity: 122.948
# Epoch: 9 Learning rate: 0.062
# 0.004 perplexity: 59.822 speed: 26603 wps
# 0.104 perplexity: 43.949 speed: 34428 wps
# 0.204 perplexity: 48.062 speed: 34489 wps
# 0.304 perplexity: 46.159 speed: 34616 wps
# 0.404 perplexity: 45.339 speed: 34738 wps
# 0.504 perplexity: 44.625 speed: 34761 wps
# 0.604 perplexity: 43.121 speed: 34744 wps
# 0.703 perplexity: 42.458 speed: 34732 wps
# 0.803 perplexity: 41.749 speed: 34698 wps
# 0.903 perplexity: 40.345 speed: 34678 wps
# Epoch: 9 Train Perplexity: 39.487
# Epoch: 9 Valid Perplexity: 123.886
# Epoch: 10 Learning rate: 0.031
# 0.004 perplexity: 57.762 speed: 25759 wps
# 0.104 perplexity: 42.402 speed: 34225 wps
# 0.204 perplexity: 46.382 speed: 34549 wps
# 0.304 perplexity: 44.544 speed: 34502 wps
# 0.404 perplexity: 43.749 speed: 34562 wps
# 0.504 perplexity: 43.055 speed: 34516 wps
# 0.604 perplexity: 41.583 speed: 34574 wps
# 0.703 perplexity: 40.930 speed: 34605 wps
# 0.803 perplexity: 40.228 speed: 34639 wps
# 0.903 perplexity: 38.855 speed: 34647 wps
# Epoch: 10 Train Perplexity: 38.009
# Epoch: 10 Valid Perplexity: 123.993
# Epoch: 11 Learning rate: 0.016
# 0.004 perplexity: 56.704 speed: 26445 wps
# 0.104 perplexity: 41.560 speed: 34284 wps
# 0.204 perplexity: 45.453 speed: 34433 wps
# 0.304 perplexity: 43.652 speed: 34475 wps
# 0.404 perplexity: 42.874 speed: 34435 wps
# 0.504 perplexity: 42.195 speed: 34536 wps
# 0.604 perplexity: 40.740 speed: 34610 wps
# 0.703 perplexity: 40.094 speed: 34601 wps
# 0.803 perplexity: 39.397 speed: 34593 wps
# 0.903 perplexity: 38.041 speed: 34649 wps
# Epoch: 11 Train Perplexity: 37.202
# Epoch: 11 Valid Perplexity: 123.605
# Epoch: 12 Learning rate: 0.008
# 0.004 perplexity: 56.006 speed: 26604 wps
# 0.104 perplexity: 41.053 speed: 34471 wps
# 0.204 perplexity: 44.907 speed: 34401 wps
# 0.304 perplexity: 43.129 speed: 34646 wps
# 0.404 perplexity: 42.367 speed: 34807 wps
# 0.504 perplexity: 41.698 speed: 34787 wps
# 0.604 perplexity: 40.258 speed: 34733 wps
# 0.703 perplexity: 39.618 speed: 34715 wps
# 0.803 perplexity: 38.928 speed: 34677 wps
# 0.903 perplexity: 37.583 speed: 34680 wps
# Epoch: 12 Train Perplexity: 36.749
# Epoch: 12 Valid Perplexity: 123.147
# Epoch: 13 Learning rate: 0.004
# 0.004 perplexity: 55.592 speed: 26368 wps
# 0.104 perplexity: 40.756 speed: 34515 wps
# 0.204 perplexity: 44.591 speed: 34687 wps
# 0.304 perplexity: 42.827 speed: 34688 wps
# 0.404 perplexity: 42.075 speed: 34726 wps
# 0.504 perplexity: 41.414 speed: 34763 wps
# 0.604 perplexity: 39.986 speed: 34725 wps
# 0.703 perplexity: 39.349 speed: 34708 wps
# 0.803 perplexity: 38.666 speed: 34675 wps
# 0.903 perplexity: 37.327 speed: 34656 wps
# Epoch: 13 Train Perplexity: 36.498
# Epoch: 13 Valid Perplexity: 122.840
# Test Perplexity: 117.949
