# %%
# %pylab
# %matplotlib inline
# %load_ext watermark
# %watermark -v -m -p numpy,tensorflow
# Out:
# Using matplotlib backend: Qt5Agg
# Populating the interactive namespace from numpy and matplotlib
# CPython 3.5.5
# IPython 6.2.1
#
# numpy 1.14.2
# tensorflow 1.7.0
#
# compiler   : GCC 7.2.0
# system     : Linux
# release    : 4.13.0-37-generic
# machine    : x86_64
# processor  : x86_64
# CPU cores  : 4
# interpreter: 64bit

# %% [markdown]
# 텐서플로 1.7.0 버전에서부터는 샘플 데이터를 다운로드하는 기능이 제외될 예정이라는 경고가 발생합니다. 경고를 무시하기 위해 로깅 설정을 변경합니다.

# %%
import tensorflow as tf
tf.logging.set_verbosity(tf.logging.ERROR)

# %%
import time
import tensorflow as tf
from tensorflow.contrib.rnn import BasicLSTMCell, MultiRNNCell, DropoutWrapper

import reader

# %% [markdown]
# Small Config 정보를 사용합니다.

# %%
class SmallConfig(object):
    """Small config."""
    init_scale = 0.1
    learning_rate = 1.0
    max_grad_norm = 5
    num_layers = 2
    num_steps = 20
    hidden_size = 200
    max_epoch = 4
    max_max_epoch = 13
    keep_prob = 1.0
    lr_decay = 0.5
    batch_size = 20
    vocab_size = 10000

# %% [markdown]
# 트레이닝과 테스트에 사용할 두개의 config 오브젝트를 만듭니다.

# %%
config = SmallConfig()
eval_config = SmallConfig()
eval_config.batch_size = 1
eval_config.num_steps = 1

# %% [markdown]
# PTB 모델을 만들어 주는 클래스를 작성합니다.

# %%
class PTBModel(object):
    """The PTB model."""

    def __init__(self, config, is_training=False):
        self.batch_size = config.batch_size
        self.num_steps = config.num_steps
        input_size = [config.batch_size, config.num_steps]
        self.input_data = tf.placeholder(tf.int32, input_size)
        self.targets = tf.placeholder(tf.int32, input_size)

        lstm_fn = lambda: BasicLSTMCell(config.hidden_size, forget_bias=0.0, state_is_tuple=True, 
                                        reuse=tf.get_variable_scope().reuse)
        # SmallConfig에서는 드롭아웃이 적용되지 않습니다.
        if is_training and config.keep_prob < 1:
            lstm_fn = lambda: DropoutWrapper(lstm_fn(), config.keep_prob)
        # 두개의 계층을 가진 신경망 구조를 만듭니다.
        cell = MultiRNNCell([lstm_fn() for _ in range(config.num_layers)], state_is_tuple=True)

        self.initial_state = cell.zero_state(config.batch_size, tf.float32)

        with tf.device("/cpu:0"):
            embedding_size = [config.vocab_size, config.hidden_size]
            embedding = tf.get_variable("embedding", embedding_size)
            inputs = tf.nn.embedding_lookup(embedding, self.input_data)

        # SmallConfig에서는 드롭아웃이 적용되지 않습니다.
        if is_training and config.keep_prob < 1:
            inputs = tf.nn.dropout(inputs, config.keep_prob)

        # 각 배치마다 순서대로 데이터를 뽑아 셀에 입력합니다. 
        outputs = []
        state = self.initial_state
        with tf.variable_scope("RNN"):
            for time_step in range(config.num_steps):
                if time_step > 0: tf.get_variable_scope().reuse_variables()
                (cell_output, state) = cell(inputs[:, time_step, :], state)
                outputs.append(cell_output)

        # output의 크기를 20x20x200에서 400x200으로 변경합니다.
        output = tf.reshape(tf.concat(outputs, 1), [-1, config.hidden_size])
        softmax_w_size = [config.hidden_size, config.vocab_size]
        softmax_w = tf.get_variable("softmax_w", softmax_w_size)
        softmax_b = tf.get_variable("softmax_b", [config.vocab_size])
        # logits의 크기는 400x10000이 됩니다.
        logits = tf.matmul(output, softmax_w) + softmax_b
    
        loss = tf.contrib.legacy_seq2seq.sequence_loss_by_example(
            [logits],
            [tf.reshape(self.targets, [-1])],
            [tf.ones([config.batch_size * config.num_steps])])
        self.cost = tf.reduce_sum(loss) / config.batch_size
        self.final_state = state

        if not is_training:
            return

        self.lr = tf.Variable(0.0, trainable=False)
        tvars = tf.trainable_variables()
        # 기울기 클리핑을 수행합니다.
        grads, _ = tf.clip_by_global_norm(tf.gradients(self.cost, tvars),
                                          config.max_grad_norm)
        optimizer = tf.train.GradientDescentOptimizer(self.lr)
        self.train_op = optimizer.apply_gradients(zip(grads, tvars))

    def assign_lr(self, session, lr_value):
        session.run(tf.assign(self.lr, lr_value))

# %% [markdown]
# 에포크를 처리할 함수를 만듭니다.

# %%
def run_epoch(session, m, data, is_training=False):
    """Runs the model on the given data."""
    epoch_size = ((len(data) // m.batch_size) - 1) // m.num_steps
    start_time = time.time()
    costs = 0.0
    iters = 0
    
    eval_op = m.train_op if is_training else tf.no_op()
    
    # initial_state는 2x20x200 크기의 튜플입니다.
    state_list = []
    for c, h in m.initial_state:
        state_list.extend([c.eval(), h.eval()])
    
    ptb_iter = reader.ptb_iterator(data, m.batch_size, m.num_steps)
    for step, (x, y) in enumerate(ptb_iter):
        fetch_list = [m.cost]
        # final_state 튜플에 담겨있는 상태를 꺼내어 fetch_list에 담습니다. 
        for c, h in m.final_state:
            fetch_list.extend([c, h])
        fetch_list.append(eval_op)
        
        # 이전 스텝에서 구해진 state_list가 feed_dict로 주입됩니다.
        feed_dict = {m.input_data: x, m.targets: y}
        for i in range(len(m.initial_state)):
            c, h = m.initial_state[i]
            feed_dict[c], feed_dict[h] = state_list[i*2:(i+1)*2]
        
        # fetch_list에 담긴 final_state의 결과를 state_list로 전달 받습니다.
        cost, *state_list, _ = session.run(fetch_list, feed_dict)

        costs += cost
        iters += m.num_steps

        if is_training and step % (epoch_size // 10) == 10:
            print("%.3f perplexity: %.3f speed: %.0f wps" %
                    (step * 1.0 / epoch_size, np.exp(costs / iters),
                     iters * m.batch_size / (time.time() - start_time)))

    return np.exp(costs / iters)

# %%
raw_data = reader.ptb_raw_data('simple-examples/data')
train_data, valid_data, test_data, _ = raw_data

# %% [markdown]
# train_data, valid_data, test_data 는 단어를 숫자로 바꾼 리스트입니다.
# 가장 많이 나온 단어 순으로 0번 부터 시작하여 10000번 까지의 번호를 가지고 있습니다.

# %%
with tf.Graph().as_default(), tf.Session() as session:
    initializer = tf.random_uniform_initializer(-config.init_scale, config.init_scale)

    # 학습과 검증, 테스트를 위한 모델을 만듭니다.
    with tf.variable_scope("model", reuse=None, initializer=initializer):
        m = PTBModel(config, is_training=True)
    with tf.variable_scope("model", reuse=True, initializer=initializer):
        mvalid = PTBModel(config)
        mtest = PTBModel(eval_config)
        
    tf.global_variables_initializer().run()
    
    for i in range(config.max_max_epoch):
        # lr_decay는 반복속도를 조절해 주는 역할을 합니다.
        lr_decay = config.lr_decay ** max(i - config.max_epoch, 0.0)
        m.assign_lr(session, config.learning_rate * lr_decay)
        print("Epoch: %d Learning rate: %.3f" % (i + 1, session.run(m.lr)))
        
        perplexity = run_epoch(session, m, train_data, is_training=True)
        print("Epoch: %d Train Perplexity: %.3f" % (i + 1, perplexity))

        perplexity = run_epoch(session, mvalid, valid_data)
        print("Epoch: %d Valid Perplexity: %.3f" % (i + 1, perplexity))

    perplexity = run_epoch(session, mtest, test_data)
    print("Test Perplexity: %.3f" % perplexity)
# Out:
# Epoch: 1 Learning rate: 1.000
# 0.004 perplexity: 5967.177 speed: 11015 wps
# 0.104 perplexity: 843.986 speed: 31510 wps
# 0.204 perplexity: 622.193 speed: 32945 wps
# 0.304 perplexity: 501.637 speed: 33325 wps
# 0.404 perplexity: 433.285 speed: 33402 wps
# 0.504 perplexity: 388.398 speed: 33559 wps
# 0.604 perplexity: 350.193 speed: 33706 wps
# 0.703 perplexity: 323.880 speed: 33856 wps
# 0.803 perplexity: 303.241 speed: 33945 wps
# 0.903 perplexity: 284.278 speed: 33987 wps
# Epoch: 1 Train Perplexity: 269.904
# Epoch: 1 Valid Perplexity: 180.231
# Epoch: 2 Learning rate: 1.000
# 0.004 perplexity: 212.794 speed: 27121 wps
# 0.104 perplexity: 152.260 speed: 34193 wps
# 0.204 perplexity: 159.413 speed: 34330 wps
# 0.304 perplexity: 154.295 speed: 34324 wps
# 0.404 perplexity: 151.403 speed: 34394 wps
# 0.504 perplexity: 148.989 speed: 34470 wps
# 0.604 perplexity: 144.342 speed: 34461 wps
# 0.703 perplexity: 142.309 speed: 34427 wps
# 0.803 perplexity: 140.329 speed: 34459 wps
# 0.903 perplexity: 136.656 speed: 34435 wps
# Epoch: 2 Train Perplexity: 134.553
# Epoch: 2 Valid Perplexity: 143.699
# Epoch: 3 Learning rate: 1.000
# 0.004 perplexity: 142.981 speed: 27626 wps
# 0.104 perplexity: 106.046 speed: 34072 wps
# 0.204 perplexity: 115.142 speed: 34227 wps
# 0.304 perplexity: 112.153 speed: 34323 wps
# 0.404 perplexity: 111.252 speed: 34269 wps
# 0.504 perplexity: 110.441 speed: 34275 wps
# 0.604 perplexity: 107.846 speed: 34339 wps
# 0.703 perplexity: 107.257 speed: 34437 wps
# 0.803 perplexity: 106.645 speed: 34466 wps
# 0.903 perplexity: 104.393 speed: 34522 wps
# Epoch: 3 Train Perplexity: 103.446
# Epoch: 3 Valid Perplexity: 132.543
# Epoch: 4 Learning rate: 1.000
# 0.004 perplexity: 116.487 speed: 26927 wps
# 0.104 perplexity: 86.062 speed: 33353 wps
# 0.204 perplexity: 94.548 speed: 33551 wps
# 0.304 perplexity: 92.156 speed: 33901 wps
# 0.404 perplexity: 91.825 speed: 34099 wps
# 0.504 perplexity: 91.424 speed: 34158 wps
# 0.604 perplexity: 89.564 speed: 34183 wps
# 0.703 perplexity: 89.412 speed: 34231 wps
# 0.803 perplexity: 89.140 speed: 34333 wps
# 0.903 perplexity: 87.488 speed: 34305 wps
# Epoch: 4 Train Perplexity: 86.918
# Epoch: 4 Valid Perplexity: 128.193
# Epoch: 5 Learning rate: 1.000
# 0.004 perplexity: 98.003 speed: 26518 wps
# 0.104 perplexity: 74.187 speed: 33863 wps
# 0.204 perplexity: 81.872 speed: 34300 wps
# 0.304 perplexity: 79.980 speed: 34189 wps
# 0.404 perplexity: 79.888 speed: 34218 wps
# 0.504 perplexity: 79.782 speed: 34303 wps
# 0.604 perplexity: 78.371 speed: 34339 wps
# 0.703 perplexity: 78.345 speed: 34404 wps
# 0.803 perplexity: 78.297 speed: 34336 wps
# 0.903 perplexity: 77.046 speed: 34356 wps
# Epoch: 5 Train Perplexity: 76.690
# Epoch: 5 Valid Perplexity: 127.620
# Epoch: 6 Learning rate: 0.500
# 0.004 perplexity: 87.976 speed: 27336 wps
# 0.104 perplexity: 64.544 speed: 34351 wps
# 0.204 perplexity: 70.194 speed: 34329 wps
# 0.304 perplexity: 67.509 speed: 34178 wps
# 0.404 perplexity: 66.623 speed: 34427 wps
# 0.504 perplexity: 65.783 speed: 34322 wps
# 0.604 perplexity: 63.881 speed: 34336 wps
# 0.703 perplexity: 63.178 speed: 34367 wps
# 0.803 perplexity: 62.460 speed: 34316 wps
# 0.903 perplexity: 60.757 speed: 34438 wps
# Epoch: 6 Train Perplexity: 59.848
# Epoch: 6 Valid Perplexity: 120.405
# Epoch: 7 Learning rate: 0.250
# 0.004 perplexity: 71.687 speed: 27735 wps
# 0.104 perplexity: 53.536 speed: 34493 wps
# 0.204 perplexity: 58.294 speed: 34754 wps
# 0.304 perplexity: 55.980 speed: 34805 wps
# 0.404 perplexity: 55.145 speed: 34524 wps
# 0.504 perplexity: 54.342 speed: 34583 wps
# 0.604 perplexity: 52.670 speed: 34516 wps
# 0.703 perplexity: 51.978 speed: 34571 wps
# 0.803 perplexity: 51.253 speed: 34577 wps
# 0.903 perplexity: 49.670 speed: 34535 wps
# Epoch: 7 Train Perplexity: 48.765
# Epoch: 7 Valid Perplexity: 120.610
# Epoch: 8 Learning rate: 0.125
# 0.004 perplexity: 63.569 speed: 26481 wps
# 0.104 perplexity: 47.631 speed: 34194 wps
# 0.204 perplexity: 51.858 speed: 34474 wps
# 0.304 perplexity: 49.739 speed: 34402 wps
# 0.404 perplexity: 48.974 speed: 34403 wps
# 0.504 perplexity: 48.221 speed: 34400 wps
# 0.604 perplexity: 46.689 speed: 34467 wps
# 0.703 perplexity: 46.042 speed: 34396 wps
# 0.803 perplexity: 45.347 speed: 34445 wps
# 0.903 perplexity: 43.867 speed: 34435 wps
# Epoch: 8 Train Perplexity: 43.005
# Epoch: 8 Valid Perplexity: 122.241
# Epoch: 9 Learning rate: 0.062
# 0.004 perplexity: 59.549 speed: 27259 wps
# 0.104 perplexity: 44.593 speed: 34221 wps
# 0.204 perplexity: 48.589 speed: 34248 wps
# 0.304 perplexity: 46.586 speed: 34248 wps
# 0.404 perplexity: 45.841 speed: 34309 wps
# 0.504 perplexity: 45.131 speed: 34375 wps
# 0.604 perplexity: 43.674 speed: 34494 wps
# 0.703 perplexity: 43.048 speed: 34497 wps
# 0.803 perplexity: 42.370 speed: 34498 wps
# 0.903 perplexity: 40.958 speed: 34449 wps
# Epoch: 9 Train Perplexity: 40.116
# Epoch: 9 Valid Perplexity: 123.354
# Epoch: 10 Learning rate: 0.031
# 0.004 perplexity: 57.392 speed: 26980 wps
# 0.104 perplexity: 42.952 speed: 34194 wps
# 0.204 perplexity: 46.879 speed: 34305 wps
# 0.304 perplexity: 44.948 speed: 34521 wps
# 0.404 perplexity: 44.232 speed: 34360 wps
# 0.504 perplexity: 43.548 speed: 34404 wps
# 0.604 perplexity: 42.134 speed: 34427 wps
# 0.703 perplexity: 41.510 speed: 34433 wps
# 0.803 perplexity: 40.829 speed: 34352 wps
# 0.903 perplexity: 39.456 speed: 34368 wps
# Epoch: 10 Train Perplexity: 38.627
# Epoch: 10 Valid Perplexity: 123.492
# Epoch: 11 Learning rate: 0.016
# 0.004 perplexity: 56.106 speed: 27278 wps
# 0.104 perplexity: 41.974 speed: 34022 wps
# 0.204 perplexity: 45.870 speed: 34131 wps
# 0.304 perplexity: 43.999 speed: 34299 wps
# 0.404 perplexity: 43.311 speed: 34467 wps
# 0.504 perplexity: 42.657 speed: 34571 wps
# 0.604 perplexity: 41.274 speed: 34675 wps
# 0.703 perplexity: 40.654 speed: 34570 wps
# 0.803 perplexity: 39.975 speed: 34542 wps
# 0.903 perplexity: 38.622 speed: 34617 wps
# Epoch: 11 Train Perplexity: 37.802
# Epoch: 11 Valid Perplexity: 123.271
# Epoch: 12 Learning rate: 0.008
# 0.004 perplexity: 55.374 speed: 27506 wps
# 0.104 perplexity: 41.425 speed: 34125 wps
# 0.204 perplexity: 45.289 speed: 34364 wps
# 0.304 perplexity: 43.446 speed: 34618 wps
# 0.404 perplexity: 42.776 speed: 34589 wps
# 0.504 perplexity: 42.141 speed: 34528 wps
# 0.604 perplexity: 40.777 speed: 34533 wps
# 0.703 perplexity: 40.163 speed: 34517 wps
# 0.803 perplexity: 39.490 speed: 34539 wps
# 0.903 perplexity: 38.149 speed: 34590 wps
# Epoch: 12 Train Perplexity: 37.336
# Epoch: 12 Valid Perplexity: 122.925
# Epoch: 13 Learning rate: 0.004
# 0.004 perplexity: 54.954 speed: 27336 wps
# 0.104 perplexity: 41.115 speed: 33903 wps
# 0.204 perplexity: 44.966 speed: 34107 wps
# 0.304 perplexity: 43.139 speed: 34380 wps
# 0.404 perplexity: 42.481 speed: 34527 wps
# 0.504 perplexity: 41.854 speed: 34621 wps
# 0.604 perplexity: 40.503 speed: 34566 wps
# 0.703 perplexity: 39.892 speed: 34587 wps
# 0.803 perplexity: 39.223 speed: 34622 wps
# 0.903 perplexity: 37.889 speed: 34553 wps
# Epoch: 13 Train Perplexity: 37.081
# Epoch: 13 Valid Perplexity: 122.620
# Test Perplexity: 116.965
