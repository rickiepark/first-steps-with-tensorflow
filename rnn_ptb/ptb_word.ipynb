# %%
# %pylab
# %matplotlib inline
# %load_ext watermark
# %watermark -v -m -p numpy,tensorflow
# Out:
# Using matplotlib backend: MacOSX
# Populating the interactive namespace from numpy and matplotlib
# CPython 3.5.2
# IPython 5.1.0
#
# numpy 1.11.3
# tensorflow 0.12.0
#
# compiler   : GCC 4.2.1 Compatible Apple LLVM 4.2 (clang-425.0.28)
# system     : Darwin
# release    : 16.3.0
# machine    : x86_64
# processor  : i386
# CPU cores  : 8
# interpreter: 64bit

# %%
import time
import tensorflow as tf
from tensorflow.python.ops.rnn_cell import BasicLSTMCell, MultiRNNCell, DropoutWrapper

import reader

# %% [markdown]
# Small Config 정보를 사용합니다.

# %%
class SmallConfig(object):
    """Small config."""
    init_scale = 0.1
    learning_rate = 1.0
    max_grad_norm = 5
    num_layers = 2
    num_steps = 20
    hidden_size = 200
    max_epoch = 4
    max_max_epoch = 13
    keep_prob = 1.0
    lr_decay = 0.5
    batch_size = 20
    vocab_size = 10000

# %% [markdown]
# 트레이닝과 테스트에 사용할 두개의 config 오브젝트를 만듭니다.

# %%
config = SmallConfig()
eval_config = SmallConfig()
eval_config.batch_size = 1
eval_config.num_steps = 1

# %% [markdown]
# PTB 모델을 만들어 주는 클래스를 작성합니다.

# %%
class PTBModel(object):
    """The PTB model."""

    def __init__(self, config, is_training=False):
        self.batch_size = config.batch_size
        self.num_steps = config.num_steps
        input_size = [config.batch_size, config.num_steps]
        self.input_data = tf.placeholder(tf.int32, input_size)
        self.targets = tf.placeholder(tf.int32, input_size)

        lstm_cell = BasicLSTMCell(config.hidden_size, forget_bias=0.0, state_is_tuple=True)
        # SmallConfig에서는 드롭아웃이 적용되지 않습니다.
        if is_training and config.keep_prob < 1:
            lstm_cell = DropoutWrapper(lstm_cell, config.keep_prob)
        # 두개의 계층을 가진 신경망 구조를 만듭니다.
        cell = MultiRNNCell([lstm_cell] * config.num_layers, state_is_tuple=True)

        self.initial_state = cell.zero_state(config.batch_size, tf.float32)

        with tf.device("/cpu:0"):
            embedding_size = [config.vocab_size, config.hidden_size]
            embedding = tf.get_variable("embedding", embedding_size)
            inputs = tf.nn.embedding_lookup(embedding, self.input_data)

        # SmallConfig에서는 드롭아웃이 적용되지 않습니다.
        if is_training and config.keep_prob < 1:
            inputs = tf.nn.dropout(inputs, config.keep_prob)

        # 각 배치마다 순서대로 데이터를 뽑아 셀에 입력합니다. 
        outputs = []
        state = self.initial_state
        with tf.variable_scope("RNN"):
            for time_step in range(config.num_steps):
                if time_step > 0: tf.get_variable_scope().reuse_variables()
                (cell_output, state) = cell(inputs[:, time_step, :], state)
                outputs.append(cell_output)

        # output의 크기를 20x20x200에서 400x200으로 변경합니다.
        output = tf.reshape(tf.concat(1, outputs), [-1, config.hidden_size])
        softmax_w_size = [config.hidden_size, config.vocab_size]
        softmax_w = tf.get_variable("softmax_w", softmax_w_size)
        softmax_b = tf.get_variable("softmax_b", [config.vocab_size])
        # logits의 크기는 400x10000이 됩니다.
        logits = tf.matmul(output, softmax_w) + softmax_b
    
        loss = tf.nn.seq2seq.sequence_loss_by_example(
            [logits],
            [tf.reshape(self.targets, [-1])],
            [tf.ones([config.batch_size * config.num_steps])])
        self.cost = tf.reduce_sum(loss) / config.batch_size
        self.final_state = state

        if not is_training:
            return

        self.lr = tf.Variable(0.0, trainable=False)
        tvars = tf.trainable_variables()
        # 기울기 클리핑을 수행합니다.
        grads, _ = tf.clip_by_global_norm(tf.gradients(self.cost, tvars),
                                          config.max_grad_norm)
        optimizer = tf.train.GradientDescentOptimizer(self.lr)
        self.train_op = optimizer.apply_gradients(zip(grads, tvars))

    def assign_lr(self, session, lr_value):
        session.run(tf.assign(self.lr, lr_value))

# %% [markdown]
# 에포크를 처리할 함수를 만듭니다.

# %%
def run_epoch(session, m, data, is_training=False):
    """Runs the model on the given data."""
    epoch_size = ((len(data) // m.batch_size) - 1) // m.num_steps
    start_time = time.time()
    costs = 0.0
    iters = 0
    
    eval_op = m.train_op if is_training else tf.no_op()
    
    # initial_state는 2x20x200 크기의 튜플입니다.
    state_list = []
    for c, h in m.initial_state:
        state_list.extend([c.eval(), h.eval()])
    
    ptb_iter = reader.ptb_iterator(data, m.batch_size, m.num_steps)
    for step, (x, y) in enumerate(ptb_iter):
        fetch_list = [m.cost]
        # final_state 튜플에 담겨있는 상태를 꺼내어 fetch_list에 담습니다. 
        for c, h in m.final_state:
            fetch_list.extend([c, h])
        fetch_list.append(eval_op)
        
        # 이전 스텝에서 구해진 state_list가 feed_dict로 주입됩니다.
        feed_dict = {m.input_data: x, m.targets: y}
        for i in range(len(m.initial_state)):
            c, h = m.initial_state[i]
            feed_dict[c], feed_dict[h] = state_list[i*2:(i+1)*2]
        
        # fetch_list에 담긴 final_state의 결과를 state_list로 전달 받습니다.
        cost, *state_list, _ = session.run(fetch_list, feed_dict)

        costs += cost
        iters += m.num_steps

        if is_training and step % (epoch_size // 10) == 10:
            print("%.3f perplexity: %.3f speed: %.0f wps" %
                    (step * 1.0 / epoch_size, np.exp(costs / iters),
                     iters * m.batch_size / (time.time() - start_time)))

    return np.exp(costs / iters)

# %%
raw_data = reader.ptb_raw_data('simple-examples/data')
train_data, valid_data, test_data, _ = raw_data

# %% [markdown]
# train_data, valid_data, test_data 는 단어를 숫자로 바꾼 리스트입니다.
# 가장 많이 나온 단어 순으로 0번 부터 시작하여 10000번 까지의 번호를 가지고 있습니다.

# %%
with tf.Graph().as_default(), tf.Session() as session:
    initializer = tf.random_uniform_initializer(-config.init_scale, config.init_scale)

    # 학습과 검증, 테스트를 위한 모델을 만듭니다.
    with tf.variable_scope("model", reuse=None, initializer=initializer):
        m = PTBModel(config, is_training=True)
    with tf.variable_scope("model", reuse=True, initializer=initializer):
        mvalid = PTBModel(config)
        mtest = PTBModel(eval_config)
        
    tf.global_variables_initializer().run()
    
    for i in range(config.max_max_epoch):
        # lr_decay는 반복속도를 조절해 주는 역할을 합니다.
        lr_decay = config.lr_decay ** max(i - config.max_epoch, 0.0)
        m.assign_lr(session, config.learning_rate * lr_decay)
        print("Epoch: %d Learning rate: %.3f" % (i + 1, session.run(m.lr)))
        
        perplexity = run_epoch(session, m, train_data, is_training=True)
        print("Epoch: %d Train Perplexity: %.3f" % (i + 1, perplexity))

        perplexity = run_epoch(session, mvalid, valid_data)
        print("Epoch: %d Valid Perplexity: %.3f" % (i + 1, perplexity))

    perplexity = run_epoch(session, mtest, test_data)
    print("Test Perplexity: %.3f" % perplexity)
# Out:
# Epoch: 1 Learning rate: 1.000
# 0.004 perplexity: 5787.117 speed: 1934 wps
# 0.104 perplexity: 836.493 speed: 1951 wps
# 0.204 perplexity: 622.175 speed: 1893 wps
# 0.304 perplexity: 503.282 speed: 1887 wps
# 0.404 perplexity: 434.008 speed: 1887 wps
# 0.504 perplexity: 388.954 speed: 1901 wps
# 0.604 perplexity: 350.315 speed: 1900 wps
# 0.703 perplexity: 323.845 speed: 1880 wps
# 0.803 perplexity: 302.948 speed: 1884 wps
# 0.903 perplexity: 283.770 speed: 1887 wps
# Epoch: 1 Train Perplexity: 269.330
# Epoch: 1 Valid Perplexity: 179.157
# Epoch: 2 Learning rate: 1.000
# 0.004 perplexity: 212.502 speed: 1923 wps
# 0.104 perplexity: 151.675 speed: 1905 wps
# 0.204 perplexity: 159.052 speed: 1902 wps
# 0.304 perplexity: 154.010 speed: 1899 wps
# 0.404 perplexity: 150.944 speed: 1895 wps
# 0.504 perplexity: 148.330 speed: 1897 wps
# 0.604 perplexity: 143.634 speed: 1894 wps
# 0.703 perplexity: 141.421 speed: 1890 wps
# 0.803 perplexity: 139.461 speed: 1886 wps
# 0.903 perplexity: 135.793 speed: 1883 wps
# Epoch: 2 Train Perplexity: 133.653
# Epoch: 2 Valid Perplexity: 146.045
# Epoch: 3 Learning rate: 1.000
# 0.004 perplexity: 145.637 speed: 1933 wps
# 0.104 perplexity: 105.456 speed: 1918 wps
# 0.204 perplexity: 114.322 speed: 1918 wps
# 0.304 perplexity: 111.498 speed: 1912 wps
# 0.404 perplexity: 110.397 speed: 1907 wps
# 0.504 perplexity: 109.468 speed: 1897 wps
# 0.604 perplexity: 106.793 speed: 1899 wps
# 0.703 perplexity: 106.145 speed: 1897 wps
# 0.803 perplexity: 105.557 speed: 1884 wps
# 0.903 perplexity: 103.315 speed: 1873 wps
# Epoch: 3 Train Perplexity: 102.273
# Epoch: 3 Valid Perplexity: 133.241
# Epoch: 4 Learning rate: 1.000
# 0.004 perplexity: 115.325 speed: 1837 wps
# 0.104 perplexity: 85.301 speed: 1846 wps
# 0.204 perplexity: 93.656 speed: 1832 wps
# 0.304 perplexity: 91.392 speed: 1826 wps
# 0.404 perplexity: 90.882 speed: 1844 wps
# 0.504 perplexity: 90.489 speed: 1849 wps
# 0.604 perplexity: 88.617 speed: 1854 wps
# 0.703 perplexity: 88.398 speed: 1856 wps
# 0.803 perplexity: 88.206 speed: 1844 wps
# 0.903 perplexity: 86.612 speed: 1850 wps
# Epoch: 4 Train Perplexity: 86.030
# Epoch: 4 Valid Perplexity: 127.971
# Epoch: 5 Learning rate: 1.000
# 0.004 perplexity: 97.598 speed: 1836 wps
# 0.104 perplexity: 73.834 speed: 1859 wps
# 0.204 perplexity: 81.312 speed: 1868 wps
# 0.304 perplexity: 79.369 speed: 1872 wps
# 0.404 perplexity: 79.138 speed: 1890 wps
# 0.504 perplexity: 78.983 speed: 1885 wps
# 0.604 perplexity: 77.634 speed: 1880 wps
# 0.703 perplexity: 77.656 speed: 1881 wps
# 0.803 perplexity: 77.646 speed: 1884 wps
# 0.903 perplexity: 76.364 speed: 1887 wps
# Epoch: 5 Train Perplexity: 76.019
# Epoch: 5 Valid Perplexity: 128.072
# Epoch: 6 Learning rate: 0.500
# 0.004 perplexity: 88.162 speed: 1818 wps
# 0.104 perplexity: 64.258 speed: 1879 wps
# 0.204 perplexity: 69.545 speed: 1873 wps
# 0.304 perplexity: 66.890 speed: 1873 wps
# 0.404 perplexity: 65.799 speed: 1877 wps
# 0.504 perplexity: 64.961 speed: 1871 wps
# 0.604 perplexity: 63.100 speed: 1871 wps
# 0.703 perplexity: 62.498 speed: 1871 wps
# 0.803 perplexity: 61.838 speed: 1872 wps
# 0.903 perplexity: 60.168 speed: 1877 wps
# Epoch: 6 Train Perplexity: 59.264
# Epoch: 6 Valid Perplexity: 121.119
# Epoch: 7 Learning rate: 0.250
# 0.004 perplexity: 73.516 speed: 1912 wps
# 0.104 perplexity: 53.349 speed: 1916 wps
# 0.204 perplexity: 57.919 speed: 1917 wps
# 0.304 perplexity: 55.602 speed: 1913 wps
# 0.404 perplexity: 54.634 speed: 1904 wps
# 0.504 perplexity: 53.828 speed: 1890 wps
# 0.604 perplexity: 52.161 speed: 1872 wps
# 0.703 perplexity: 51.534 speed: 1870 wps
# 0.803 perplexity: 50.839 speed: 1873 wps
# 0.903 perplexity: 49.291 speed: 1867 wps
# Epoch: 7 Train Perplexity: 48.385
# Epoch: 7 Valid Perplexity: 122.026
# Epoch: 8 Learning rate: 0.125
# 0.004 perplexity: 65.417 speed: 1862 wps
# 0.104 perplexity: 47.318 speed: 1879 wps
# 0.204 perplexity: 51.502 speed: 1883 wps
# 0.304 perplexity: 49.409 speed: 1878 wps
# 0.404 perplexity: 48.544 speed: 1875 wps
# 0.504 perplexity: 47.797 speed: 1872 wps
# 0.604 perplexity: 46.285 speed: 1866 wps
# 0.703 perplexity: 45.682 speed: 1870 wps
# 0.803 perplexity: 45.004 speed: 1876 wps
# 0.903 perplexity: 43.562 speed: 1881 wps
# Epoch: 8 Train Perplexity: 42.701
# Epoch: 8 Valid Perplexity: 123.332
# Epoch: 9 Learning rate: 0.062
# 0.004 perplexity: 61.041 speed: 1913 wps
# 0.104 perplexity: 44.297 speed: 1898 wps
# 0.204 perplexity: 48.233 speed: 1893 wps
# 0.304 perplexity: 46.255 speed: 1878 wps
# 0.404 perplexity: 45.454 speed: 1873 wps
# 0.504 perplexity: 44.750 speed: 1871 wps
# 0.604 perplexity: 43.319 speed: 1863 wps
# 0.703 perplexity: 42.725 speed: 1858 wps
# 0.803 perplexity: 42.064 speed: 1856 wps
# 0.903 perplexity: 40.681 speed: 1856 wps
# Epoch: 9 Train Perplexity: 39.842
# Epoch: 9 Valid Perplexity: 124.021
# Epoch: 10 Learning rate: 0.031
# 0.004 perplexity: 58.555 speed: 1823 wps
# 0.104 perplexity: 42.732 speed: 1863 wps
# 0.204 perplexity: 46.542 speed: 1860 wps
# 0.304 perplexity: 44.621 speed: 1859 wps
# 0.404 perplexity: 43.856 speed: 1861 wps
# 0.504 perplexity: 43.174 speed: 1854 wps
# 0.604 perplexity: 41.787 speed: 1855 wps
# 0.703 perplexity: 41.196 speed: 1867 wps
# 0.803 perplexity: 40.541 speed: 1866 wps
# 0.903 perplexity: 39.186 speed: 1866 wps
# Epoch: 10 Train Perplexity: 38.355
# Epoch: 10 Valid Perplexity: 123.951
# Epoch: 11 Learning rate: 0.016
# 0.004 perplexity: 57.102 speed: 1873 wps
# 0.104 perplexity: 41.822 speed: 1893 wps
# 0.204 perplexity: 45.594 speed: 1893 wps
# 0.304 perplexity: 43.712 speed: 1901 wps
# 0.404 perplexity: 42.972 speed: 1897 wps
# 0.504 perplexity: 42.304 speed: 1893 wps
# 0.604 perplexity: 40.942 speed: 1889 wps
# 0.703 perplexity: 40.352 speed: 1886 wps
# 0.803 perplexity: 39.699 speed: 1883 wps
# 0.903 perplexity: 38.360 speed: 1876 wps
# Epoch: 11 Train Perplexity: 37.537
# Epoch: 11 Valid Perplexity: 123.645
# Epoch: 12 Learning rate: 0.008
# 0.004 perplexity: 56.262 speed: 1722 wps
# 0.104 perplexity: 41.263 speed: 1826 wps
# 0.204 perplexity: 45.040 speed: 1849 wps
# 0.304 perplexity: 43.187 speed: 1860 wps
# 0.404 perplexity: 42.461 speed: 1858 wps
# 0.504 perplexity: 41.804 speed: 1859 wps
# 0.604 perplexity: 40.457 speed: 1857 wps
# 0.703 perplexity: 39.871 speed: 1854 wps
# 0.803 perplexity: 39.223 speed: 1852 wps
# 0.903 perplexity: 37.893 speed: 1852 wps
# Epoch: 12 Train Perplexity: 37.077
# Epoch: 12 Valid Perplexity: 123.375
# Epoch: 13 Learning rate: 0.004
# 0.004 perplexity: 55.806 speed: 1901 wps
# 0.104 perplexity: 40.948 speed: 1837 wps
# 0.204 perplexity: 44.728 speed: 1848 wps
# 0.304 perplexity: 42.894 speed: 1845 wps
# 0.404 perplexity: 42.177 speed: 1852 wps
# 0.504 perplexity: 41.528 speed: 1855 wps
# 0.604 perplexity: 40.189 speed: 1859 wps
# 0.703 perplexity: 39.605 speed: 1857 wps
# 0.803 perplexity: 38.962 speed: 1855 wps
# 0.903 perplexity: 37.638 speed: 1857 wps
# Epoch: 13 Train Perplexity: 36.826
# Epoch: 13 Valid Perplexity: 123.159
# Test Perplexity: 118.158
